# %%
# !pip install -q transformers accelerate bitsandbytes
# !pip install -q datasets
# !pip install -q evaluate
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.1/76.1 MB 22.9 MB/s eta 0:00:00:00:0100:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.0/84.0 kB 3.0 MB/s eta 0:00:00

# %%
from transformers import AutoTokenizer, AutoModelForCausalLM
# Load model directly
model_name = "premai-io/prem-1B-SQL"

tokenizer = AutoTokenizer.from_pretrained(model_name)

model = AutoModelForCausalLM.from_pretrained(
    model_name,
    device_map="auto"  # Đưa mô hình lên GPU nếu có
)
# Out:
# tokenizer_config.json:   0%|          | 0.00/5.49k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.37M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/462 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/794 [00:00<?, ?B/s]
# model.safetensors.index.json:   0%|          | 0.00/18.0k [00:00<?, ?B/s]
# Downloading shards:   0%|          | 0/2 [00:00<?, ?it/s]
# model-00001-of-00002.safetensors:   0%|          | 0.00/4.99G [00:00<?, ?B/s]
# model-00002-of-00002.safetensors:   0%|          | 0.00/400M [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/119 [00:00<?, ?B/s]

# %%
import torch

device = "cuda" if torch.cuda.is_available() else "cpu"

# %%
from datasets import load_dataset

# Tải bộ dữ liệu từ Hugging Face
dataset = load_dataset("gretelai/synthetic_text_to_sql")

# Truy cập phần train và test
train_data = dataset['train']
test_data = dataset['test']

# In 2 mẫu đại diện dưới dạng JSON từ phần train và test
import json

# Lấy 2 mẫu đầu tiên từ phần train và test
train_sample = train_data[0]
test_sample = test_data[0]

# In dưới dạng JSON
print("Train Sample:", json.dumps(train_sample, indent=2))
print("Test Sample:", json.dumps(test_sample, indent=2))
# Out:
# README.md:   0%|          | 0.00/8.18k [00:00<?, ?B/s]
# (…)nthetic_text_to_sql_train.snappy.parquet:   0%|          | 0.00/32.4M [00:00<?, ?B/s]
# (…)ynthetic_text_to_sql_test.snappy.parquet:   0%|          | 0.00/1.90M [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/100000 [00:00<?, ? examples/s]
# Generating test split:   0%|          | 0/5851 [00:00<?, ? examples/s]
# Train Sample: {
#   "id": 5097,
#   "domain": "forestry",
#   "domain_description": "Comprehensive data on sustainable forest management, timber production, wildlife habitat, and carbon sequestration in forestry.",
#   "sql_complexity": "single join",
#   "sql_complexity_description": "only one join (specify inner, outer, cross)",
#   "sql_task_type": "analytics and reporting",
#   "sql_task_type_description": "generating reports, dashboards, and analytical insights",
#   "sql_prompt": "What is the total volume of timber sold by each salesperson, sorted by salesperson?",
#   "sql_context": "CREATE TABLE salesperson (salesperson_id INT, name TEXT, region TEXT); INSERT INTO salesperson (salesperson_id, name, region) VALUES (1, 'John Doe', 'North'), (2, 'Jane Smith', 'South'); CREATE TABLE timber_sales (sales_id INT, salesperson_id INT, volume REAL, sale_date DATE); INSERT INTO timber_sales (sales_id, salesperson_id, volume, sale_date) VALUES (1, 1, 120, '2021-01-01'), (2, 1, 150, '2021-02-01'), (3, 2, 180, '2021-01-01');",
#   "sql": "SELECT salesperson_id, name, SUM(volume) as total_volume FROM timber_sales JOIN salesperson ON timber_sales.salesperson_id = salesperson.salesperson_id GROUP BY salesperson_id, name ORDER BY total_volume DESC;",
#   "sql_explanation": "Joins timber_sales and salesperson tables, groups sales by salesperson, calculates total volume sold by each salesperson, and orders the results by total volume in descending order."
# }
# Test Sample: {
#   "id": 1,
#   "domain": "artificial intelligence",
#   "domain_description": "AI data on algorithmic fairness, AI safety, explainable AI, and creative AI applications.",
#   "sql_complexity": "basic SQL",
#   "sql_complexity_description": "basic SQL with a simple select statement",
#   "sql_task_type": "analytics and reporting",
#   "sql_task_type_description": "generating reports, dashboards, and analytical insights",
#   "sql_prompt": "What is the average explainability score of creative AI applications in 'Europe' and 'North America' in the 'creative_ai' table?",
#   "sql_context": "CREATE TABLE creative_ai (application_id INT, name TEXT, region TEXT, explainability_score FLOAT); INSERT INTO creative_ai (application_id, name, region, explainability_score) VALUES (1, 'ApplicationX', 'Europe', 0.87), (2, 'ApplicationY', 'North America', 0.91), (3, 'ApplicationZ', 'Europe', 0.84), (4, 'ApplicationAA', 'North America', 0.93), (5, 'ApplicationAB', 'Europe', 0.89);",
#   "sql": "SELECT AVG(explainability_score) FROM creative_ai WHERE region IN ('Europe', 'North America');",
#   "sql_explanation": "This SQL query calculates the average explainability score of creative AI applications in 'Europe' and 'North America' in the 'creative_ai' table by using the AVG() function on the 'explainability_score' column, and the WHERE clause to filter records based on the 'region' column."
# }

# %%
LEFT_INDEX = 4000
RIGHT_INDEX = 5851
BATCH_SIZE = 8

# %%
references = [
    test_data[idx]['sql'] for idx in range(LEFT_INDEX, RIGHT_INDEX)
]

# %%
BASE_TEXT2SQL_PROMPT = """
# Follow these instruction:
You will be given context of making tables of a database. Your job is to write correct
error free SQL query based on the question asked. Please make sure:

1. Do not add ``` at start / end of the query. It should be a single line query in a  single line (string format)
2. Make sure the column names are correct and exists in the table
3. For column names which has a space with it, make sure you have put `` in that column name
4. Think step by step and always check context and question and the column names before writing the
query.

# Hre is context for the SQL query:
{additional_knowledge}

# Question: {question}

# SQL:
"""

few_shot_examples = '''
single join: only one join (specify inner, outer, cross):
  Sample 1:
    SQL Prompt: What is the total volume of timber sold by each salesperson, sorted by salesperson?
    SQL Query: SELECT salesperson_id, name, SUM(volume) as total_volume FROM timber_sales JOIN salesperson ON timber_sales.salesperson_id = salesperson.salesperson_id GROUP BY salesperson_id, name ORDER BY total_volume DESC;
  Sample 2:
    SQL Prompt: What is the average water temperature for each fish species in February?
    SQL Query: SELECT SpeciesName, AVG(WaterTemp) as AvgTemp FROM SpeciesWaterTemp INNER JOIN FishSpecies ON SpeciesWaterTemp.SpeciesID = FishSpecies.SpeciesID WHERE MONTH(Date) = 2 GROUP BY SpeciesName;
  Sample 3:
    SQL Prompt: What is the average income of farmers in each district in India?
    SQL Query: SELECT d.name, AVG(f.income) FROM farmers_india f JOIN districts_india d ON f.district_id = d.id GROUP BY d.name;

aggregation: aggregation functions (COUNT, SUM, AVG, MIN, MAX, etc.), and HAVING clause:
  Sample 1:
    SQL Prompt: List all the unique equipment types and their corresponding total maintenance frequency from the equipment_maintenance table.
    SQL Query: SELECT equipment_type, SUM(maintenance_frequency) AS total_maintenance_frequency FROM equipment_maintenance GROUP BY equipment_type;
  Sample 2:
    SQL Prompt: What is the total trade value and average price for each trader and stock in the trade_history table?
    SQL Query: SELECT trader_id, stock, SUM(price * quantity) as total_trade_value, AVG(price) as avg_price FROM trade_history GROUP BY trader_id, stock;
  Sample 3:
    SQL Prompt: Show the conservation status of marine mammals and birds by year.
    SQL Query: SELECT animal_group, conservation_status, year, COUNT(*) FROM combined GROUP BY animal_group, conservation_status, year;

basic SQL: basic SQL with a simple select statement:
  Sample 1:
    SQL Prompt: How many marine species are found in the Southern Ocean?
    SQL Query: SELECT COUNT(*) FROM marine_species WHERE location = 'Southern Ocean';
  Sample 2:
    SQL Prompt: What is the total spending on humanitarian assistance by the European Union in the last 3 years?
    SQL Query: SELECT SUM(spending) FROM defense.eu_humanitarian_assistance WHERE year BETWEEN 2019 AND 2021;
  Sample 3:
    SQL Prompt: Delete a program's outcome data
    SQL Query: DELETE FROM Program_Outcomes WHERE program_id = 1002;

window functions: window functions (e.g., ROW_NUMBER, LEAD, LAG, RANk, NTILE, PERCENT_RANK, etc.) with partitioning and ordering:
  Sample 1:
    SQL Prompt: Find the energy efficiency upgrades with the highest cost and their types.
    SQL Query: SELECT type, cost FROM (SELECT type, cost, ROW_NUMBER() OVER (ORDER BY cost DESC) as rn FROM upgrades) sub WHERE rn = 1;
  Sample 2:
    SQL Prompt: Which autonomous vehicles have the highest safety ratings in the 'auto_show' table?
    SQL Query: SELECT vehicle_name, safety_rating FROM (SELECT vehicle_name, safety_rating, RANK() OVER (ORDER BY safety_rating DESC) as safety_rank FROM auto_show WHERE vehicle_name LIKE '%Autonomous%') AS auton_ranks WHERE safety_rank = 1;
  Sample 3:
    SQL Prompt: Find the title and genre of the top 3 movies with the highest ratings from studios based in Italy, ordered by ratings in descending order.
    SQL Query: SELECT title, genre FROM (SELECT title, genre, studio, rating, ROW_NUMBER() OVER (PARTITION BY studio ORDER BY rating DESC) as rank FROM movies WHERE studio LIKE '%Italy%') subquery WHERE rank <= 3 ORDER BY rating DESC;

subqueries: subqueries, including correlated and nested subqueries:
  Sample 1:
    SQL Prompt: What is the average sea surface temperature in the Pacific Ocean per year?
    SQL Query: SELECT AVG(temperature) FROM (SELECT temperature FROM Ocean WHERE region = 'Pacific' GROUP BY temperature, YEAR(STR_TO_DATE(region, '%Y'))) AS PacificAverage;
  Sample 2:
    SQL Prompt: What are the common cybersecurity policies across all departments, according to our Policy Analysis database?
    SQL Query: SELECT policy FROM PolicyAnalysis GROUP BY policy HAVING COUNT(DISTINCT department) = (SELECT COUNT(DISTINCT department) FROM PolicyAnalysis);
  Sample 3:
    SQL Prompt: What is the total number of space missions led by women?
    SQL Query: SELECT COUNT(*) FROM space_missions WHERE leader IN (SELECT name FROM astronauts WHERE gender = 'Female');

multiple_joins: two or more joins (specify inner, outer, cross):
  Sample 1:
    SQL Prompt: What are the names and habitats of all animals that are part of an education program in the 'Americas' region?
    SQL Query: SELECT a.name, h.name FROM Animals a INNER JOIN AnimalEducation ae ON a.id = ae.animal_id INNER JOIN EducationPrograms e ON ae.program_id = e.id INNER JOIN Coordinators c ON e.coordinator_id = c.id INNER JOIN Habitat h ON a.habitat_id = h.id WHERE c.region = 'Americas';
  Sample 2:
    SQL Prompt: What is the total biomass of deciduous trees per wildlife habitat?
    SQL Query: SELECT h.name habitat, SUM(t.biomass) total_biomass FROM trees t JOIN tree_habitat_associations tha ON t.id = tha.tree_id JOIN wildlife_habitats h ON tha.habitat_id = h.id JOIN tree_types tt ON t.tree_type_id = tt.id WHERE tt.name = 'Deciduous' GROUP BY h.name;
  Sample 3:
    SQL Prompt: Get the name and country of the top 3 customers for organic cosmetics
    SQL Query: SELECT customers.name, customers.country FROM customers JOIN purchases ON customers.id = purchases.customer_id JOIN products ON purchases.product_id = products.id WHERE products.organic = TRUE GROUP BY customers.id ORDER BY SUM(purchases.quantity) DESC LIMIT 3;

set operations: set operations such as UNION, INTERSECT, and EXCEPT:
  Sample 1:
    SQL Prompt: Which menu items are served at both Location1 and Location2, but not at Location3?
    SQL Query: SELECT menu_item FROM menu_items WHERE location = 'Location1' INTERSECT SELECT menu_item FROM menu_items WHERE location = 'Location2' EXCEPT SELECT menu_item FROM menu_items WHERE location = 'Location3';
  Sample 2:
    SQL Prompt: How many players from Africa and South America have adopted VR technology?
    SQL Query: SELECT 'Africa' AS continent, COUNT(DISTINCT p.player_id) AS num_players FROM players p JOIN vr_tech v ON p.player_id = v.player_id WHERE p.region = 'Africa' UNION ALL SELECT 'South America' AS continent, COUNT(DISTINCT p.player_id) AS num_players FROM players p JOIN vr_tech v ON p.player_id = v.player_id WHERE p.region = 'South America';
  Sample 3:
    SQL Prompt: What are the total number of works in the 'Artworks' and 'Exhibitions' tables?
    SQL Query: SELECT COUNT(*) FROM Artworks UNION ALL SELECT COUNT(*) FROM Exhibitions;

CTEs: common table expressions:
  Sample 1:
    SQL Prompt: Add a new spacecraft to the Spacecrafts table.
    SQL Query: WITH new_spacecraft AS (VALUES (1, 'New Horizons 2', 'NASA', '2025-01-01', 'Active')) INSERT INTO Spacecrafts (Sid, Name, Manufacturer, Launch_Date, Status) SELECT * FROM new_spacecraft;
  Sample 2:
    SQL Prompt: Delete a publication record from the "publications" table
    SQL Query: WITH deleted_publication AS (DELETE FROM publications WHERE id = 1 RETURNING *) SELECT * FROM deleted_publication;
  Sample 3:
    SQL Prompt: Delete an artwork from the 'Impressionist Art' exhibition
    SQL Query: WITH artwork_to_delete AS (DELETE FROM exhibition_artworks WHERE exhibition_id = 1 AND artwork_id = 1) SELECT * FROM artwork_to_delete;'''

# %%
import re
import json
import torch
from time import time
from torch.utils.data import DataLoader

extracted_sqls_with_context = []
# Định nghĩa dataset từ test_data
class SQLDataset(torch.utils.data.Dataset):
    def __init__(self, dataset, left, right):
        self.dataset = dataset.select(range(left, right)).to_dict()
        self.samples = [dict(zip(self.dataset.keys(), values)) for values in zip(*self.dataset.values())]

    def __len__(self):
        return len(self.samples)

    def __getitem__(self, idx):
        sample = self.samples[idx]
        return BASE_TEXT2SQL_PROMPT.format(
            question=sample['sql_prompt'],
            additional_knowledge=sample['sql_context'],
            few_shot_examples=few_shot_examples
        )

# Bắt đầu đo thời gian
start_time = time()

# Tạo DataLoader
sql_dataset = SQLDataset(test_data, LEFT_INDEX, RIGHT_INDEX)
dataloader = DataLoader(sql_dataset, batch_size=BATCH_SIZE, shuffle=False)

# %%
# Định nghĩa file output
filename = f'Prem-1B-SQL_{LEFT_INDEX}_{RIGHT_INDEX}.jsonl'

total_samples = 0  # Đếm tổng số mẫu

with open(filename, 'w') as json_file:
    for batch_idx, batch_sql_prompts in enumerate(dataloader):
        batch_start_time = time()  # Đo thời gian cho từng batch

        tokenizer.padding_side = "left"
        inputs = tokenizer(batch_sql_prompts, return_tensors="pt", padding=True, truncation=True).to(device)

        # Sinh output từ mô hình
        with torch.no_grad():
          generated_ids = model.generate(
              **inputs,
              max_new_tokens=512,
              pad_token_id=tokenizer.eos_token_id
          )


        generated_ids = [
            output_ids[len(input_ids):] for input_ids, output_ids in zip(inputs.input_ids, generated_ids)
        ]
        # Giải mã output
        generated_sqls = tokenizer.batch_decode(generated_ids, skip_special_tokens=True)


        for idx, generated_sql in enumerate(generated_sqls):
            generated_sql = generated_sql.strip()  # Loại bỏ khoảng trắng hai đầu
            generated_sql = re.sub(r"^[^\w]+", "", generated_sql)   # Loại bỏ các ký tự không hợp lệ bên trái
            generated_sql = generated_sql.split(';', 1)[0] + ';' if ';' in generated_sql else generated_sql  # Lấy đến dấu ';' đầu tiên
            total_samples += 1
            extracted_sqls_with_context.append(generated_sql)
            result = {'id': LEFT_INDEX + batch_idx * BATCH_SIZE + idx + 1, 'answer': generated_sql}
            json.dump(result, json_file)
            json_file.write("\n")




        batch_end_time = time()
        print(f"⏱️ Batch {batch_idx + 1} processed in {batch_end_time - batch_start_time:.2f} seconds.")

# Kết thúc đo thời gian
end_time = time()
elapsed_time = end_time - start_time

# In ra kết quả
print(f"✅ Data saved to {filename}")
print(f"⏳ Total time taken: {elapsed_time:.2f} seconds")
if total_samples > 0:
    print(f"⏱️ Average time per sample: {elapsed_time / total_samples:.4f} seconds")
# Out:
# ⏱️ Batch 1 processed in 6.14 seconds.
# ⏱️ Batch 2 processed in 9.94 seconds.
# ⏱️ Batch 3 processed in 36.33 seconds.
# ⏱️ Batch 4 processed in 6.46 seconds.
# ⏱️ Batch 5 processed in 5.93 seconds.
# ⏱️ Batch 6 processed in 7.24 seconds.
# ⏱️ Batch 7 processed in 8.19 seconds.
# ⏱️ Batch 8 processed in 5.81 seconds.
# ⏱️ Batch 9 processed in 7.68 seconds.
# ⏱️ Batch 10 processed in 8.31 seconds.
# ⏱️ Batch 11 processed in 6.91 seconds.
# ⏱️ Batch 12 processed in 7.85 seconds.
# ⏱️ Batch 13 processed in 6.95 seconds.
# ⏱️ Batch 14 processed in 8.90 seconds.
# ⏱️ Batch 15 processed in 39.29 seconds.
# ⏱️ Batch 16 processed in 10.75 seconds.
# ⏱️ Batch 17 processed in 4.60 seconds.
# ⏱️ Batch 18 processed in 40.91 seconds.
# ⏱️ Batch 19 processed in 10.12 seconds.
# ⏱️ Batch 20 processed in 8.45 seconds.
# ⏱️ Batch 21 processed in 6.35 seconds.
# ⏱️ Batch 22 processed in 8.30 seconds.
# ⏱️ Batch 23 processed in 7.67 seconds.
# ⏱️ Batch 24 processed in 7.18 seconds.
# ⏱️ Batch 25 processed in 5.04 seconds.
# ⏱️ Batch 26 processed in 10.93 seconds.
# ⏱️ Batch 27 processed in 5.84 seconds.
# ⏱️ Batch 28 processed in 7.64 seconds.
# ⏱️ Batch 29 processed in 5.49 seconds.
# ⏱️ Batch 30 processed in 6.33 seconds.
# ⏱️ Batch 31 processed in 14.96 seconds.
# ⏱️ Batch 32 processed in 8.32 seconds.
# ⏱️ Batch 33 processed in 4.43 seconds.
# ⏱️ Batch 34 processed in 7.54 seconds.
# ⏱️ Batch 35 processed in 8.20 seconds.
# ⏱️ Batch 36 processed in 5.87 seconds.
# ⏱️ Batch 37 processed in 10.76 seconds.
# ⏱️ Batch 38 processed in 6.12 seconds.
# ⏱️ Batch 39 processed in 7.15 seconds.
# ⏱️ Batch 40 processed in 6.19 seconds.
# ⏱️ Batch 41 processed in 8.75 seconds.
# ⏱️ Batch 42 processed in 11.55 seconds.
# ⏱️ Batch 43 processed in 8.70 seconds.
# ⏱️ Batch 44 processed in 9.64 seconds.
# ⏱️ Batch 45 processed in 5.33 seconds.
# ⏱️ Batch 46 processed in 7.24 seconds.
# ⏱️ Batch 47 processed in 7.01 seconds.
# ⏱️ Batch 48 processed in 7.10 seconds.
# ⏱️ Batch 49 processed in 6.34 seconds.
# ⏱️ Batch 50 processed in 9.08 seconds.
# ⏱️ Batch 51 processed in 7.73 seconds.
# ⏱️ Batch 52 processed in 7.45 seconds.
# ⏱️ Batch 53 processed in 5.32 seconds.
# ⏱️ Batch 54 processed in 38.92 seconds.
# ⏱️ Batch 55 processed in 42.23 seconds.
# ⏱️ Batch 56 processed in 6.43 seconds.
# ⏱️ Batch 57 processed in 9.29 seconds.
# ⏱️ Batch 58 processed in 7.41 seconds.
# ⏱️ Batch 59 processed in 7.02 seconds.
# ⏱️ Batch 60 processed in 7.66 seconds.
# ⏱️ Batch 61 processed in 6.95 seconds.
# ⏱️ Batch 62 processed in 8.97 seconds.
# ⏱️ Batch 63 processed in 5.06 seconds.
# ⏱️ Batch 64 processed in 36.16 seconds.
# ⏱️ Batch 65 processed in 9.62 seconds.
# ⏱️ Batch 66 processed in 10.75 seconds.
# ⏱️ Batch 67 processed in 10.54 seconds.
# ⏱️ Batch 68 processed in 6.87 seconds.
# ⏱️ Batch 69 processed in 9.12 seconds.
# ⏱️ Batch 70 processed in 7.26 seconds.
# ⏱️ Batch 71 processed in 5.04 seconds.
# ⏱️ Batch 72 processed in 18.33 seconds.
# ⏱️ Batch 73 processed in 39.36 seconds.
# ⏱️ Batch 74 processed in 9.18 seconds.
# ⏱️ Batch 75 processed in 7.25 seconds.
# ⏱️ Batch 76 processed in 17.89 seconds.
# ⏱️ Batch 77 processed in 9.84 seconds.
# ⏱️ Batch 78 processed in 6.19 seconds.
# ⏱️ Batch 79 processed in 5.05 seconds.
# ⏱️ Batch 80 processed in 6.84 seconds.
# ⏱️ Batch 81 processed in 6.34 seconds.
# ⏱️ Batch 82 processed in 38.30 seconds.
# ⏱️ Batch 83 processed in 10.15 seconds.
# ⏱️ Batch 84 processed in 8.99 seconds.
# ⏱️ Batch 85 processed in 7.69 seconds.
# ⏱️ Batch 86 processed in 42.04 seconds.
# ⏱️ Batch 87 processed in 6.52 seconds.
# ⏱️ Batch 88 processed in 9.49 seconds.
# ⏱️ Batch 89 processed in 11.43 seconds.
# ⏱️ Batch 90 processed in 38.33 seconds.
# ⏱️ Batch 91 processed in 5.97 seconds.
# ⏱️ Batch 92 processed in 37.01 seconds.
# ⏱️ Batch 93 processed in 8.15 seconds.
# ⏱️ Batch 94 processed in 8.53 seconds.
# ⏱️ Batch 95 processed in 8.04 seconds.
# ⏱️ Batch 96 processed in 7.86 seconds.
# ⏱️ Batch 97 processed in 7.03 seconds.
# ⏱️ Batch 98 processed in 6.02 seconds.
# ⏱️ Batch 99 processed in 6.32 seconds.
# ⏱️ Batch 100 processed in 6.10 seconds.
# ⏱️ Batch 101 processed in 5.50 seconds.
# ⏱️ Batch 102 processed in 9.28 seconds.
# ⏱️ Batch 103 processed in 8.18 seconds.
# ⏱️ Batch 104 processed in 5.47 seconds.
# ⏱️ Batch 105 processed in 6.47 seconds.
# ⏱️ Batch 106 processed in 5.46 seconds.
# ⏱️ Batch 107 processed in 13.78 seconds.
# ⏱️ Batch 108 processed in 6.45 seconds.
# ⏱️ Batch 109 processed in 38.22 seconds.
# ⏱️ Batch 110 processed in 10.30 seconds.
# ⏱️ Batch 111 processed in 7.08 seconds.
# ⏱️ Batch 112 processed in 5.91 seconds.
# ⏱️ Batch 113 processed in 6.95 seconds.
# ⏱️ Batch 114 processed in 9.49 seconds.
# ⏱️ Batch 115 processed in 5.06 seconds.
# ⏱️ Batch 116 processed in 7.07 seconds.
# ⏱️ Batch 117 processed in 7.08 seconds.
# ⏱️ Batch 118 processed in 6.82 seconds.
# ⏱️ Batch 119 processed in 6.81 seconds.
# ⏱️ Batch 120 processed in 8.26 seconds.
# ⏱️ Batch 121 processed in 7.06 seconds.
# ⏱️ Batch 122 processed in 9.29 seconds.
# ⏱️ Batch 123 processed in 11.19 seconds.
# ⏱️ Batch 124 processed in 7.58 seconds.
# ⏱️ Batch 125 processed in 7.65 seconds.
# ⏱️ Batch 126 processed in 6.86 seconds.
# ⏱️ Batch 127 processed in 38.23 seconds.
# ⏱️ Batch 128 processed in 6.12 seconds.
# ⏱️ Batch 129 processed in 6.42 seconds.
# ⏱️ Batch 130 processed in 8.09 seconds.
# ⏱️ Batch 131 processed in 4.55 seconds.
# ⏱️ Batch 132 processed in 8.88 seconds.
# ⏱️ Batch 133 processed in 9.04 seconds.
# ⏱️ Batch 134 processed in 10.48 seconds.
# ⏱️ Batch 135 processed in 7.84 seconds.
# ⏱️ Batch 136 processed in 6.78 seconds.
# ⏱️ Batch 137 processed in 8.94 seconds.
# ⏱️ Batch 138 processed in 10.17 seconds.
# ⏱️ Batch 139 processed in 5.62 seconds.
# ⏱️ Batch 140 processed in 37.66 seconds.
# ⏱️ Batch 141 processed in 7.88 seconds.
# ⏱️ Batch 142 processed in 6.27 seconds.
# ⏱️ Batch 143 processed in 4.63 seconds.
# ⏱️ Batch 144 processed in 8.09 seconds.
# ⏱️ Batch 145 processed in 6.57 seconds.
# ⏱️ Batch 146 processed in 8.79 seconds.
# ⏱️ Batch 147 processed in 7.97 seconds.
# ⏱️ Batch 148 processed in 42.08 seconds.
# ⏱️ Batch 149 processed in 6.02 seconds.
# ⏱️ Batch 150 processed in 7.03 seconds.
# ⏱️ Batch 151 processed in 5.41 seconds.
# ⏱️ Batch 152 processed in 38.27 seconds.
# ⏱️ Batch 153 processed in 38.58 seconds.
# ⏱️ Batch 154 processed in 7.20 seconds.
# ⏱️ Batch 155 processed in 7.29 seconds.
# ⏱️ Batch 156 processed in 7.86 seconds.
# ⏱️ Batch 157 processed in 7.37 seconds.
# ⏱️ Batch 158 processed in 7.22 seconds.
# ⏱️ Batch 159 processed in 7.27 seconds.
# ⏱️ Batch 160 processed in 6.98 seconds.
# ⏱️ Batch 161 processed in 5.47 seconds.
# ⏱️ Batch 162 processed in 7.81 seconds.
# ⏱️ Batch 163 processed in 7.14 seconds.
# ⏱️ Batch 164 processed in 5.98 seconds.
# ⏱️ Batch 165 processed in 5.77 seconds.
# ⏱️ Batch 166 processed in 11.37 seconds.
# ⏱️ Batch 167 processed in 36.82 seconds.
# ⏱️ Batch 168 processed in 4.53 seconds.
# ⏱️ Batch 169 processed in 9.84 seconds.
# ⏱️ Batch 170 processed in 10.10 seconds.
# ⏱️ Batch 171 processed in 9.59 seconds.
# ⏱️ Batch 172 processed in 8.61 seconds.
# ⏱️ Batch 173 processed in 7.40 seconds.
# ⏱️ Batch 174 processed in 7.53 seconds.
# ⏱️ Batch 175 processed in 7.82 seconds.
# ⏱️ Batch 176 processed in 5.47 seconds.
# ⏱️ Batch 177 processed in 37.73 seconds.
# ⏱️ Batch 178 processed in 39.60 seconds.
# ⏱️ Batch 179 processed in 6.06 seconds.
# ⏱️ Batch 180 processed in 7.22 seconds.
# ⏱️ Batch 181 processed in 7.17 seconds.
# ⏱️ Batch 182 processed in 6.65 seconds.
# ⏱️ Batch 183 processed in 6.97 seconds.
# ⏱️ Batch 184 processed in 7.17 seconds.
# ⏱️ Batch 185 processed in 8.40 seconds.
# ⏱️ Batch 186 processed in 5.95 seconds.
# ⏱️ Batch 187 processed in 5.36 seconds.
# ⏱️ Batch 188 processed in 7.39 seconds.
# ⏱️ Batch 189 processed in 5.39 seconds.
# ⏱️ Batch 190 processed in 8.25 seconds.
# ⏱️ Batch 191 processed in 6.62 seconds.
# ⏱️ Batch 192 processed in 6.19 seconds.
# ⏱️ Batch 193 processed in 6.99 seconds.
# ⏱️ Batch 194 processed in 7.94 seconds.
# ⏱️ Batch 195 processed in 7.20 seconds.
# ⏱️ Batch 196 processed in 40.35 seconds.
# ⏱️ Batch 197 processed in 8.55 seconds.
# ⏱️ Batch 198 processed in 39.76 seconds.
# ⏱️ Batch 199 processed in 5.71 seconds.
# ⏱️ Batch 200 processed in 6.51 seconds.
# ⏱️ Batch 201 processed in 7.14 seconds.
# ⏱️ Batch 202 processed in 6.32 seconds.
# ⏱️ Batch 203 processed in 5.98 seconds.
# ⏱️ Batch 204 processed in 8.63 seconds.
# ⏱️ Batch 205 processed in 8.24 seconds.
# ⏱️ Batch 206 processed in 8.64 seconds.
# ⏱️ Batch 207 processed in 7.49 seconds.
# ⏱️ Batch 208 processed in 9.47 seconds.
# ⏱️ Batch 209 processed in 8.01 seconds.
# ⏱️ Batch 210 processed in 7.04 seconds.
# ⏱️ Batch 211 processed in 8.60 seconds.
# ⏱️ Batch 212 processed in 4.57 seconds.
# ⏱️ Batch 213 processed in 6.75 seconds.
# ⏱️ Batch 214 processed in 13.73 seconds.
# ⏱️ Batch 215 processed in 6.76 seconds.
# ⏱️ Batch 216 processed in 4.93 seconds.
# ⏱️ Batch 217 processed in 7.85 seconds.
# ⏱️ Batch 218 processed in 7.74 seconds.
# ⏱️ Batch 219 processed in 8.16 seconds.
# ⏱️ Batch 220 processed in 5.75 seconds.
# ⏱️ Batch 221 processed in 41.36 seconds.
# ⏱️ Batch 222 processed in 8.46 seconds.
# ⏱️ Batch 223 processed in 9.52 seconds.
# ⏱️ Batch 224 processed in 8.49 seconds.
# ⏱️ Batch 225 processed in 7.09 seconds.
# ⏱️ Batch 226 processed in 7.30 seconds.
# ⏱️ Batch 227 processed in 12.69 seconds.
# ⏱️ Batch 228 processed in 9.72 seconds.
# ⏱️ Batch 229 processed in 8.81 seconds.
# ⏱️ Batch 230 processed in 6.28 seconds.
# ⏱️ Batch 231 processed in 5.48 seconds.
# ⏱️ Batch 232 processed in 4.21 seconds.
# ✅ Data saved to Prem-1B-SQL_4000_5851.jsonl
# ⏳ Total time taken: 2498.43 seconds
# ⏱️ Average time per sample: 1.3498 seconds

# %%
extracted_sqls_with_context
# Out:
# ["SELECT MAX(billing_amount) FROM cases JOIN attorneys ON cases.attorney_id = attorneys.attorney_id WHERE attorneys.state = 'NY' AND attorneys.win_rate > 0.8;",
#  "SELECT country, emissions FROM (SELECT country, emissions, ROW_NUMBER() OVER (ORDER BY emissions DESC) as rn FROM emissions WHERE country != 'US') t WHERE rn <= 3;",
#  'SELECT State, COUNT(*) FROM Hospitals WHERE MentalHealth = TRUE GROUP BY State;',
#  'SELECT AVG(raised_amount) FROM investments JOIN diversity ON investments.company_id = diversity.company_id WHERE latinx_founder = true;',
#  "SELECT COUNT(*) FROM accommodations WHERE accommodation_category = 'Online Learning';",
#  "DELETE FROM CoralReefs WHERE Health_Status = 'Degraded';",
#  "SELECT MIN(Daily_Transactions) FROM Smart_Contracts SC JOIN Digital_Assets DA ON SC.Asset_ID = DA.Asset_ID WHERE DA.Issuer_Country = 'Africa';",
#  "SELECT status FROM regulation WHERE country = 'germany';",
#  'SELECT SUM(market_cap) FROM digital_assets WHERE asset_id IN (SELECT asset_id FROM transactions GROUP BY asset_id HAVING COUNT(*) >= 1000);',
#  "SELECT AVG(training_count) FROM DisasterPreparedness WHERE state = 'California' GROUP BY year;",
#  'SELECT artist_name, SUM(quantity) FROM MuseumArtists GROUP BY artist_name;',
#  "SELECT AVG(avg_attendance) FROM concerts WHERE genre = 'Jazz';",
#  "INSERT INTO veteran_employment (veteran_id, name, job_start_date) VALUES (888, 'James Smith', '2015-01-01');",
#  "UPDATE threat_intelligence SET threat_level = 'medium' WHERE threat_source = 'United Nations' AND threat_date < '2022-01-01';",
#  "SELECT * FROM employee_skills WHERE skill_name = 'sustainable_manufacturing' AND experience_years > 2;",
#  'SELECT site_name, SUM(total_artifacts) FROM excavation_sites WHERE year = 2020 GROUP BY site_name;',
#  "SELECT name FROM hospitals WHERE region = 'Northeast' AND patient_capacity = (SELECT MIN(patient_capacity) FROM hospitals WHERE region = 'Northeast');",
#  "INSERT INTO open_pedagogy_resources (resource_name, topic) VALUES ('Critical Thinking in Math Education', 'critical thinking');",
#  'SELECT Department FROM Employees GROUP BY Department HAVING COUNT(*) > 1;',
#  'SELECT HireYear, COUNT(*) OVER (PARTITION BY HireYear ORDER BY HireYear) AS Running_Total FROM Hiring;',
#  'SELECT sector, (SUM(efficiency) / (SELECT SUM(efficiency) FROM energy_efficiency WHERE year = 2015 AND sector = e.sector) * 100.0) - 100.0 AS improvement FROM energy_efficiency e WHERE year = 2020 GROUP BY sector;',
#  "SELECT SUM(capacity) FROM windfarm WHERE country IN ('Germany', 'France');",
#  "INSERT INTO basketball_players (player_id, player_name, position, team, country) VALUES (1, 'Marta Santiago', 'center', 'Spain national team', 'Spain');",
#  "SELECT AVG(item_count) FROM (SELECT item_count, delivery_date FROM items_delivered WHERE country = 'South America' AND QUARTER(delivery_date) = 3 AND YEAR(delivery_date) = 2021 GROUP BY delivery_date) AS avg_items_per_day;",
#  "DELETE FROM accessibility_features WHERE feature_type = 'Voice Command' AND status = 'Discontinued';",
#  'SELECT company, year, COUNT(*) FROM ai_patents GROUP BY company, year;',
#  "UPDATE EthicalAIPractices SET StartDate = '2022-05-01' WHERE Project = 'AI for Children';",
#  "SELECT AVG(project_count) FROM (SELECT COUNT(*) AS project_count FROM digital_divide_projects WHERE country = 'Asia' GROUP BY completion_year) AS subquery;",
#  "SELECT SUM(budget) FROM accessible_tech WHERE sector = 'education';",
#  "SELECT SUM(fare) FROM bus_trips JOIN bus_routes ON bus_trips.route_id = bus_routes.route_id WHERE bus_routes.starting_letter = 'B';",
#  "SELECT Brand_ID, DATEDIFF(day, ISNULL(Last_Usage_Date, '9999-01-01'), '9999-01-01') AS Days_Since_Last_Usage FROM Brand_Sustainable_Material_Last_Usage;",
#  'SELECT region, COUNT(*) FROM labor_practices_violations GROUP BY region;',
#  "SELECT name, SUM(spend) as total_spend FROM african_consumers WHERE country IN ('Nigeria', 'South Africa', 'Egypt') GROUP BY name ORDER BY total_spend DESC LIMIT 1;",
#  'SELECT country, COUNT(*) as sustainable_labor_count FROM ManufacturerLabor WHERE has_sustainable_labor = true GROUP BY country ORDER BY sustainable_labor_count DESC;',
#  "SELECT COUNT(*) FROM sales WHERE size = '2XL' AND date >= DATE_SUB(CURRENT_DATE, INTERVAL 1 MONTH);",
#  "SELECT SUM(amount) FROM donations WHERE donor = 'Aisha' AND YEAR(donation_date) = 2021;",
#  'SELECT COUNT(*) FROM FinancialTransactions INNER JOIN Volunteers ON FinancialTransactions.VolunteerID = Volunteers.VolunteerID;',
#  "UPDATE OrganicProducts SET name = 'Eco-friendly Product2' WHERE id = 2;",
#  "SELECT COUNT(*) FROM Inventory WHERE is_organic = TRUE AND category = 'Fruit';",
#  'SELECT carrier_name, COUNT(*) FROM shipment GROUP BY carrier_name;',
#  'SELECT transportation_mode, COUNT(DISTINCT item_type) FROM shipments GROUP BY transportation_mode;',
#  "SELECT WarehouseID, COUNT(*) as TotalLateDeliveries FROM Shipments WHERE LateDelivery = 1 AND ShippedDate >= DATEADD(month, -1, GETDATE()) AND WarehouseID IN (SELECT WarehouseID FROM Warehouses WHERE Region = 'Americas') GROUP BY WarehouseID HAVING COUNT(*) >= 25;",
#  "SELECT COUNT(*), area_sqm FROM parks WHERE state = 'New York' GROUP BY area_sqm;",
#  "SELECT (COUNT(*) * 100.0 / (SELECT COUNT(*) FROM faculty_members WHERE faculty_department = 'School of Business')) AS percentage FROM faculty_members WHERE faculty_race = 'AAPI';",
#  "SELECT AVG(budget) FROM green_buildings WHERE building_name LIKE '%green%';",
#  "SELECT SUM(capacity) FROM wind_projects WHERE country = 'Germany';",
#  'SELECT city, project_type, SUM(investment_cost) FROM energy_efficient_lighting WHERE investment_cost > 1000000 GROUP BY city, project_type;',
#  "SELECT MAX(number) FROM mental_health_parity_violations WHERE state IN ('South Carolina', 'North Carolina', 'Virginia', 'West Virginia', 'Maryland', 'Delaware', 'District of Columbia');",
#  "SELECT city, COUNT(*) FROM asian_sites WHERE city IN ('Tokyo', 'Seoul') AND type = 'historical' GROUP BY city;",
#  "SELECT country, SUM(num_sessions) as total_sessions FROM virtual_tourism WHERE session_date >= '2023-01-01' AND session_date < '2023-04-01' GROUP BY country ORDER BY total_sessions DESC LIMIT 5;",
#  "SELECT SUM(num_engagements) FROM TourEngagements WHERE city = 'Barcelona' AND rating >= 4.5;",
#  "SELECT Artist.country_of_origin, Artwork.medium, COUNT(Artwork.artwork_id) FROM Artist INNER JOIN Artwork ON Artist.artist_id = Artwork.artist_id WHERE Artwork.genre = 'Expressionism' GROUP BY Artist.country_of_origin, Artwork.medium;",
#  "SELECT COUNT(*) FROM UNESCO_SITES WHERE region = 'Oceania';",
#  "SELECT AVG(age) FROM patients WHERE improvement = 'improved';",
#  "SELECT AVG(patients.age) FROM patients INNER JOIN treatments ON patients.patient_id = treatments.patient_id WHERE treatments.treatment_type = 'Therapy' AND patients.country = 'Canada';",
#  "INSERT INTO design_standards (id, name, version, description) VALUES (4, 'Bridge Design Standards for Earthquake Zones', 2022, 'New standards for bridge design in earthquake zones');",
#  'SELECT MAX(visitors) FROM gcnp_visitors;',
#  "SELECT SUM(revenue) FROM sustainable_tourism WHERE country IN ('New Zealand', 'Canada') AND year = 2022;",
#  'SELECT COUNT(DISTINCT service_type) FROM defendant_services;',
#  "SELECT species, AVG(depth) FROM underwater_species WHERE ocean IN ('Indian', 'Pacific') GROUP BY species;",
#  "UPDATE marine_sites SET max_depth = 3500 WHERE site_name = 'Research Site A';",
#  "SELECT country FROM CountryPollution WHERE pollution_level = (SELECT MAX(pollution_level) FROM CountryPollution WHERE region = 'Atlantic Ocean');",
#  'CREATE TABLE food_waste_tracking (waste_id INT PRIMARY KEY, waste_type VARCHAR(255), quantity INT, location VARCHAR(255));',
#  'SELECT customer_id, COUNT(*) as order_count FROM Orders WHERE order_date >= DATE_SUB(CURRENT_DATE, INTERVAL 30 DAY) GROUP BY customer_id ORDER BY order_count DESC LIMIT 10;',
#  "SELECT MAX(value) FROM contract_values WHERE contractor = 'Northrop Grumman' AND service = 'Geopolitical Risk Assessment';",
#  "SELECT AVG(productivity) FROM labor WHERE department = 'coal';",
#  'SELECT continent, avg_upload_speed, avg_upload_speed/AVG(avg_upload_speed) OVER (PARTITION BY continent) as avg_upload_speed_percentage FROM avg_upload_speed_view;',
#  "SELECT MAX(data_usage) FROM subscribers WHERE region = 'urban';",
#  'SELECT c.name AS country, COUNT(m.id) AS mobile_subscribers, COUNT(b.id) AS broadband_subscribers FROM subscribers s JOIN mobile_plans mp ON s.plan_id = mp.id JOIN broadband_plans bp ON s.plan_id = bp.id JOIN countries c ON s.country = c.name GROUP BY c.name;',
#  'SELECT city, MAX(sales) FROM Concerts;',
#  'SELECT DonorID, AVG(DonationAmount) OVER (PARTITION BY DonorID ORDER BY EXTRACT(MONTH FROM DonationDate)) AS AvgDonationPerMonth FROM DonationAmounts;',
#  "SELECT donor_id, AVG(DATEDIFF('month', MIN(donation_date), MAX(donation_date))) FROM donations GROUP BY donor_id;",
#  'SELECT Programs.ProgramName FROM Programs INNER JOIN ProgramDonations ON Programs.ProgramID = ProgramDonations.ProgramID;',
#  'SELECT c.cause_name, AVG(dam.donation_frequency) FROM philanthropy.causes c JOIN (SELECT cause_id, COUNT(*) AS donation_frequency FROM philanthropy.donation_amount_by_cause GROUP BY cause_id) dam ON c.cause_id = dam.cause_id GROUP BY c.cause_name;',
#  "SELECT MAX(PlaytimeMinutes) FROM CosmicRacersPlayers WHERE Rank IN ('Platinum', 'Gold', 'Diamond');",
#  "SELECT COUNT(DISTINCT PlayerId) FROM GamePlayer GP JOIN Player P ON GP.PlayerId = P.id WHERE GP.GameId = (SELECT G.id FROM Game G WHERE G.name = 'Fantasy') AND P.country = 'Asia';",
#  'SELECT VR_Games.GameName, Designers.DesignerName, Designers.YearsOfExperience FROM VR_Games INNER JOIN VR_GameDesign ON VR_Games.GameID = VR_GameDesign.GameID INNER JOIN Designers ON VR_GameDesign.DesignerID = Designers.DesignerID;',
#  'SELECT country, COUNT(*) as total_analysis FROM satellite_image_analysis WHERE analysis_date >= DATEADD(month, -1, GETDATE()) GROUP BY country ORDER BY total_analysis DESC LIMIT 3;',
#  'SELECT AVG(temperature) FROM Field1_Temperature WHERE EXTRACT(MONTH FROM measurement_time) = 7 AND EXTRACT(YEAR FROM measurement_time) IN (2021, 2022);',
#  'SELECT ct.crop_type, MAX(ct.temperature) AS max_temperature, MAX(ch.humidity) AS max_humidity FROM crop_temperature ct INNER JOIN crop_humidity ch ON ct.crop_type = ch.crop_type WHERE ct.timestamp >= DATEADD(month, -1, CURRENT_TIMESTAMP) GROUP BY ct.crop_type;',
#  "SELECT SUM(count) FROM Deliveries WHERE quarter = 2 AND region = 'North';",
#  "SELECT MIN(amount) FROM Budget WHERE department = 'Education' AND year = 2022;",
#  'SELECT element, MIN(quantity) FROM production WHERE year = 2019 GROUP BY element;',
#  "SELECT co_owners.name, properties.address FROM co_owners INNER JOIN properties ON co_owners.property_id = properties.id WHERE co_owners.city IN ('Portland', 'Seattle');",
#  "SELECT COUNT(*) FROM carbon_offset_programs WHERE program_location LIKE 'Asia%' AND program_start_date >= '2020-01-01' AND program_start_date < '2021-01-01';",
#  "SELECT AVG(rating) FROM projects WHERE location = 'Germany';",
#  "SELECT project_name FROM renewable_projects WHERE location IN ('US', 'Canada');",
#  'SELECT menu_item_id, SUM(quantity_sold) as total_quantity_sold FROM MenuSales WHERE sale_date >= DATEADD(month, -1, GETDATE()) GROUP BY menu_item_id ORDER BY total_quantity_sold ASC;',
#  "SELECT source, type, COUNT(*) as debris_count, AVG(DATEDIFF('year', launch_date, '2022-01-01')) as avg_years_in_orbit FROM space_debris GROUP BY source, type;",
#  "SELECT COUNT(*) FROM SpaceMissions WHERE end_date < '2010-01-01' AND status = 'Success';",
#  "SELECT SUM(Mass) FROM Spacecraft WHERE Manufacturer = 'SpaceX';",
#  'SELECT gender, COUNT(*) FROM fan_demographics GROUP BY gender;',
#  'SELECT COUNT(*) FROM security_incidents si JOIN users u ON si.user_id = u.user_id WHERE incident_date >= DATEADD(year, -1, GETDATE()) AND u.department_size > 50;',
#  "SELECT AVG(speed) FROM taxi_speeds WHERE taxi_type = 'Autonomous' AND city = 'New York' AND date >= DATEADD(day, -7, CURRENT_DATE);",
#  "SELECT SUM(claim_amount) FROM claims WHERE policyholder_state IN ('Utah', 'Idaho');",
#  "SELECT Underwriters.UnderwriterID, SUM(Claims.Amount) AS TotalClaimAmount FROM Underwriters INNER JOIN Claims ON Underwriters.UnderwriterID = Claims.UnderwriterID WHERE Underwriters.Region = 'Midwest' GROUP BY Underwriters.UnderwriterID ORDER BY TotalClaimAmount DESC LIMIT 3;",
#  'SELECT w.region, (COUNT(CASE WHEN i.injury_count = 0 THEN 1 END) / COUNT(w.id)) * 100 AS pct_no_injuries FROM workplaces w LEFT JOIN injuries i ON w.id = i.workplace_id GROUP BY w.region;',
#  'DELETE FROM VehicleSafetyTesting WHERE release_year < 2010;',
#  "SELECT AVG(speed) FROM vessels WHERE port_id IN (SELECT id FROM ports WHERE country = 'USA' AND name IN ('New York', 'Savannah', 'Norfolk')) AND EXTRACT(MONTH FROM arrival_date) = 7;",
#  'SELECT vessel_id, SUM(amount) FROM regulatory_compliance GROUP BY vessel_id;',
#  "SELECT country, AVG(recycling_rate) FROM RecyclingRatesOceania WHERE year = 2021 AND country IN ('Australia', 'New Zealand') GROUP BY country;",
#  'SELECT researcher_name FROM safety_research ORDER BY contributions DESC LIMIT 3;',
#  "SELECT SUM(cost) FROM infrastructure_projects WHERE country = 'India' AND completion_year IN (2021, 2022);",
#  "SELECT community_type, SUM(investment) FROM rural_infrastructure_projects WHERE country = 'United States' AND community_type = 'Latinx' GROUP BY community_type;",
#  "SELECT project, budget FROM (SELECT project, budget, ROW_NUMBER() OVER (ORDER BY budget DESC) as rn FROM innovation_projects WHERE country = 'Indonesia') t WHERE rn <= 5;",
#  'SELECT farm_id, SUM(weight) OVER (PARTITION BY farm_id ORDER BY date) biomass FROM FishBiomass WHERE farm_id = 2;',
#  'SELECT MAX(donation_amount) FROM dance_sponsors;',
#  "SELECT AVG(DonationAmount) FROM Donors WHERE DonationDate BETWEEN '2021-04-01' AND '2021-06-30' AND DonorID NOT IN (SELECT DonorID FROM Donors GROUP BY DonorID HAVING COUNT(*) > 1);",
#  "SELECT SUM(cost) FROM Projects WHERE state = 'Texas' AND is_sustainable = true AND project_date BETWEEN '2022-04-01' AND '2022-06-30';",
#  "SELECT COUNT(*) FROM cases WHERE attorney = 'Rodriguez' AND state = 'Texas' AND outcome = 'won' AND YEAR(date) = 2020;",
#  "DELETE FROM waste_production WHERE region = 'Antarctica' AND EXTRACT(MONTH FROM date) = 1 AND EXTRACT(YEAR FROM date) = 2022;",
#  "SELECT AVG(emissions) FROM factories WHERE location = 'California';",
#  'SELECT Protocol FROM Plant_A_Safety_Protocols EXCEPT (SELECT Protocol FROM Plant_B_Safety_Protocols INTERSECT SELECT Protocol FROM Plant_C_Safety_Protocols) EXCEPT (SELECT Protocol FROM Plant_C_Safety_Protocols EXCEPT SELECT Protocol FROM Plant_B_Safety_Protocols INTERSECT SELECT Protocol FROM Plant_A_Safety_Protocols);',
#  "SELECT finance_type, SUM(amount) FROM climate_finance WHERE project_location = 'Africa' AND finance_year BETWEEN 2015 AND 2020 GROUP BY finance_type;",
#  'SELECT city FROM Finance WHERE avg_temp > (SELECT avg_temp FROM Mitigation WHERE city = Finance.city);',
#  "SELECT AVG(LifeExpectancy) FROM Countries WHERE Continent = 'Africa';",
#  "INSERT INTO student_disability (id, student_name, disability_type, accommodation_provided) VALUES (3, 'Bob Johnson', 'Mobility Impairment', 'Jumping Jacket');",
#  "UPDATE climate_change SET avg_temp_celsius = avg_temp_celsius - 5 WHERE region = 'Arctic Ocean';",
#  "SELECT * FROM transactions WHERE user_address = '0x456...';",
#  "SELECT name FROM regulatory_frameworks WHERE country_id = (SELECT id FROM countries WHERE name = 'Country1');",
#  "SELECT 'Total Organic' AS metric, COUNT(*) AS count FROM products_organic WHERE organic = true UNION ALL SELECT 'Total Non-Organic' AS metric, COUNT(*) AS count FROM products_organic WHERE organic = false;",
#  "SELECT AVG(price) FROM cosmetics WHERE is_vegan = TRUE AND country = 'US';",
#  'SELECT (COUNT(*) * 100.0 / (SELECT COUNT(*) FROM lipsticks)) AS percentage FROM lipsticks WHERE is_vegan = TRUE AND is_gluten_free = TRUE;',
#  "SELECT (COUNT(*) * 100.0 / (SELECT COUNT(*) FROM haircare_sales WHERE country = 'France' AND sale_date BETWEEN '2021-07-01' AND '2021-09-30' AND is_sustainable = true)) AS percentage FROM haircare_sales WHERE country = 'France' AND sale_date BETWEEN '2021-07-01' AND '2021-09-30' AND is_sustainable = true;",
#  'SELECT b.brand_name, MAX(p.rating) as max_rating FROM brands b JOIN products p ON b.brand_id = p.brand_id WHERE p.is_cruelty_free = TRUE GROUP BY b.brand_name;',
#  'SELECT name, AVG(crime_count/population) FROM neighborhoods GROUP BY name;',
#  'SELECT cd.community_name, ct.crime_type, AVG(cd.response_time) as avg_response_time FROM community_districts cd JOIN crime_data cd ON cd.cd_number = cd.cd_number JOIN (SELECT crime_type, cd_number, COUNT(*) as count FROM crime_data WHERE crime_date >= CURDATE() - INTERVAL 1 MONTH GROUP BY crime_type, cd_number ORDER BY count DESC LIMIT 5) ct ON cd.cd_number = ct.cd_number GROUP BY cd.community_name, ct.crime_type;',
#  "SELECT maintenance_cost(maintenance_cost) FROM equipment_maintenance WHERE equipment_type = 'Type A' AND maintenance_date BETWEEN '2022-01-01' AND '2022-12-31' INTERSECT SELECT maintenance_cost(maintenance_cost) FROM equipment_maintenance WHERE equipment_type = 'Type B' AND maintenance_date BETWEEN '2022-01-01' AND '2022-12-31';",
#  "SELECT event FROM defense_diplomacy WHERE country1 = 'China' AND country2 = 'India' AND year BETWEEN 2005 AND 2010;",
#  "SELECT SUM(capacity) FROM vessels WHERE registry = 'Hong Kong';",
#  "SELECT name FROM suppliers WHERE country = 'Germany';",
#  "SELECT tech_name, capabilities FROM military_tech WHERE region = 'North America';",
#  "DELETE FROM music_genres WHERE genre = 'Hip-Hop' AND YEAR(event_date) = 2019;",
#  "SELECT AVG(song_length) FROM songs JOIN artists ON songs.artist_id = artists.artist_id WHERE artists.country = 'United States';",
#  'SELECT COUNT(*) FROM (SELECT DonorID FROM Donations WHERE Amount > 100 GROUP BY DonorID HAVING COUNT(*) > 1);',
#  "SELECT AVG(DonationAmount) FROM Donations WHERE DonorName LIKE 'S%';",
#  "SELECT AVG(donation_amount) FROM Donations d JOIN Donors don ON d.donor_id = don.donor_id WHERE program_id IN (SELECT program_id FROM Programs WHERE category = 'health') AND YEAR(donation_date) = 2022 AND QUARTER(donation_date) = 2 AND donor_id NOT IN (SELECT donor_id FROM Donors WHERE last_donation_date < donation_date);",
#  'SELECT student_id, course_id, COUNT(course_id) OVER (PARTITION BY student_id ORDER BY completion_date) as completed_courses FROM lifelong_learning WHERE student_id = 2;',
#  'SELECT Name FROM TopTeachers;',
#  'SELECT district_id, AVG(mental_health_score) as avg_mental_health FROM student_mental_health GROUP BY district_id ORDER BY avg_mental_health DESC;',
#  'SELECT SUM(Salary) FROM Employees;',
#  "INSERT INTO energy_storage (id, region, year, capacity) VALUES (1, 'Sao Paulo', 2027, 9000);",
#  "SELECT SUM(generation) FROM energy_generation WHERE country IN ('Kenya', 'Nigeria', 'South Africa') AND source_type IN ('Solar', 'Wind') AND generation_date BETWEEN '2021-01-01' AND '2021-03-31';",
#  "SELECT COUNT(*) FROM wells WHERE region IN ('Permian Basin', 'Marcellus Shale') AND well_type = 'Gas' AND status = 'Producing';",
#  'SELECT t.team_name, (SUM(g.won) * 100.0 / (SELECT COUNT(*) FROM games WHERE team_id = t.team_id AND season_id = (SELECT MAX(season_id) FROM teams))) AS win_percentage FROM teams t JOIN games g ON t.team_id = g.team_id WHERE t.season_id = (SELECT MAX(season_id) FROM teams) GROUP BY t.team_name ORDER BY win_percentage DESC LIMIT 1;',
#  'SELECT name, home_runs FROM baseball_stats ORDER BY home_runs DESC LIMIT 1;',
#  "SELECT SUM(amount) FROM Funding INNER JOIN Organization ON Funding.organization_id = Organization.id WHERE Organization.country = 'India';",
#  'SELECT MAX(fare) FROM urban.trams WHERE fare >= 2;',
#  "SELECT SUM(revenue) FROM routes WHERE route_name = 'Red Line';",
#  "SELECT AVG(delivery_time) FROM orders WHERE country = 'Italy' AND eco_friendly = TRUE;",
#  "SELECT SUM(income) AS total_income, SUM(expenses) AS total_expenses FROM FinancialWellbeingPrograms WHERE country = 'Australia';",
#  "SELECT donor_age_group, SUM(donation_amount) FROM (SELECT CASE WHEN donor_age < 30 THEN 'Minor' WHEN donor_age BETWEEN 30 AND 60 THEN 'Regular' ELSE 'Senior' END AS donor_age_group, donation_amount FROM donors WHERE EXTRACT(YEAR FROM donation_date) = 2021) GROUP BY donor_age_group;",
#  "SELECT AVG(weight) FROM packages WHERE shipped_date >= DATE_SUB(CURRENT_DATE, INTERVAL 1 YEAR) AND region = 'Africa';",
#  "SELECT SUM(weight) FROM parcels JOIN shipments ON parcels.shipment_id = shipments.id WHERE source_airport = 'FRA' AND destination_airport = 'ICN' AND shipped_date BETWEEN '2022-03-01' AND '2022-03-31';",
#  "DELETE FROM genetic_research_experiments WHERE experiment_date < '2010-01-01';",
#  "SELECT name FROM projects WHERE location = 'Spain' AND biosensor_used = true;",
#  "UPDATE programs SET budget = 30000000 WHERE id = 1 AND state = 'Florida';",
#  'SELECT committee_name FROM committees WHERE members < 5 ORDER BY members ASC;',
#  "SELECT MAX(salary) FROM faculty WHERE department='Physics' AND rank='Professor';",
#  "SELECT Region, (CommunityHealthWorkerCount / MentalHealthProfessionalCount) AS Ratio FROM (SELECT Region, COUNT(*) AS CommunityHealthWorkerCount, (SELECT COUNT(*) FROM HealthWorkers WHERE WorkerType = 'MentalHealthProfessional' AND Region = HealthWorkers.Region) AS MentalHealthProfessionalCount FROM HealthWorkers WHERE WorkerType = 'CommunityHealthWorker' GROUP BY Region);",
#  "SELECT COUNT(*) FROM MentalHealthParity WHERE Region = 'Southwest' AND YEAR(ReportDate) = 2020;",
#  "SELECT SUM(bookings) FROM accommodations WHERE city = 'Barcelona' AND is_eco_friendly = true;",
#  "SELECT AVG(bookings) FROM ai_bookings WHERE quarter = 'Q2 2022' AND region = 'North America';",
#  "SELECT s.name FROM researcher_species rs JOIN researchers r ON r.id = rs.researcher_id JOIN species s ON s.id = rs.species_id WHERE r.name = 'Agnes Sorensen';",
#  "SELECT COUNT(*) FROM Green_Infrastructure WHERE location = 'Park';",
#  'SELECT city, AVG(price) FROM Hotels_Europe GROUP BY city;',
#  'SELECT project_name FROM marine_research_projects;',
#  "SELECT MIN(min_depth) FROM coral_species WHERE region = 'Caribbean';",
#  "SELECT 100.0 * COUNT(*) / (SELECT COUNT(*) FROM videos WHERE topic = 'disinformation detection') as percentage FROM videos WHERE topic = 'disinformation detection' AND creator_type = 'independent';",
#  "SELECT (COUNT(*) * 100.0 / (SELECT COUNT(*) FROM Employees)) AS Percentage FROM Employees WHERE Gender = 'Female' AND Position = 'Manager';",
#  "SELECT * FROM network_towers WHERE city = 'Los Angeles' AND latitude BETWEEN -118.4 AND -118.3;",
#  "SELECT AVG(word_count) FROM (SELECT a.id, COUNT(w.word) AS word_count FROM articles a INNER JOIN words w ON a.id = w.article_id WHERE a.newspaper = 'The Wall Street Journal' AND a.category = 'Business' GROUP BY a.id) t;",
#  "SELECT MIN(conservation_score) FROM marine_protected_areas WHERE region = 'Mediterranean';",
#  "SELECT COUNT(*) FROM deep_sea_exploration WHERE ocean = 'Southern Ocean';",
#  'SELECT region, COUNT(*) FROM marine_species GROUP BY region;',
#  "DELETE FROM esports_teams WHERE region = 'Asia';",
#  "SELECT MIN(PlayerLevel) FROM Players WHERE Game = 'CS:GO';",
#  "SELECT SUM(fine_amount) FROM fines WHERE fine_city = 'Houston' AND YEAR(fine_date) = 2019;",
#  "SELECT DISTINCT producer FROM production WHERE element = 'Gadolinium' ORDER BY producer;",
#  'SELECT City FROM AffordableHousing WHERE OccupancyRate < 0.8;',
#  'SELECT person.name FROM person INNER JOIN property ON person.id = property.owner_id WHERE price > (SELECT AVG(price) FROM property);',
#  'SELECT country, (SUM(consumption) FILTER (WHERE year BETWEEN 2018 AND 2022) OVER (PARTITION BY country)::DECIMAL / SUM(consumption) OVER (PARTITION BY country)) * 100 AS pct_renewable FROM SEA_Renewable_Energy;',
#  "SELECT country, SUM(product_quantity) AS total_sales FROM sales JOIN ethical_brands ON sales.brand_id = ethical_brands.brand_id WHERE ethical_brands.product_category = 'Clothing' GROUP BY country ORDER BY total_sales DESC, country;",
#  'SELECT MAX(distance) FROM astrophysics_research;',
#  "SELECT MIN(age) FROM athletes WHERE community = 'LGBTQ+';",
#  'SELECT cve_id, COUNT(*) as vulnerability_count, RANK() OVER (ORDER BY vulnerability_count DESC) as vulnerability_rank FROM Vulnerabilities WHERE timestamp >= DATE_SUB(CURRENT_TIMESTAMP, INTERVAL 1 MONTH) GROUP BY cve_id ORDER BY vulnerability_rank;',
#  "SELECT org_id, AVG(DATEDIFF(vuln_remediation_date, vuln_report_date)) as avg_time_to_remediate FROM vulnerabilities WHERE vuln_severity = 'high' GROUP BY org_id;",
#  "SELECT * FROM user_accounts WHERE region = 'Europe' AND account_created >= DATE_SUB(CURRENT_DATE, INTERVAL 1 WEEK);",
#  'SELECT COUNT(*) FROM Autonomous_Vehicles WHERE year IN (2021, 2022) AND average_speed > 40;',
#  "SELECT AVG(occupancy_rate) FROM public_transportation_occupancy WHERE city = 'Seoul';",
#  "SELECT DATE(start_time) AS day, COUNT(*) AS usage FROM london_bikes WHERE city = 'London' GROUP BY day;",
#  "DELETE FROM Policy WHERE PolicyID NOT IN (SELECT PolicyID FROM Claims WHERE PolicyID = Policy.PolicyID AND ClaimDate > DATEADD(month, -24, GETDATE()) AND PolicyType = 'Renters');",
#  'SELECT COUNT(*) FROM technology_unions WHERE salary > 80000.00;',
#  "SELECT current_capacity FROM landfill_capacity WHERE region = 'North America';",
#  "SELECT country, MIN(landfill_capacity) FROM LandfillCapacity WHERE region = 'European Union' GROUP BY country;",
#  'SELECT city, (SUM(waste) / population) * 100000 FROM WasteGeneration GROUP BY city;',
#  "SELECT COUNT(*) FROM drought_impact WHERE (year = 2019 OR year = 2020) AND impact_level != 'none';",
#  'SELECT DISTINCT region, initiative_name FROM conservation_initiatives;',
#  'SELECT MIN(Duration), Gender FROM Workout INNER JOIN Member ON Workout.MemberID = Member.MemberID WHERE YEAR(MembershipStart) = 2019 GROUP BY Gender;',
#  'SELECT MONTH(JoinDate) AS Month, Gender, COUNT(*) AS NumberOfMembers FROM Members GROUP BY Month, Gender;',
#  'SELECT workout_type, SUM(fee) FROM workout_fees GROUP BY workout_type;',
#  'SELECT airline, COUNT(*) FROM FlightOperations WHERE operated_date >= DATEADD(month, -1, GETDATE()) GROUP BY airline;',
#  'SELECT country, COUNT(*) FROM aerospace.satellites GROUP BY country;',
#  'SELECT sanctuary_name, SUM(animal_count) AS total_animals FROM animal_sanctuary GROUP BY sanctuary_name ORDER BY total_animals DESC;',
#  "SELECT SUM(quantity) FROM seafood_exports_v2 WHERE export_country = 'US' AND import_country = 'China' AND EXTRACT(YEAR FROM export_date) = 2020 AND unit_type = 'ton';",
#  "INSERT INTO audience (visitor_id, name, country, visit_date) VALUES ((SELECT MAX(visitor_id) FROM audience) + 1, 'Alex', 'USA', CURRENT_DATE);",
#  "SELECT AVG(project_timeline_weeks) FROM Projects WHERE area_type = 'urban';",
#  "INSERT INTO cannabis_production (strain, yield) VALUES ('Gelato', 500);",
#  'SELECT plants.plant_name FROM plants INNER JOIN emissions ON plants.plant_id = emissions.plant_id WHERE emissions.emission_level > (SELECT MAX(emission_limit) FROM allowed_emissions) AND emissions.emission_date >= DATEADD(year, -1, GETDATE());',
#  "SELECT Percentage FROM Health_Insurance WHERE Country = 'United States';",
#  "SELECT COUNT(*) FROM startups WHERE industry = 'Transportation' AND founder_community = 'Underrepresented';",
#  "SELECT name FROM smart_contracts WHERE developer_country IN ('Germany', 'France', 'USA');",
#  "SELECT asset_name, trading_volume FROM digital_assets WHERE region = 'Europe' ORDER BY trading_volume DESC LIMIT 5;",
#  'SELECT digital_asset, SUM(transaction_count) as total_transactions, SUM(trading_volume) as total_volume FROM decentralized_exchanges GROUP BY digital_asset;',
#  "INSERT INTO timber_production (region, year, volume) VALUES ('Southeast', 2018, 1200), ('Southeast', 2019, 1500), ('Southeast', 2020, 1800);",
#  'SELECT * FROM forest_management WHERE age > 50;',
#  "SELECT * FROM cosmetics INNER JOIN ingredient_sourcing ON cosmetics.product_id = ingredient_sourcing.ingredient_id WHERE cosmetics.product_type = 'Foundation' AND ingredient_sourcing.sourcing_country != 'USA';",
#  'SELECT i.name FROM ingredients i JOIN country_biodiversity cb ON i.sourcing_country = cb.country WHERE cb.biodiversity_index > 80;',
#  "SELECT AVG(threat_score) FROM threat_intelligence WHERE threat_region = 'Pacific' AND threat_date >= DATEADD(month, -1, GETDATE());",
#  'SELECT contractor, COUNT(*) as contract_count FROM contract_timeline WHERE contract_date >= DATEADD(month, -12, CURRENT_DATE) GROUP BY contractor ORDER BY contract_count DESC;',
#  "SELECT SUM(amount) FROM defense_spending WHERE continent = 'Oceania' AND year = 2018;",
#  'SELECT customer_id, AVG(amount) as avg_daily_amount FROM transactions WHERE transaction_date >= DATEADD(quarter, -1, GETDATE()) GROUP BY customer_id;',
#  'SELECT COUNT(DISTINCT destination) FROM cargo_handling WHERE cargo_id IN (SELECT cargo_id FROM regulatory_compliance);',
#  "SELECT COUNT(*) FROM factories WHERE industry = 'pharmaceutical' AND region = 'South America' AND ethical_manufacturing = TRUE;",
#  'SELECT factories.factory_id, AVG(factories.total_salary) FROM factories INNER JOIN workforce_development ON factories.factory_id = workforce_development.factory_id GROUP BY factories.factory_id;',
#  "SELECT SUM(waste_generated) FROM waste WHERE industry = 'electronics' AND region = 'Africa';",
#  'DELETE FROM ExcavationSite WHERE NumArtifacts < 10;',
#  "UPDATE hospitals SET address = '456 Elm St' WHERE id = 123;",
#  'SELECT SUM(healthcare_expenditure) FROM rural_counties WHERE state IN (SELECT state FROM rural_counties WHERE healthcare_expenditure IS NOT NULL GROUP BY state HAVING COUNT(*) > 5);',
#  "SELECT * FROM investments WHERE sector = 'renewable_energy' ORDER BY risk_score;",
#  'SELECT * FROM military_tech WHERE YEAR(tech_date) = 2020;',
#  "SELECT album, SUM(streams) AS total_streams FROM AlbumStreaming WHERE genre = 'jazz' GROUP BY album ORDER BY total_streams DESC LIMIT 5;",
#  'SELECT DonorID, SUM(DonationAmount) as TotalDonation FROM Donations WHERE DonationDate >= DATEADD(day, -30, GETDATE()) GROUP BY DonorID ORDER BY TotalDonation DESC FETCH FIRST 5 ROWS ONLY;',
#  'SELECT program_id, MAX(amount) FROM donations GROUP BY program_id;',
#  "SELECT SUM(D.Amount) as TotalDonation FROM Donations D WHERE D.ProgramID = (SELECT P.ProgramID FROM Programs P WHERE P.Name = 'Education');",
#  "CREATE VIEW TopTeachers AS SELECT Name, Subject FROM Teachers WHERE Subject = 'Science';",
#  'DELETE FROM Employees WHERE Salary > 80000.00;',
#  "SELECT DISTINCT country FROM oil_rigs WHERE status = 'active';",
#  'SELECT stadium_name, capacity FROM stadiums WHERE capacity > 70000;',
#  "SELECT player_name, MAX(assists) FROM players WHERE team_name = 'Heat' AND season_start_year = 2017 AND season_end_year = 2018;",
#  'SELECT e.name, e.country FROM social_enterprises e JOIN grants g ON e.id = g.social_enterprises_id WHERE g.grant_date >= DATE_SUB(CURRENT_DATE, INTERVAL 3 YEAR);',
#  "SELECT DISTINCT city FROM conferences c JOIN ethical_ai_topics t ON c.id = t.conference_id WHERE t.title LIKE '%ethical AI%';",
#  "SELECT EXTRACT(MONTH FROM first_order_date) AS month, COUNT(*) FILTER (WHERE EXTRACT(MONTH FROM first_order_date) = EXTRACT(MONTH FROM last_order_date)) AS new_customers, COUNT(*) FILTER (WHERE EXTRACT(MONTH FROM first_order_date) <> EXTRACT(MONTH FROM last_order_date)) AS returning_customers FROM customer WHERE first_order_date >= '2021-01-01' AND last_order_date <= '2021-12-31' GROUP BY month;",
#  'SELECT continent, COUNT(*) * 100.0 / (SELECT COUNT(*) FROM factories) as percentage FROM factories WHERE uses_renewable_energy = TRUE GROUP BY continent;',
#  "SELECT c.name, COUNT(up.post_id) as posts_about_topic FROM user_posts up JOIN categories c ON up.category_id = c.id WHERE c.name LIKE '%environmental conservation%' GROUP BY up.category_id ORDER BY posts_about_topic DESC LIMIT 3;",
#  "SELECT AVG(amount) FROM shariah_compliant_loans WHERE region IN ('Middle East', 'Africa');",
#  "SELECT COUNT(*) FROM financial_institutions WHERE country IN ('UAE', 'Egypt') AND is_shariah_compliant = true;",
#  'SELECT name, manager FROM programs WHERE budget > 50000.00;',
#  'SELECT City, SUM(DonationAmount) FROM Donations WHERE DonationDate >= DATEADD(month, -6, GETDATE()) GROUP BY City;',
#  'SELECT MAX(quantity) FROM DELIVERY_RECORDS WHERE is_organic = true;',
#  'SELECT department, SUM(amount) FROM funding WHERE year = 2021 GROUP BY department;',
#  'UPDATE mental_health_diagnosis M SET training_completion_date = (SELECT training_date FROM cultural_competency_training C WHERE C.patient_id = M.patient_id LIMIT 1);',
#  'SELECT AVG(revenue) FROM revenues WHERE is_sustainable = true;',
#  "SELECT year, SUM(emissions) FROM CO2Emissions WHERE country = 'Canada' GROUP BY year;",
#  'SELECT name, language FROM heritage_sites;',
#  "INSERT INTO patients (id, name, age, gender) VALUES (1, 'Dr. Rajesh Patel', 55, 'Male');",
#  "SELECT COUNT(DISTINCT patient_id) FROM treatments WHERE country = 'Spain' AND YEAR(treatment_date) = 2020;",
#  "SELECT name FROM dam WHERE province = 'Quebec' AND max_exceeded = 1;",
#  "SELECT COUNT(*) FROM attractions WHERE country = 'Japan' AND wheelchair_accessibility > 4;",
#  'SELECT District, COUNT(*) FROM ADRPrograms WHERE YearEstablished BETWEEN 2010 AND 2020 GROUP BY District;',
#  "SELECT MAX(speed_limit) FROM maritime_laws WHERE region = 'Bering Sea';",
#  'SELECT MAX(max_depth) FROM ocean_floor_mapping;',
#  "SELECT COUNT(*) FROM maritime_law_compliance WHERE region = 'Caribbean' AND compliant = FALSE;",
#  "SELECT COUNT(*) FROM Pollution_Incidents WHERE location = 'Atlantic Ocean' AND year >= 2010;",
#  "SELECT SUM(CASE WHEN character_gender = 'female' THEN lines ELSE 0 END) + SUM(CASE WHEN character_gender = 'male' THEN lines ELSE 0 END) FROM lines;",
#  "SELECT project_name FROM DefenseProjects WHERE end_date < '2021-01-01';",
#  'SELECT location, COUNT(*) FROM mining_sites WHERE extraction_rate > (SELECT AVG(extraction_rate) FROM mining_sites) GROUP BY location;',
#  "UPDATE MiningEmployees SET EmployeeCount = 350 WHERE State = 'California' AND EmployeeEthnicity = 'Native Hawaiian or Pacific Islander';",
#  'SELECT province, MAX(num_employees) AS max_employees, MIN(num_employees) AS min_employees FROM mining_operations GROUP BY province;',
#  'SELECT i.tech_type, COUNT(s.id) as total_subscribers FROM subscribers s INNER JOIN infrastructure i ON s.technology = i.tech_type GROUP BY i.tech_type;',
#  'SELECT region, AVG(data_usage) FROM mobile_subscribers GROUP BY region;',
#  "SELECT o.operator_name, DATE_FORMAT(u.usage_date, '%Y-%m') as month, AVG(u.usage_amount) FROM mobile_plans p JOIN mobile_operators o ON p.operator_id = o.operator_id JOIN usage u ON p.plan_id = u.plan_id GROUP BY o.operator_name, month;",
#  'SELECT monthly_spending FROM broadband_customers WHERE customer_id = 1;',
#  "SELECT SUM(US.StreamCount) FROM UserStreams US JOIN Songs S ON US.SongID = S.SongID JOIN UserLocation UL ON US.UserID = UL.UserID WHERE S.Genre = 'Afrobeats' AND UL.Country = 'Nigeria' AND QUARTER(US.StreamDate) = 1 AND YEAR(US.StreamDate) = 2022;",
#  "INSERT INTO volunteers (id, organization_id, name) VALUES (1, (SELECT id FROM organizations WHERE name = 'Doctors Without Borders'), 'Fatima Ahmed'), (2, (SELECT id FROM organizations WHERE name = 'Doctors Without Borders'), 'Sophia Lee'), (3, (SELECT id FROM organizations WHERE name = 'Doctors Without Borders'), 'Hassan Patel');",
#  'SELECT name FROM oceans WHERE underwater_volcanoes = (SELECT MAX(underwater_volcanoes) FROM oceans);',
#  "SELECT SUM(Playtime) FROM PlayerJoinDates WHERE GameName = 'Cryptic Explorers' AND JoinDate <= '2022-12-31';",
#  'SELECT f.name, AVG(sm.level) FROM field f INNER JOIN soil_moisture sm ON f.id = sm.field_id WHERE sm.measurement >= DATEADD(week, -1, GETDATE()) GROUP BY f.name;',
#  'SELECT MIN(temperature) FROM Greenhouse7 WHERE EXTRACT(MONTH FROM date) = 9;',
#  "SELECT COUNT(*) FROM lutetium_transactions WHERE element = 'Lutetium' AND price > 70 AND country IN (SELECT DISTINCT country FROM lutetium_transactions WHERE country LIKE 'E%');",
#  'SELECT r.name, AVG(m.carbon_footprint) FROM regions r JOIN manufacturers m ON r.id = m.region_id GROUP BY r.id;',
#  "SELECT MIN(Price) FROM Products JOIN Stores ON Products.StoreID = Stores.StoreID WHERE Category = 'Grocery' AND Country = 'USA' AND State = 'New York';",
#  "SELECT SUM(quantity) FROM sales WHERE business_size = 'small';",
#  'SELECT COUNT(DISTINCT country) FROM space_agencies;',
#  "SELECT mission_name, launch_date FROM missions WHERE country = 'Russia';",
#  'SELECT country, COUNT(*) FROM SpaceMissions GROUP BY country;',
#  "SELECT COUNT(*) FROM Missions WHERE agency = 'NASA';",
#  'INSERT INTO fans (fan_id, age, gender, country) SELECT fan_id, age, gender, country FROM new_fans;',
#  'SELECT team_id, total_sales FROM (SELECT team_id, SUM(total_sales) AS total_sales FROM team_performance WHERE home_game = true AND total_sales > 0 GROUP BY team_id) AS high_sales JOIN (SELECT team_id, SUM(total_sales) AS total_sales FROM team_performance WHERE home_game = true AND total_sales < 0 GROUP BY team_id) AS low_sales ON high_sales.team_id = low_sales.team_id ORDER BY total_sales DESC, high_sales.team_id;',
#  "SELECT COUNT(*) FROM security_incidents WHERE incident_date >= '2022-01-01' AND incident_date < '2023-01-01';",
#  "SELECT PolicyType, COUNT(*) as PoliciesSold FROM Policies WHERE SaleDate BETWEEN '2022-01-01' AND '2022-03-31' GROUP BY PolicyType;",
#  "SELECT sector, SUM(violations) as total_violations FROM union_construction WHERE sector = 'Construction' GROUP BY sector ORDER BY total_violations DESC;",
#  "SELECT city, (electric_vehicle_adoption_rate * 100) AS adoption_rate FROM City_Data WHERE state = 'California';",
#  "SELECT AVG(generation_rate) FROM WasteGeneration WHERE region = 'EMEA';",
#  "SELECT capacity FROM landfill_capacity WHERE region = 'East' AND year = 2020;",
#  'SELECT ((consumption_2018 - consumption_2017) / consumption_2017) * 100.0 FROM (SELECT consumption FROM WaterConsumptionYearly_Lima WHERE year = 2017 AND id = 1) AS t1, (SELECT consumption FROM WaterConsumptionYearly_Lima WHERE year = 2018 AND id = 1) AS t2;',
#  "DELETE FROM wearable_device WHERE name = 'Grace Wilson';",
#  "SELECT COUNT(*) FROM memberships WHERE join_date BETWEEN '2023-01-01' AND '2023-03-31';",
#  'SELECT * FROM members WHERE QUARTER(join_date) = 1 AND YEAR(join_date) = 2021;',
#  "SELECT DISTINCT m.MemberID FROM Members m WHERE m.MembershipType = 'Platinum' AND m.MemberID NOT IN (SELECT MemberID FROM Classes WHERE MONTH(ClassDate) = 1 AND YEAR(ClassDate) = 2021);",
#  "SELECT SUM(distance) FROM wearables WHERE device_brand = 'XYZ';",
#  'SELECT organization_name, COUNT(*) as incident_count FROM ai_safety GROUP BY organization_name ORDER BY incident_count DESC;',
#  'SELECT AVG(habitat_size) FROM animal_habitat;',
#  'SELECT species, SUM(deaths) FROM fish_health GROUP BY species HAVING SUM(deaths) > (SELECT AVG(deaths) FROM fish_health);',
#  'SELECT location, SUM(num_fish) FROM fish_stock GROUP BY location UNION ALL SELECT location, SUM(num_fish) FROM sustainable_seafood GROUP BY location;',
#  'SELECT e.exhibition_name, f.source_name, ef.amount FROM art_exhibitions e INNER JOIN exhibition_funding ef ON e.exhibition_id = ef.exhibition_id INNER JOIN funding_sources f ON ef.source_id = f.source_id;',
#  "SELECT CASE WHEN age < 30 THEN 'Under 30' ELSE '30 and over' END as age_group, COUNT(*) as user_count FROM SPOTIFY_USERS WHERE premium = true GROUP BY age_group;",
#  "SELECT country, SUM(count) FROM country_movies WHERE genre IN ('action', 'comedy') GROUP BY country ORDER BY SUM(count) DESC;",
#  "SELECT DATE_FORMAT(violation_date, '%Y-%m') as quarter, COUNT(*) as num_violations FROM compliance_violations WHERE YEAR(violation_date) = 2021 GROUP BY quarter;",
#  "SELECT campaign_name, budget FROM climate_communication_campaigns WHERE region = 'Asia' AND budget > 1000000.00 AND focus = 'Mitigation';",
#  "SELECT MAX(Amount) FROM ClimateAid WHERE Community IN (SELECT DISTINCT Community FROM ClimateAid WHERE Country = 'Amazon');",
#  'SELECT a.name, COUNT(m.id) FROM australia_territories a INNER JOIN mental_health_clinics m ON a.id = m.territory_id GROUP BY a.name;',
#  "SELECT founding_year, AVG(employee_count) FROM Company_Info WHERE industry = 'Technology' GROUP BY founding_year';",
#  "SELECT SUM(funding.amount) FROM funding JOIN founders ON funding.company_id = founders.company_id WHERE founders.gender = 'female';",
#  'SELECT region, size, COUNT(*) FROM farm_sizes JOIN kenyan_regions ON farm_sizes.region = kenyan_regions.region_code WHERE farm_sizes.year = 2017 GROUP BY region;',
#  "SELECT ImplementationYear, COUNT(*) FROM SupportPrograms WHERE Region = 'Northeast' GROUP BY ImplementationYear;",
#  'SELECT name FROM oceans WHERE avg_temperature = (SELECT MAX(avg_temperature) FROM oceans) AND avg_salinity = (SELECT MAX(avg_salinity) FROM oceans);',
#  'SELECT SUM(Weight) FROM Products WHERE Organic = TRUE AND Category_ID = 1;',
#  'SELECT metric_name, rating FROM community_policing;',
#  'SELECT city, MAX(attendance) FROM CulturalEvents WHERE date >= DATEADD(year, -1, GETDATE()) GROUP BY city;',
#  "INSERT INTO weapons (name, origin, status) VALUES ('Javelin', 'USA', 'in-development');",
#  "SELECT type FROM military_equipment WHERE country = 'Canada';",
#  'SELECT mi.name, mi.year FROM military_innovation mi INNER JOIN (SELECT DISTINCT country FROM military_innovation) mic ON mi.country = mic.country;',
#  "SELECT AVG(total_amount) FROM transactions t JOIN clients c ON t.client_id = c.client_id WHERE c.net_worth > 1000000 AND t.transaction_date BETWEEN '2023-10-01' AND '2023-12-31';",
#  "SELECT MIN(account_balance) FROM clients WHERE region = 'Northwest';",
#  'ports(port_id, port_name, country, region, location)\nWITH deleted_port AS (DELETE FROM ports WHERE port_id = 8000 RETURNING *) SELECT * FROM deleted_port;',
#  "SELECT COUNT(DISTINCT vessels.id) FROM vessels LEFT JOIN cargo ON vessels.id = cargo.vessel_id LEFT JOIN ports ON cargo.port_id = ports.id WHERE ports.name = 'Port of Mumbai' AND cargo.loaded_date >= '2022-06-01' AND cargo.loaded_date <= '2022-06-30' AND cargo.perishable IS NULL;",
#  'SELECT port_id, AVG(time_in_hours) FROM cargo_handling GROUP BY port_id;',
#  'SELECT material FROM WasteData WHERE waste_quantity > (SELECT avg_waste FROM IndustryAverages WHERE material = WasteData.material);',
#  'SELECT state, COUNT(*) AS num_hospitals_and_clinics, (SELECT COUNT(*) FROM hospitals WHERE has_ct_scan = true) * 100.0 / (SELECT COUNT(*) FROM hospitals) AS pct_hospitals_with_ct_scan FROM hospitals GROUP BY state UNION SELECT state, COUNT(*) AS num_hospitals_and_clinics, (SELECT COUNT(*) FROM clinics) * 100.0 / (SELECT COUNT(*) FROM clinics) AS pct_hospitals_with_ct_scan FROM clinics GROUP BY state;',
#  'SELECT country, COUNT(*) FROM green_energy_funding WHERE funding_date >= DATEADD(month, -3, GETDATE()) GROUP BY country;',
#  'DROP TABLE EmployeeDemographics;',
#  "DELETE FROM fields WHERE field_name LIKE '%Field%' AND region = 'Gulf of Mexico';",
#  "SELECT DATE_FORMAT(post_date, '%Y-%m') as month, platform, COUNT(*) as num_posts FROM social_media_posts WHERE post_text LIKE '%ethical AI%' GROUP BY month, platform;",
#  "DELETE FROM fares WHERE rider_id = (SELECT rider_id FROM riders WHERE name = 'John Smith');",
#  "SELECT COUNT(*) FROM bus_trips WHERE borough = 'NYC' AND trip_date BETWEEN '2022-01-01' AND '2022-03-31';",
#  'SELECT size, COUNT(*) FROM products INNER JOIN size_ranges ON products.size = size_ranges.size GROUP BY size;',
#  "SELECT * FROM (SELECT *, ROW_NUMBER() OVER (PARTITION BY category ORDER BY likes DESC) rn FROM posts) t WHERE t.rn = 3 AND t.category = 'sports';",
#  'SELECT AVG(comments_count) FROM social_media_posts;',
#  "SELECT AVG(price) FROM textile_sourcing WHERE material = 'cotton' AND country = 'United States';",
#  "SELECT customer_id, COUNT(*) as purchase_count FROM CustomerOrders WHERE product = 'Sustainable Clothing' AND order_date >= DATE_SUB(CURRENT_DATE, INTERVAL 6 MONTH) GROUP BY customer_id ORDER BY purchase_count DESC LIMIT 1;",
#  "SELECT DATE_FORMAT(VolunteerDate, '%Y-%m') AS Month, ProgramID, SUM(Hours) FROM Volunteers WHERE YEAR(VolunteerDate) = YEAR(CURRENT_DATE) GROUP BY Month, ProgramID;",
#  "SELECT SUM(calories) FROM Dishes WHERE dish_name LIKE 'HealthyHarvest%' AND price > (SELECT AVG(price) FROM Dishes WHERE dish_name LIKE 'HealthyHarvest%');",
#  "SELECT Warehouses.WarehouseName, SUM(Shipments.Quantity) AS TotalShipments FROM Warehouses INNER JOIN Shipments ON Warehouses.WarehouseID = Shipments.WarehouseID WHERE Warehouses.Country = 'USA' GROUP BY Warehouses.WarehouseName ORDER BY TotalShipments DESC LIMIT 3;",
#  "UPDATE warehouse_management SET item_name = 'WidGET' WHERE id = 1;",
#  'SELECT return_point FROM (SELECT return_point, ROW_NUMBER() OVER (ORDER BY return_half DESC, return_year DESC) as rn FROM returns WHERE return_year = 2022 AND return_half = 1) t WHERE rn <= 3;',
#  "SELECT AVG(funding) FROM biotech.startups WHERE location = 'USA' AND industry = 'Biotechnology';",
#  "SELECT DISTINCT service_type FROM public_services WHERE service_type NOT IN ('type_c', 'type_d');",
#  "SELECT professors.name, grants.amount FROM professors INNER JOIN grants ON professors.id = grants.professor_id INNER JOIN departments ON professors.department_id = departments.id WHERE departments.name = 'Computer Science';",
#  'SELECT region, worker_count, COUNT(*) OVER (PARTITION BY region) AS total_workers FROM region_health_workers;',
#  "SELECT SUM(views) FROM virtual_tours WHERE location = 'Japan' AND date >= DATEADD(year, -1, GETDATE());",
#  "SELECT COUNT(DISTINCT vt.hotel_id) AS total_tours_engaged FROM virtual_tours vt INNER JOIN hotels h ON vt.hotel_id = h.hotel_id INNER JOIN ai_solutions ai ON h.hotel_id = ai.hotel_id WHERE ai.solution_type = 'housekeeping' AND h.region = 'Africa';",
#  "SELECT artwork_name, price FROM Artworks WHERE period = 'Surrealism';",
#  "SELECT DATE_FORMAT(date, '%Y-%m') AS month, species, AVG(temperature) FROM arctic_weather WHERE YEAR(date) = 2020 GROUP BY month, species;",
#  "SELECT AVG(age) FROM patients WHERE condition = 'Anxiety Disorder';",
#  "SELECT MAX(Cost) - MIN(Cost) FROM Road_Australia WHERE Country = 'Australia';",
#  "SELECT SUM(market_spend) FROM sustainable_tourism_initiatives WHERE country = 'Japan' AND start_year BETWEEN 2017 AND 2019;",
#  "SELECT AVG(expenditure), COUNT(*) FROM Visitors_Brazil WHERE year = 2022 AND country = 'Brazil';",
#  'SELECT destination_name, country, awards, RANK() OVER (PARTITION BY country ORDER BY awards ASC) AS rank FROM Destinations;',
#  'SELECT county, COUNT(*) FROM legal_aid_organizations GROUP BY county;',
#  "SELECT SUM(biomass) FROM MarineSpecies INNER JOIN MarineEcosystems ON MarineSpecies.ecosystem_id = MarineEcosystems.ecosystem_id WHERE MarineEcosystems.ecosystem_name = 'Coral Reef';",
#  'SELECT COUNT(*) FROM Arctic_Marine_Species WHERE is_affected_by_pollution = true;',
#  "SELECT AVG(views) FROM movies WHERE country IN ('South Korea', 'Japan');",
#  'SELECT mine_name, impact FROM (SELECT mine_name, impact, measurement_date, ROW_NUMBER() OVER (ORDER BY impact DESC) as rn FROM mine_environmental_impact WHERE measurement_date >= DATEADD(year, -1, CURRENT_DATE)) t WHERE rn <= 5;',
#  "SELECT year, AVG(productivity) FROM LaborProductivity WHERE country = 'Australia' AND industry = 'Mining' AND year BETWEEN (SELECT MAX(year) - 5 FROM LaborProductivity) AND MAX(year) GROUP BY year;",
#  "SELECT name, role FROM mine_operators WHERE name LIKE 'A%' OR name LIKE 'B%';",
#  'SELECT EXTRACT(MONTH FROM publish_date) AS month, COUNT(*) AS articles FROM articles GROUP BY month;',
#  "SELECT organizations.organization_name FROM organizations INNER JOIN donations ON organizations.organization_id = donations.organization_id WHERE donations.donation_year = 2023 AND donations.donation_country = 'Brazil';",
#  "INSERT INTO marine_species (name, weight, location) VALUES ('Blue Whale', 200000.0, 'North Atlantic Ocean');",
#  'INSERT INTO players SELECT * FROM new_players WHERE NOT EXISTS (SELECT 1 FROM players WHERE players.id = new_players.id);',
#  "SELECT AVG(Age) FROM Players WHERE Game = 'Racing Simulator 2022';",
# ...
#  "SELECT AVG(amount) FROM donations WHERE campaign = 'Education for All' AND YEAR(donation_date) = 2021;",
#  "SELECT COUNT(*) FROM Donations JOIN Volunteers ON Donations.volunteer_id = Volunteers.id WHERE Volunteers.country = 'India';",
#  'SELECT year, score, LAG(score) OVER (PARTITION BY student_id ORDER BY year) as previous_score, score - LAG(score) OVER (PARTITION BY student_id ORDER BY year) as score_change FROM mental_health_changes;',
#  "INSERT INTO tanker (id, name, operator, source, destination, capacity) VALUES (1, 'Theta Shipping', 'Norway', 'Canada', 100000);",
#  "INSERT INTO oil_market (market_id, market_name, crude_oil_price_usd) VALUES (105, 'Asian Market', 85.99);",
#  "INSERT INTO wells (id, location, depth) VALUES (1, 'Brazil', 4000);",
#  'SELECT name, age, gender FROM (SELECT name, age, gender, ROW_NUMBER() OVER (PARTITION BY gender ORDER BY age DESC) as rn FROM donors) t WHERE rn = 1;',
#  'SELECT device_type, user_count FROM (SELECT device_type, user_count, NTILE(4) OVER (ORDER BY user_count) as percentile FROM technology_accessibility) tmp WHERE percentile IN (2, 3, 4) ORDER BY user_count ASC;',
#  'SELECT vehicle_type, SUM(fare) OVER (PARTITION BY vehicle_type) AS total_fare FROM Fares ORDER BY total_fare DESC;',
#  "SELECT AVG(delay_time) FROM (SELECT delay_time, EXTRACT(MONTH FROM delay_date) AS month FROM subway_delays WHERE station = 'uptown' GROUP BY month, delay_time) WHERE station = 'uptown';",
#  "SELECT factory_id, AVG(production_cost) FROM garments WHERE garment_name LIKE '%Polyester%' GROUP BY factory_id;",
#  'SELECT * FROM privacy_settings WHERE data_sharing = TRUE;',
#  "SELECT MAX(users.followers) FROM users JOIN posts ON users.id = posts.user_id WHERE posts.content LIKE '%sustainable living%' AND posts.post_date >= DATE_SUB(CURRENT_DATE, INTERVAL 1 MONTH);",
#  "SELECT SUM(revenue) FROM sponsored_posts WHERE category = 'beauty';",
#  "DELETE FROM nutrition_facts WHERE product_id = 'P001';",
#  'SELECT s.name, COUNT(*) as organic_shipments FROM suppliers s JOIN shipments sh ON s.supplier_id = sh.supplier_id WHERE sh.organic = true GROUP BY s.name ORDER BY organic_shipments DESC LIMIT 3;',
#  "SELECT SUM(quantity) FROM shipments JOIN warehouses ON shipments.warehouse_id = warehouses.warehouse_id WHERE warehouses.city = 'NYC';",
#  'SELECT SUM(budget) FROM biosensor_tech WHERE quarter IN (2, 3) AND year = 2021;',
#  'SELECT i.name, b.investment_amount FROM investors i INNER JOIN biosensors b ON i.id = b.investor_id WHERE b.investment_amount > 50000;',
#  "UPDATE startups SET name = 'NewStartupA' WHERE id = 1;",
#  "SELECT SUM(funding) FROM genome_inc WHERE project = 'Genetic Research';",
#  "SELECT SUM(size) FROM green_buildings WHERE country = 'India' AND certification = 'GRIHA';",
#  "SELECT contractor_name, COUNT(*) as total_projects FROM green_buildings JOIN contractors ON green_buildings.contractor_id = contractors.contractor_id WHERE state = 'CA' GROUP BY contractor_name ORDER BY total_projects DESC LIMIT 5;",
#  'SELECT Countries.name, COUNT(CountryHeritages.id) AS num_sites FROM Countries INNER JOIN CountryHeritages ON Countries.id = CountryHeritages.country_id GROUP BY Countries.name ORDER BY num_sites DESC LIMIT 3;',
#  "SELECT AVG(languages_count) FROM (SELECT COUNT(languages.id) AS languages_count FROM languages JOIN countries ON languages.country_id = countries.id JOIN continents ON countries.continent_id = continents.id WHERE continents.name = 'Southeast Asia' GROUP BY countries.id) AS subquery;",
#  "SELECT COUNT(*) FROM diagnoses JOIN patients ON diagnoses.patient_id = patients.id WHERE diagnoses.condition = 'Anxiety' AND patients.country = 'Germany';",
#  "SELECT AVG(maintenance_cost) FROM Airport WHERE country = 'Germany';",
#  'SELECT country_name, COUNT(*) as num_incidents FROM MarinePollution WHERE country_name IN (SELECT country_name FROM OceanWaters) GROUP BY country_name;',
#  "SELECT COUNT(*) FROM tv_shows WHERE country = 'Spain' AND year = 2017;",
#  "SELECT MIN(pub_date) FROM articles_tech WHERE category = 'Tech';",
#  'SELECT COUNT(*) as num_allergen_free, (COUNT(*) * 100.0 / (SELECT COUNT(*) FROM menus)) as allergen_free_percentage FROM menus WHERE has_allergen_free = TRUE;',
#  "SELECT Region, SUM(Quantity) FROM Regional_Sales WHERE Menu_Item = 'Veggie Burger' GROUP BY Region;",
#  'SELECT SUM(i.unit_price * o.quantity) FROM inventory i JOIN orders o ON i.item_id = o.item_id JOIN menu_items m ON i.item_id = m.item_id WHERE m.is_organic = true AND o.order_date >= DATEADD(month, -1, GETDATE());',
#  "SELECT MAX(quantity_sold) FROM naval_sales WHERE company = 'ArmaTech' AND region = 'Europe';",
#  "SELECT COUNT(DISTINCT genre) FROM (SELECT genre FROM Artists JOIN Music_Festivals ON Artists.region = Music_Festivals.region WHERE Artists.festival_performance > 0 AND Artists.region = 'Africa' AND YEAR(Music_Festivals.festival_date) = 2022) AS Subquery;",
#  "DELETE FROM audience_demographics WHERE country = 'Russia' AND age < 18;",
#  'DELETE FROM Players WHERE PlayerID NOT IN (SELECT PlayerID FROM Players WHERE HasPlayedVR = TRUE) AND Age < 25;',
#  "SELECT AVG(PrizePool) FROM PrizePools WHERE Game = 'RPG' AND Region = 'North America';",
#  'SELECT COUNT(*) FROM sensor;',
#  "DELETE FROM irrigation_data WHERE irrigation_id = 'I031';",
#  'SELECT country, 100.0 * SUM(quantity) / (SELECT SUM(quantity) FROM europium_production) as percentage FROM europium_production GROUP BY country;',
#  "SELECT MAX(quantity * price) FROM Yttrium_Sales WHERE country = 'India' AND year BETWEEN 2019 AND 2021;",
#  "UPDATE menu SET price = 12.99 WHERE item_name = 'Tofu Stir Fry' AND restaurant_id = (SELECT restaurant_id FROM restaurants WHERE name = 'Green Garden');",
#  "SELECT MIN(revenue) FROM Restaurants WHERE type = 'Ethiopian';",
#  "SELECT SUM(Revenue) FROM Revenue WHERE Practice = 'Ethical Labor' AND Country = 'South America';",
#  "SELECT name FROM space_craft WHERE orbit = 'GTO' AND mass = (SELECT MAX(mass) FROM space_craft WHERE orbit = 'GTO');",
#  "SELECT SUM(Mass) FROM Space_Debris WHERE Object_Type = 'Space Debris';",
#  'SELECT t.team_name, SUM(tp.total_sales) as total_sales FROM team_performance tp JOIN team_data t ON tp.team_id = t.team_id WHERE tp.home_game = true AND tp.total_sales > 0 GROUP BY t.team_name;',
#  'SELECT salesperson_id, COUNT(*) as num_sales, SUM(revenue) as total_revenue FROM sales GROUP BY salesperson_id ORDER BY num_sales DESC;',
#  'SELECT country, AVG(sustainability_rating) as avg_sustainability_rating, RANK() OVER (ORDER BY AVG(sustainability_rating) DESC) as rank FROM suppliers GROUP BY country HAVING rank <= 3;',
#  "SELECT DISTINCT p.Name FROM Policyholder p INNER JOIN Policy pol ON p.PolicyholderID = pol.PolicyholderID INNER JOIN Claim c ON pol.PolicyID = c.PolicyID WHERE p.Region = 'Midwest' AND c.ClaimAmount > 1000;",
#  "SELECT AVG(num_employees) FROM workplaces WHERE country = 'USA' AND is_unionized = true;",
#  'SELECT AVG(total_workers) FROM industry;',
#  "SELECT AVG(speed) FROM vessel_speed WHERE vessel_name = 'VesselL';",
#  'SELECT Visitor.name FROM Visitor INNER JOIN Visitor_Exhibition ON Visitor.id = Visitor_Exhibition.visitor_id GROUP BY Visitor.name HAVING COUNT(Visitor_Exhibition.exhibition_id) > 1;',
#  'DELETE FROM recycling_rates WHERE year = 2018;',
#  "SELECT SUM(savings) FROM WaterConservationInitiatives WHERE city = 'San Diego' AND year = 2019;",
#  'DELETE FROM Workouts WHERE id = 2;',
#  "SELECT COUNT(*) FROM fairness_incidents WHERE region = 'Asia' AND incident_date >= DATEADD(quarter, -1, CURRENT_DATE);",
#  "SELECT AVG(num_models) FROM (SELECT COUNT(*) AS num_models, EXTRACT(MONTH FROM launch_date) AS month FROM explainable_ai WHERE country = 'Singapore' AND launch_date >= '2021-01-01' AND launch_date < '2022-01-01' GROUP BY month) subquery;",
#  'SELECT spacecraft, COUNT(*) FROM Accidents GROUP BY spacecraft;',
#  "SELECT COUNT(*) FROM Satellite_Deployments WHERE manufacturer = 'SpaceX' AND success = true AND deployment_date >= DATE_SUB(CURRENT_DATE, INTERVAL 5 YEAR);",
#  'SELECT country, COUNT(*) FROM community_education GROUP BY country;',
#  'CREATE VIEW avg_biomass AS SELECT species, AVG(biomass) FROM fish_stock GROUP BY species;',
#  "SELECT AVG(attendee_age) FROM attendee_demographics INNER JOIN event_attendance ON attendee_demographics.attendee_id = event_attendance.attendee_id WHERE event_attendance.event_name = 'Dance';",
#  "DELETE FROM genres WHERE country = 'Russia';",
#  "SELECT SUM(amount) FROM Funding WHERE program = 'Dance' AND location = 'California' AND date >= '2017-01-01';",
#  "SELECT AVG(production_budget), release_year FROM movies WHERE genre = 'Action' AND release_year BETWEEN 2010 AND 2020 GROUP BY release_year;",
#  "SELECT project_id, labor_hours, RANK() OVER (ORDER BY labor_hours DESC) AS labor_rank FROM project WHERE region = 'Northeast';",
#  "SELECT AVG(quantity) FROM Waste_Disposal WHERE chemical_name = 'Sulfuric Acid' AND disposal_date BETWEEN '2022-07-01' AND '2022-07-31';",
#  "SELECT MAX(ChemicalProducts.SafetyScore) FROM ChemicalProducts INNER JOIN Manufacturers ON ChemicalProducts.ManufacturerID = Manufacturers.ManufacturerID WHERE Manufacturers.Region = 'Asia';",
#  "SELECT COUNT(*) FROM climate_finance WHERE location = 'Asia' AND sector = 'Climate Finance';",
#  'SELECT SUM(revenue) FROM drug_sales_3 WHERE year BETWEEN 2017 AND 2019;',
#  "SELECT COUNT(*) FROM community_health_centers WHERE location = 'urban';",
#  "SELECT AVG(date_hired) FROM Employee WHERE company_id IN (SELECT id FROM Company WHERE industry = 'GreenTech');",
#  'SELECT country, initiatives FROM urban_agriculture ORDER BY initiatives DESC;',
#  'SELECT type, MIN(budget) FROM AccommodationTypes WHERE type IN (SELECT type FROM AccommodationTypes WHERE budget = (SELECT MIN(budget) FROM AccommodationTypes WHERE type = AccommodationTypes.type)) GROUP BY type;',
#  "SELECT COUNT(*) FROM conservation_efforts WHERE program = 'Pacific_conservation';",
#  'SELECT ingredient_name, AVG(sustainability_rating) as avg_rating, COUNT(*) as total_products FROM ingredients GROUP BY ingredient_name ORDER BY avg_rating DESC LIMIT 2;',
#  'SELECT product_id, AVG(carbon_footprint) OVER (ORDER BY product_id ROWS BETWEEN UNBOUNDED PRECEDING AND CURRENT ROW) AS avg_carbon_footprint FROM sustainability_metrics;',
#  'SELECT call_type, COUNT(*) FROM search_and_rescue GROUP BY call_type;',
#  'SELECT call_type, AVG(response_time) FROM emergency_calls GROUP BY call_type;',
#  "SELECT COUNT(*) FROM community_policing WHERE country = 'USA';",
#  "SELECT COUNT(*) FROM emergency_incidents WHERE city = 'Oakland';",
#  "SELECT MAX(Value) FROM Investments WHERE Market = 'US';",
#  "SELECT MIN(age) AS min_age, MAX(age) AS max_age FROM customers WHERE country = 'Japan';",
#  "SELECT * FROM Employee WHERE Department = 'Quality Control';",
#  "SELECT AVG(DATEDIFF('2021-12-31', birth_date) / 365.25) FROM patients JOIN hospital_visits ON patients.patient_id = hospital_visits.patient_id WHERE hospital_visits.location = 'Rural Louisiana';",
#  'SELECT region_id, incident_quarter, AVG(incident_count) OVER (PARTITION BY region_id ORDER BY incident_quarter ROWS BETWEEN 2 PRECEDING AND CURRENT ROW) as moving_average FROM incident_data;',
#  "SELECT * FROM advisors WHERE clearance = 'Top Secret';",
#  "SELECT Name FROM MilitaryAircrafts WHERE Country = 'USA' AND ManufacturingDate > '2000-12-31';",
#  "SELECT ProgramCategory, SUM(Budget) - SUM(Spent) as TotalBudgetSpent FROM Programs WHERE HoursWorked BETWEEN '2022-01-01' AND '2022-06-30' GROUP BY ProgramCategory;",
#  'SELECT subject, COUNT(*) FROM teachers WHERE professional_development_course_completion_date >= DATEADD(year, -1, GETDATE()) GROUP BY subject;',
#  "SELECT COUNT(*) FROM Employees WHERE Department = 'HR' AND HireDate >= DATEADD(month, -6, GETDATE());",
#  "SELECT AVG(efficiency_rating) FROM energy_efficiency WHERE building_type = 'Residential' AND country = 'India';",
#  "SELECT AVG(age) FROM basketball_players WHERE position = 'Guard' OR position = 'Forward';",
#  'DELETE FROM shelters WHERE shelter_id = 2;',
#  'SELECT disaster_type, SUM(donation_amount) FROM donations WHERE donation_date >= DATE_SUB(CURRENT_DATE, INTERVAL 3 MONTH) GROUP BY disaster_type;',
#  'SELECT tr.route_name, AVG(tf.fare_amount) FROM train_routes tr INNER JOIN train_fares tf ON tr.route_id = tf.route_id GROUP BY tr.route_name;',
#  "SELECT COUNT(*) FROM posts WHERE platform = 'Twitter' AND MONTH(post_date) = 6 AND YEAR(post_date) = 2021 AND user_id IN (SELECT user_id FROM users WHERE category = 'brand');",
#  'SELECT AVG(posts.likes) FROM posts WHERE posts.timestamp >= DATE_SUB(NOW(), INTERVAL 1 MONTH) GROUP BY posts.user_id HAVING COUNT(posts.id) > 1;',
#  "SELECT SUBSTRING_INDEX(SUBSTRING_INDEX(hashtags, ' ', n.n), ' ', -1) hashtag, COUNT(*) count FROM posts JOIN users ON posts.user_id = users.id CROSS JOIN (SELECT 1 n UNION SELECT 2 UNION SELECT 3 UNION SELECT 4 UNION SELECT 5) n WHERE users.country = 'Brazil' GROUP BY hashtag ORDER BY count DESC LIMIT 1;",
#  "SELECT SUM(sessions) FROM financial_capability_training WHERE country = 'Germany' AND quarter = 1 AND year = 2022;",
#  "UPDATE dishes SET calorie_count = 350 WHERE name = 'Pão de Queijo' AND country = 'Brazil';",
#  "SELECT AVG(expression) FROM (SELECT expression FROM genetic.gene_expression WHERE tissue = 'Cardiovascular' ORDER BY expression DESC LIMIT 5) subquery;",
#  "SELECT AVG(energy_output) FROM renewable_energy WHERE energy_type = 'Wind';",
#  "SELECT worker_id, (COUNT(CASE WHEN metric1 THEN 1 END) * 100.0 / COUNT(*)) AS metric1_percentage, (COUNT(CASE WHEN metric2 THEN 1 END) * 100.0 / COUNT(*)) AS metric2_percentage, (COUNT(CASE WHEN metric3 THEN 1 END) * 100.0 / COUNT(*)) AS metric3_percentage FROM health_equity_metrics_worker WHERE region = 'West' AND year IN (2020, 2021) GROUP BY worker_id;",
#  "SELECT AVG(rating) FROM virtual_tours WHERE country = 'Southeast Asia' AND quarter = 'Q2';",
#  "SELECT MAX(revenue) FROM sustainable_tours WHERE country = 'Japan';",
#  "SELECT COUNT(*) FROM Exhibitions WHERE location IN ('France', 'Spain');",
#  "DELETE FROM LanguagePreservation WHERE country = 'Vanuatu' AND language = 'Bislama' AND status = 'Vulnerable';",
#  'SELECT Continent, MAX(Number_Speakers) AS Max_Speakers, 100.0 * MAX(Number_Speakers) / SUM(MAX(Number_Speakers)) OVER (PARTITION BY Continent) AS Percentage FROM Endangered_Languages_Continent GROUP BY Continent;',
#  "SELECT COUNT(*) FROM court_cases WHERE defender_type = 'Public Defender' AND YEAR(court_date) = 2020 AND city = 'New York City';",
#  'SELECT province_territory, AVG(clients_served) FROM canada_legal_aid GROUP BY province_territory;',
#  'DELETE FROM MilitaryEquipmentSales WHERE sale_amount > 50000;',
#  "SELECT SUM(production) FROM mine WHERE mineral = 'Iron' AND location = 'Russia';",
#  'SELECT mine_name FROM co2_emissions JOIN mine_info ON co2_emissions.mine_id = mine_info.mine_id WHERE co2_amount > (SELECT AVG(co2_amount) FROM co2_emissions);',
#  "SELECT r.name, COUNT(DISTINCT n.author) as unique_authors FROM news.Region r INNER JOIN news.NewsSource n ON r.name = n.name WHERE r.location = 'western' GROUP BY r.name;",
#  "SELECT COUNT(*) FROM deep_sea_expeditions WHERE location = 'Pacific Ocean';",
#  "SELECT species_name FROM marine_species WHERE ocean_location = 'Arctic Ocean';",
#  'SELECT type, COUNT(*) FROM marine_species GROUP BY type;',
#  "SELECT location, SUM(humidity) as total_humidity FROM Weather WHERE timestamp >= NOW() - INTERVAL '1 week' GROUP BY location ORDER BY total_humidity DESC LIMIT 3;",
#  "SELECT SUM(precipitation) FROM precipitation JOIN sensors ON precipitation.sensor_id = sensors.sensor_id WHERE sensors.location = 'Field E' AND timestamp BETWEEN '2022-01-01 00:00:00' AND '2022-01-31 23:59:59';",
#  "SELECT MAX(size) - MIN(size) FROM properties WHERE city = 'Sydney';",
#  "SELECT country, COUNT(*) FROM clean_energy_policies WHERE policy = 'clean_energy' GROUP BY country;",
#  "SELECT product_category, SUM(sale_amount) AS total_sales_revenue FROM sales JOIN products ON sales.product_id = products.product_id WHERE sale_region = 'Europe' GROUP BY product_category ORDER BY total_sales_revenue DESC LIMIT 3;",
#  ...]

# %%
for x in extracted_sqls_with_context:
  print(x)
  print("--------------")
# Out:
# SELECT MAX(billing_amount) FROM cases JOIN attorneys ON cases.attorney_id = attorneys.attorney_id WHERE attorneys.state = 'NY' AND attorneys.win_rate > 0.8;
# --------------
# SELECT country, emissions FROM (SELECT country, emissions, ROW_NUMBER() OVER (ORDER BY emissions DESC) as rn FROM emissions WHERE country != 'US') t WHERE rn <= 3;
# --------------
# SELECT State, COUNT(*) FROM Hospitals WHERE MentalHealth = TRUE GROUP BY State;
# --------------
# SELECT AVG(raised_amount) FROM investments JOIN diversity ON investments.company_id = diversity.company_id WHERE latinx_founder = true;
# --------------
# SELECT COUNT(*) FROM accommodations WHERE accommodation_category = 'Online Learning';
# --------------
# DELETE FROM CoralReefs WHERE Health_Status = 'Degraded';
# --------------
# SELECT MIN(Daily_Transactions) FROM Smart_Contracts SC JOIN Digital_Assets DA ON SC.Asset_ID = DA.Asset_ID WHERE DA.Issuer_Country = 'Africa';
# --------------
# SELECT status FROM regulation WHERE country = 'germany';
# --------------
# SELECT SUM(market_cap) FROM digital_assets WHERE asset_id IN (SELECT asset_id FROM transactions GROUP BY asset_id HAVING COUNT(*) >= 1000);
# --------------
# SELECT AVG(training_count) FROM DisasterPreparedness WHERE state = 'California' GROUP BY year;
# --------------
# SELECT artist_name, SUM(quantity) FROM MuseumArtists GROUP BY artist_name;
# --------------
# SELECT AVG(avg_attendance) FROM concerts WHERE genre = 'Jazz';
# --------------
# INSERT INTO veteran_employment (veteran_id, name, job_start_date) VALUES (888, 'James Smith', '2015-01-01');
# --------------
# UPDATE threat_intelligence SET threat_level = 'medium' WHERE threat_source = 'United Nations' AND threat_date < '2022-01-01';
# --------------
# SELECT * FROM employee_skills WHERE skill_name = 'sustainable_manufacturing' AND experience_years > 2;
# --------------
# SELECT site_name, SUM(total_artifacts) FROM excavation_sites WHERE year = 2020 GROUP BY site_name;
# --------------
# SELECT name FROM hospitals WHERE region = 'Northeast' AND patient_capacity = (SELECT MIN(patient_capacity) FROM hospitals WHERE region = 'Northeast');
# --------------
# INSERT INTO open_pedagogy_resources (resource_name, topic) VALUES ('Critical Thinking in Math Education', 'critical thinking');
# --------------
# SELECT Department FROM Employees GROUP BY Department HAVING COUNT(*) > 1;
# --------------
# SELECT HireYear, COUNT(*) OVER (PARTITION BY HireYear ORDER BY HireYear) AS Running_Total FROM Hiring;
# --------------
# SELECT sector, (SUM(efficiency) / (SELECT SUM(efficiency) FROM energy_efficiency WHERE year = 2015 AND sector = e.sector) * 100.0) - 100.0 AS improvement FROM energy_efficiency e WHERE year = 2020 GROUP BY sector;
# --------------
# SELECT SUM(capacity) FROM windfarm WHERE country IN ('Germany', 'France');
# --------------
# INSERT INTO basketball_players (player_id, player_name, position, team, country) VALUES (1, 'Marta Santiago', 'center', 'Spain national team', 'Spain');
# --------------
# SELECT AVG(item_count) FROM (SELECT item_count, delivery_date FROM items_delivered WHERE country = 'South America' AND QUARTER(delivery_date) = 3 AND YEAR(delivery_date) = 2021 GROUP BY delivery_date) AS avg_items_per_day;
# --------------
# DELETE FROM accessibility_features WHERE feature_type = 'Voice Command' AND status = 'Discontinued';
# --------------
# SELECT company, year, COUNT(*) FROM ai_patents GROUP BY company, year;
# --------------
# UPDATE EthicalAIPractices SET StartDate = '2022-05-01' WHERE Project = 'AI for Children';
# --------------
# SELECT AVG(project_count) FROM (SELECT COUNT(*) AS project_count FROM digital_divide_projects WHERE country = 'Asia' GROUP BY completion_year) AS subquery;
# --------------
# SELECT SUM(budget) FROM accessible_tech WHERE sector = 'education';
# --------------
# SELECT SUM(fare) FROM bus_trips JOIN bus_routes ON bus_trips.route_id = bus_routes.route_id WHERE bus_routes.starting_letter = 'B';
# --------------
# SELECT Brand_ID, DATEDIFF(day, ISNULL(Last_Usage_Date, '9999-01-01'), '9999-01-01') AS Days_Since_Last_Usage FROM Brand_Sustainable_Material_Last_Usage;
# --------------
# SELECT region, COUNT(*) FROM labor_practices_violations GROUP BY region;
# --------------
# SELECT name, SUM(spend) as total_spend FROM african_consumers WHERE country IN ('Nigeria', 'South Africa', 'Egypt') GROUP BY name ORDER BY total_spend DESC LIMIT 1;
# --------------
# SELECT country, COUNT(*) as sustainable_labor_count FROM ManufacturerLabor WHERE has_sustainable_labor = true GROUP BY country ORDER BY sustainable_labor_count DESC;
# --------------
# SELECT COUNT(*) FROM sales WHERE size = '2XL' AND date >= DATE_SUB(CURRENT_DATE, INTERVAL 1 MONTH);
# --------------
# SELECT SUM(amount) FROM donations WHERE donor = 'Aisha' AND YEAR(donation_date) = 2021;
# --------------
# SELECT COUNT(*) FROM FinancialTransactions INNER JOIN Volunteers ON FinancialTransactions.VolunteerID = Volunteers.VolunteerID;
# --------------
# UPDATE OrganicProducts SET name = 'Eco-friendly Product2' WHERE id = 2;
# --------------
# SELECT COUNT(*) FROM Inventory WHERE is_organic = TRUE AND category = 'Fruit';
# --------------
# SELECT carrier_name, COUNT(*) FROM shipment GROUP BY carrier_name;
# --------------
# SELECT transportation_mode, COUNT(DISTINCT item_type) FROM shipments GROUP BY transportation_mode;
# --------------
# SELECT WarehouseID, COUNT(*) as TotalLateDeliveries FROM Shipments WHERE LateDelivery = 1 AND ShippedDate >= DATEADD(month, -1, GETDATE()) AND WarehouseID IN (SELECT WarehouseID FROM Warehouses WHERE Region = 'Americas') GROUP BY WarehouseID HAVING COUNT(*) >= 25;
# --------------
# SELECT COUNT(*), area_sqm FROM parks WHERE state = 'New York' GROUP BY area_sqm;
# --------------
# SELECT (COUNT(*) * 100.0 / (SELECT COUNT(*) FROM faculty_members WHERE faculty_department = 'School of Business')) AS percentage FROM faculty_members WHERE faculty_race = 'AAPI';
# --------------
# SELECT AVG(budget) FROM green_buildings WHERE building_name LIKE '%green%';
# --------------
# SELECT SUM(capacity) FROM wind_projects WHERE country = 'Germany';
# --------------
# SELECT city, project_type, SUM(investment_cost) FROM energy_efficient_lighting WHERE investment_cost > 1000000 GROUP BY city, project_type;
# --------------
# SELECT MAX(number) FROM mental_health_parity_violations WHERE state IN ('South Carolina', 'North Carolina', 'Virginia', 'West Virginia', 'Maryland', 'Delaware', 'District of Columbia');
# --------------
# SELECT city, COUNT(*) FROM asian_sites WHERE city IN ('Tokyo', 'Seoul') AND type = 'historical' GROUP BY city;
# --------------
# SELECT country, SUM(num_sessions) as total_sessions FROM virtual_tourism WHERE session_date >= '2023-01-01' AND session_date < '2023-04-01' GROUP BY country ORDER BY total_sessions DESC LIMIT 5;
# --------------
# SELECT SUM(num_engagements) FROM TourEngagements WHERE city = 'Barcelona' AND rating >= 4.5;
# --------------
# SELECT Artist.country_of_origin, Artwork.medium, COUNT(Artwork.artwork_id) FROM Artist INNER JOIN Artwork ON Artist.artist_id = Artwork.artist_id WHERE Artwork.genre = 'Expressionism' GROUP BY Artist.country_of_origin, Artwork.medium;
# --------------
# SELECT COUNT(*) FROM UNESCO_SITES WHERE region = 'Oceania';
# --------------
# SELECT AVG(age) FROM patients WHERE improvement = 'improved';
# --------------
# SELECT AVG(patients.age) FROM patients INNER JOIN treatments ON patients.patient_id = treatments.patient_id WHERE treatments.treatment_type = 'Therapy' AND patients.country = 'Canada';
# --------------
# INSERT INTO design_standards (id, name, version, description) VALUES (4, 'Bridge Design Standards for Earthquake Zones', 2022, 'New standards for bridge design in earthquake zones');
# --------------
# SELECT MAX(visitors) FROM gcnp_visitors;
# --------------
# SELECT SUM(revenue) FROM sustainable_tourism WHERE country IN ('New Zealand', 'Canada') AND year = 2022;
# --------------
# SELECT COUNT(DISTINCT service_type) FROM defendant_services;
# --------------
# SELECT species, AVG(depth) FROM underwater_species WHERE ocean IN ('Indian', 'Pacific') GROUP BY species;
# --------------
# UPDATE marine_sites SET max_depth = 3500 WHERE site_name = 'Research Site A';
# --------------
# SELECT country FROM CountryPollution WHERE pollution_level = (SELECT MAX(pollution_level) FROM CountryPollution WHERE region = 'Atlantic Ocean');
# --------------
# CREATE TABLE food_waste_tracking (waste_id INT PRIMARY KEY, waste_type VARCHAR(255), quantity INT, location VARCHAR(255));
# --------------
# SELECT customer_id, COUNT(*) as order_count FROM Orders WHERE order_date >= DATE_SUB(CURRENT_DATE, INTERVAL 30 DAY) GROUP BY customer_id ORDER BY order_count DESC LIMIT 10;
# --------------
# SELECT MAX(value) FROM contract_values WHERE contractor = 'Northrop Grumman' AND service = 'Geopolitical Risk Assessment';
# --------------
# SELECT AVG(productivity) FROM labor WHERE department = 'coal';
# --------------
# SELECT continent, avg_upload_speed, avg_upload_speed/AVG(avg_upload_speed) OVER (PARTITION BY continent) as avg_upload_speed_percentage FROM avg_upload_speed_view;
# --------------
# SELECT MAX(data_usage) FROM subscribers WHERE region = 'urban';
# --------------
# SELECT c.name AS country, COUNT(m.id) AS mobile_subscribers, COUNT(b.id) AS broadband_subscribers FROM subscribers s JOIN mobile_plans mp ON s.plan_id = mp.id JOIN broadband_plans bp ON s.plan_id = bp.id JOIN countries c ON s.country = c.name GROUP BY c.name;
# --------------
# SELECT city, MAX(sales) FROM Concerts;
# --------------
# SELECT DonorID, AVG(DonationAmount) OVER (PARTITION BY DonorID ORDER BY EXTRACT(MONTH FROM DonationDate)) AS AvgDonationPerMonth FROM DonationAmounts;
# --------------
# SELECT donor_id, AVG(DATEDIFF('month', MIN(donation_date), MAX(donation_date))) FROM donations GROUP BY donor_id;
# --------------
# SELECT Programs.ProgramName FROM Programs INNER JOIN ProgramDonations ON Programs.ProgramID = ProgramDonations.ProgramID;
# --------------
# SELECT c.cause_name, AVG(dam.donation_frequency) FROM philanthropy.causes c JOIN (SELECT cause_id, COUNT(*) AS donation_frequency FROM philanthropy.donation_amount_by_cause GROUP BY cause_id) dam ON c.cause_id = dam.cause_id GROUP BY c.cause_name;
# --------------
# SELECT MAX(PlaytimeMinutes) FROM CosmicRacersPlayers WHERE Rank IN ('Platinum', 'Gold', 'Diamond');
# --------------
# SELECT COUNT(DISTINCT PlayerId) FROM GamePlayer GP JOIN Player P ON GP.PlayerId = P.id WHERE GP.GameId = (SELECT G.id FROM Game G WHERE G.name = 'Fantasy') AND P.country = 'Asia';
# --------------
# SELECT VR_Games.GameName, Designers.DesignerName, Designers.YearsOfExperience FROM VR_Games INNER JOIN VR_GameDesign ON VR_Games.GameID = VR_GameDesign.GameID INNER JOIN Designers ON VR_GameDesign.DesignerID = Designers.DesignerID;
# --------------
# SELECT country, COUNT(*) as total_analysis FROM satellite_image_analysis WHERE analysis_date >= DATEADD(month, -1, GETDATE()) GROUP BY country ORDER BY total_analysis DESC LIMIT 3;
# --------------
# SELECT AVG(temperature) FROM Field1_Temperature WHERE EXTRACT(MONTH FROM measurement_time) = 7 AND EXTRACT(YEAR FROM measurement_time) IN (2021, 2022);
# --------------
# SELECT ct.crop_type, MAX(ct.temperature) AS max_temperature, MAX(ch.humidity) AS max_humidity FROM crop_temperature ct INNER JOIN crop_humidity ch ON ct.crop_type = ch.crop_type WHERE ct.timestamp >= DATEADD(month, -1, CURRENT_TIMESTAMP) GROUP BY ct.crop_type;
# --------------
# SELECT SUM(count) FROM Deliveries WHERE quarter = 2 AND region = 'North';
# --------------
# SELECT MIN(amount) FROM Budget WHERE department = 'Education' AND year = 2022;
# --------------
# SELECT element, MIN(quantity) FROM production WHERE year = 2019 GROUP BY element;
# --------------
# SELECT co_owners.name, properties.address FROM co_owners INNER JOIN properties ON co_owners.property_id = properties.id WHERE co_owners.city IN ('Portland', 'Seattle');
# --------------
# SELECT COUNT(*) FROM carbon_offset_programs WHERE program_location LIKE 'Asia%' AND program_start_date >= '2020-01-01' AND program_start_date < '2021-01-01';
# --------------
# SELECT AVG(rating) FROM projects WHERE location = 'Germany';
# --------------
# SELECT project_name FROM renewable_projects WHERE location IN ('US', 'Canada');
# --------------
# SELECT menu_item_id, SUM(quantity_sold) as total_quantity_sold FROM MenuSales WHERE sale_date >= DATEADD(month, -1, GETDATE()) GROUP BY menu_item_id ORDER BY total_quantity_sold ASC;
# --------------
# SELECT source, type, COUNT(*) as debris_count, AVG(DATEDIFF('year', launch_date, '2022-01-01')) as avg_years_in_orbit FROM space_debris GROUP BY source, type;
# --------------
# SELECT COUNT(*) FROM SpaceMissions WHERE end_date < '2010-01-01' AND status = 'Success';
# --------------
# SELECT SUM(Mass) FROM Spacecraft WHERE Manufacturer = 'SpaceX';
# --------------
# SELECT gender, COUNT(*) FROM fan_demographics GROUP BY gender;
# --------------
# SELECT COUNT(*) FROM security_incidents si JOIN users u ON si.user_id = u.user_id WHERE incident_date >= DATEADD(year, -1, GETDATE()) AND u.department_size > 50;
# --------------
# SELECT AVG(speed) FROM taxi_speeds WHERE taxi_type = 'Autonomous' AND city = 'New York' AND date >= DATEADD(day, -7, CURRENT_DATE);
# --------------
# SELECT SUM(claim_amount) FROM claims WHERE policyholder_state IN ('Utah', 'Idaho');
# --------------
# SELECT Underwriters.UnderwriterID, SUM(Claims.Amount) AS TotalClaimAmount FROM Underwriters INNER JOIN Claims ON Underwriters.UnderwriterID = Claims.UnderwriterID WHERE Underwriters.Region = 'Midwest' GROUP BY Underwriters.UnderwriterID ORDER BY TotalClaimAmount DESC LIMIT 3;
# --------------
# SELECT w.region, (COUNT(CASE WHEN i.injury_count = 0 THEN 1 END) / COUNT(w.id)) * 100 AS pct_no_injuries FROM workplaces w LEFT JOIN injuries i ON w.id = i.workplace_id GROUP BY w.region;
# --------------
# DELETE FROM VehicleSafetyTesting WHERE release_year < 2010;
# --------------
# SELECT AVG(speed) FROM vessels WHERE port_id IN (SELECT id FROM ports WHERE country = 'USA' AND name IN ('New York', 'Savannah', 'Norfolk')) AND EXTRACT(MONTH FROM arrival_date) = 7;
# --------------
# SELECT vessel_id, SUM(amount) FROM regulatory_compliance GROUP BY vessel_id;
# --------------
# SELECT country, AVG(recycling_rate) FROM RecyclingRatesOceania WHERE year = 2021 AND country IN ('Australia', 'New Zealand') GROUP BY country;
# --------------
# SELECT researcher_name FROM safety_research ORDER BY contributions DESC LIMIT 3;
# --------------
# SELECT SUM(cost) FROM infrastructure_projects WHERE country = 'India' AND completion_year IN (2021, 2022);
# --------------
# SELECT community_type, SUM(investment) FROM rural_infrastructure_projects WHERE country = 'United States' AND community_type = 'Latinx' GROUP BY community_type;
# --------------
# SELECT project, budget FROM (SELECT project, budget, ROW_NUMBER() OVER (ORDER BY budget DESC) as rn FROM innovation_projects WHERE country = 'Indonesia') t WHERE rn <= 5;
# --------------
# SELECT farm_id, SUM(weight) OVER (PARTITION BY farm_id ORDER BY date) biomass FROM FishBiomass WHERE farm_id = 2;
# --------------
# SELECT MAX(donation_amount) FROM dance_sponsors;
# --------------
# SELECT AVG(DonationAmount) FROM Donors WHERE DonationDate BETWEEN '2021-04-01' AND '2021-06-30' AND DonorID NOT IN (SELECT DonorID FROM Donors GROUP BY DonorID HAVING COUNT(*) > 1);
# --------------
# SELECT SUM(cost) FROM Projects WHERE state = 'Texas' AND is_sustainable = true AND project_date BETWEEN '2022-04-01' AND '2022-06-30';
# --------------
# SELECT COUNT(*) FROM cases WHERE attorney = 'Rodriguez' AND state = 'Texas' AND outcome = 'won' AND YEAR(date) = 2020;
# --------------
# DELETE FROM waste_production WHERE region = 'Antarctica' AND EXTRACT(MONTH FROM date) = 1 AND EXTRACT(YEAR FROM date) = 2022;
# --------------
# SELECT AVG(emissions) FROM factories WHERE location = 'California';
# --------------
# SELECT Protocol FROM Plant_A_Safety_Protocols EXCEPT (SELECT Protocol FROM Plant_B_Safety_Protocols INTERSECT SELECT Protocol FROM Plant_C_Safety_Protocols) EXCEPT (SELECT Protocol FROM Plant_C_Safety_Protocols EXCEPT SELECT Protocol FROM Plant_B_Safety_Protocols INTERSECT SELECT Protocol FROM Plant_A_Safety_Protocols);
# --------------
# SELECT finance_type, SUM(amount) FROM climate_finance WHERE project_location = 'Africa' AND finance_year BETWEEN 2015 AND 2020 GROUP BY finance_type;
# --------------
# SELECT city FROM Finance WHERE avg_temp > (SELECT avg_temp FROM Mitigation WHERE city = Finance.city);
# --------------
# SELECT AVG(LifeExpectancy) FROM Countries WHERE Continent = 'Africa';
# --------------
# INSERT INTO student_disability (id, student_name, disability_type, accommodation_provided) VALUES (3, 'Bob Johnson', 'Mobility Impairment', 'Jumping Jacket');
# --------------
# UPDATE climate_change SET avg_temp_celsius = avg_temp_celsius - 5 WHERE region = 'Arctic Ocean';
# --------------
# SELECT * FROM transactions WHERE user_address = '0x456...';
# --------------
# SELECT name FROM regulatory_frameworks WHERE country_id = (SELECT id FROM countries WHERE name = 'Country1');
# --------------
# SELECT 'Total Organic' AS metric, COUNT(*) AS count FROM products_organic WHERE organic = true UNION ALL SELECT 'Total Non-Organic' AS metric, COUNT(*) AS count FROM products_organic WHERE organic = false;
# --------------
# SELECT AVG(price) FROM cosmetics WHERE is_vegan = TRUE AND country = 'US';
# --------------
# SELECT (COUNT(*) * 100.0 / (SELECT COUNT(*) FROM lipsticks)) AS percentage FROM lipsticks WHERE is_vegan = TRUE AND is_gluten_free = TRUE;
# --------------
# SELECT (COUNT(*) * 100.0 / (SELECT COUNT(*) FROM haircare_sales WHERE country = 'France' AND sale_date BETWEEN '2021-07-01' AND '2021-09-30' AND is_sustainable = true)) AS percentage FROM haircare_sales WHERE country = 'France' AND sale_date BETWEEN '2021-07-01' AND '2021-09-30' AND is_sustainable = true;
# --------------
# SELECT b.brand_name, MAX(p.rating) as max_rating FROM brands b JOIN products p ON b.brand_id = p.brand_id WHERE p.is_cruelty_free = TRUE GROUP BY b.brand_name;
# --------------
# SELECT name, AVG(crime_count/population) FROM neighborhoods GROUP BY name;
# --------------
# SELECT cd.community_name, ct.crime_type, AVG(cd.response_time) as avg_response_time FROM community_districts cd JOIN crime_data cd ON cd.cd_number = cd.cd_number JOIN (SELECT crime_type, cd_number, COUNT(*) as count FROM crime_data WHERE crime_date >= CURDATE() - INTERVAL 1 MONTH GROUP BY crime_type, cd_number ORDER BY count DESC LIMIT 5) ct ON cd.cd_number = ct.cd_number GROUP BY cd.community_name, ct.crime_type;
# --------------
# SELECT maintenance_cost(maintenance_cost) FROM equipment_maintenance WHERE equipment_type = 'Type A' AND maintenance_date BETWEEN '2022-01-01' AND '2022-12-31' INTERSECT SELECT maintenance_cost(maintenance_cost) FROM equipment_maintenance WHERE equipment_type = 'Type B' AND maintenance_date BETWEEN '2022-01-01' AND '2022-12-31';
# --------------
# SELECT event FROM defense_diplomacy WHERE country1 = 'China' AND country2 = 'India' AND year BETWEEN 2005 AND 2010;
# --------------
# SELECT SUM(capacity) FROM vessels WHERE registry = 'Hong Kong';
# --------------
# SELECT name FROM suppliers WHERE country = 'Germany';
# --------------
# SELECT tech_name, capabilities FROM military_tech WHERE region = 'North America';
# --------------
# DELETE FROM music_genres WHERE genre = 'Hip-Hop' AND YEAR(event_date) = 2019;
# --------------
# SELECT AVG(song_length) FROM songs JOIN artists ON songs.artist_id = artists.artist_id WHERE artists.country = 'United States';
# --------------
# SELECT COUNT(*) FROM (SELECT DonorID FROM Donations WHERE Amount > 100 GROUP BY DonorID HAVING COUNT(*) > 1);
# --------------
# SELECT AVG(DonationAmount) FROM Donations WHERE DonorName LIKE 'S%';
# --------------
# SELECT AVG(donation_amount) FROM Donations d JOIN Donors don ON d.donor_id = don.donor_id WHERE program_id IN (SELECT program_id FROM Programs WHERE category = 'health') AND YEAR(donation_date) = 2022 AND QUARTER(donation_date) = 2 AND donor_id NOT IN (SELECT donor_id FROM Donors WHERE last_donation_date < donation_date);
# --------------
# SELECT student_id, course_id, COUNT(course_id) OVER (PARTITION BY student_id ORDER BY completion_date) as completed_courses FROM lifelong_learning WHERE student_id = 2;
# --------------
# SELECT Name FROM TopTeachers;
# --------------
# SELECT district_id, AVG(mental_health_score) as avg_mental_health FROM student_mental_health GROUP BY district_id ORDER BY avg_mental_health DESC;
# --------------
# SELECT SUM(Salary) FROM Employees;
# --------------
# INSERT INTO energy_storage (id, region, year, capacity) VALUES (1, 'Sao Paulo', 2027, 9000);
# --------------
# SELECT SUM(generation) FROM energy_generation WHERE country IN ('Kenya', 'Nigeria', 'South Africa') AND source_type IN ('Solar', 'Wind') AND generation_date BETWEEN '2021-01-01' AND '2021-03-31';
# --------------
# SELECT COUNT(*) FROM wells WHERE region IN ('Permian Basin', 'Marcellus Shale') AND well_type = 'Gas' AND status = 'Producing';
# --------------
# SELECT t.team_name, (SUM(g.won) * 100.0 / (SELECT COUNT(*) FROM games WHERE team_id = t.team_id AND season_id = (SELECT MAX(season_id) FROM teams))) AS win_percentage FROM teams t JOIN games g ON t.team_id = g.team_id WHERE t.season_id = (SELECT MAX(season_id) FROM teams) GROUP BY t.team_name ORDER BY win_percentage DESC LIMIT 1;
# --------------
# SELECT name, home_runs FROM baseball_stats ORDER BY home_runs DESC LIMIT 1;
# --------------
# SELECT SUM(amount) FROM Funding INNER JOIN Organization ON Funding.organization_id = Organization.id WHERE Organization.country = 'India';
# --------------
# SELECT MAX(fare) FROM urban.trams WHERE fare >= 2;
# --------------
# SELECT SUM(revenue) FROM routes WHERE route_name = 'Red Line';
# --------------
# SELECT AVG(delivery_time) FROM orders WHERE country = 'Italy' AND eco_friendly = TRUE;
# --------------
# SELECT SUM(income) AS total_income, SUM(expenses) AS total_expenses FROM FinancialWellbeingPrograms WHERE country = 'Australia';
# --------------
# SELECT donor_age_group, SUM(donation_amount) FROM (SELECT CASE WHEN donor_age < 30 THEN 'Minor' WHEN donor_age BETWEEN 30 AND 60 THEN 'Regular' ELSE 'Senior' END AS donor_age_group, donation_amount FROM donors WHERE EXTRACT(YEAR FROM donation_date) = 2021) GROUP BY donor_age_group;
# --------------
# SELECT AVG(weight) FROM packages WHERE shipped_date >= DATE_SUB(CURRENT_DATE, INTERVAL 1 YEAR) AND region = 'Africa';
# --------------
# SELECT SUM(weight) FROM parcels JOIN shipments ON parcels.shipment_id = shipments.id WHERE source_airport = 'FRA' AND destination_airport = 'ICN' AND shipped_date BETWEEN '2022-03-01' AND '2022-03-31';
# --------------
# DELETE FROM genetic_research_experiments WHERE experiment_date < '2010-01-01';
# --------------
# SELECT name FROM projects WHERE location = 'Spain' AND biosensor_used = true;
# --------------
# UPDATE programs SET budget = 30000000 WHERE id = 1 AND state = 'Florida';
# --------------
# SELECT committee_name FROM committees WHERE members < 5 ORDER BY members ASC;
# --------------
# SELECT MAX(salary) FROM faculty WHERE department='Physics' AND rank='Professor';
# --------------
# SELECT Region, (CommunityHealthWorkerCount / MentalHealthProfessionalCount) AS Ratio FROM (SELECT Region, COUNT(*) AS CommunityHealthWorkerCount, (SELECT COUNT(*) FROM HealthWorkers WHERE WorkerType = 'MentalHealthProfessional' AND Region = HealthWorkers.Region) AS MentalHealthProfessionalCount FROM HealthWorkers WHERE WorkerType = 'CommunityHealthWorker' GROUP BY Region);
# --------------
# SELECT COUNT(*) FROM MentalHealthParity WHERE Region = 'Southwest' AND YEAR(ReportDate) = 2020;
# --------------
# SELECT SUM(bookings) FROM accommodations WHERE city = 'Barcelona' AND is_eco_friendly = true;
# --------------
# SELECT AVG(bookings) FROM ai_bookings WHERE quarter = 'Q2 2022' AND region = 'North America';
# --------------
# SELECT s.name FROM researcher_species rs JOIN researchers r ON r.id = rs.researcher_id JOIN species s ON s.id = rs.species_id WHERE r.name = 'Agnes Sorensen';
# --------------
# SELECT COUNT(*) FROM Green_Infrastructure WHERE location = 'Park';
# --------------
# SELECT city, AVG(price) FROM Hotels_Europe GROUP BY city;
# --------------
# SELECT project_name FROM marine_research_projects;
# --------------
# SELECT MIN(min_depth) FROM coral_species WHERE region = 'Caribbean';
# --------------
# SELECT 100.0 * COUNT(*) / (SELECT COUNT(*) FROM videos WHERE topic = 'disinformation detection') as percentage FROM videos WHERE topic = 'disinformation detection' AND creator_type = 'independent';
# --------------
# SELECT (COUNT(*) * 100.0 / (SELECT COUNT(*) FROM Employees)) AS Percentage FROM Employees WHERE Gender = 'Female' AND Position = 'Manager';
# --------------
# SELECT * FROM network_towers WHERE city = 'Los Angeles' AND latitude BETWEEN -118.4 AND -118.3;
# --------------
# SELECT AVG(word_count) FROM (SELECT a.id, COUNT(w.word) AS word_count FROM articles a INNER JOIN words w ON a.id = w.article_id WHERE a.newspaper = 'The Wall Street Journal' AND a.category = 'Business' GROUP BY a.id) t;
# --------------
# SELECT MIN(conservation_score) FROM marine_protected_areas WHERE region = 'Mediterranean';
# --------------
# SELECT COUNT(*) FROM deep_sea_exploration WHERE ocean = 'Southern Ocean';
# --------------
# SELECT region, COUNT(*) FROM marine_species GROUP BY region;
# --------------
# DELETE FROM esports_teams WHERE region = 'Asia';
# --------------
# SELECT MIN(PlayerLevel) FROM Players WHERE Game = 'CS:GO';
# --------------
# SELECT SUM(fine_amount) FROM fines WHERE fine_city = 'Houston' AND YEAR(fine_date) = 2019;
# --------------
# SELECT DISTINCT producer FROM production WHERE element = 'Gadolinium' ORDER BY producer;
# --------------
# SELECT City FROM AffordableHousing WHERE OccupancyRate < 0.8;
# --------------
# SELECT person.name FROM person INNER JOIN property ON person.id = property.owner_id WHERE price > (SELECT AVG(price) FROM property);
# --------------
# SELECT country, (SUM(consumption) FILTER (WHERE year BETWEEN 2018 AND 2022) OVER (PARTITION BY country)::DECIMAL / SUM(consumption) OVER (PARTITION BY country)) * 100 AS pct_renewable FROM SEA_Renewable_Energy;
# --------------
# SELECT country, SUM(product_quantity) AS total_sales FROM sales JOIN ethical_brands ON sales.brand_id = ethical_brands.brand_id WHERE ethical_brands.product_category = 'Clothing' GROUP BY country ORDER BY total_sales DESC, country;
# --------------
# SELECT MAX(distance) FROM astrophysics_research;
# --------------
# SELECT MIN(age) FROM athletes WHERE community = 'LGBTQ+';
# --------------
# SELECT cve_id, COUNT(*) as vulnerability_count, RANK() OVER (ORDER BY vulnerability_count DESC) as vulnerability_rank FROM Vulnerabilities WHERE timestamp >= DATE_SUB(CURRENT_TIMESTAMP, INTERVAL 1 MONTH) GROUP BY cve_id ORDER BY vulnerability_rank;
# --------------
# SELECT org_id, AVG(DATEDIFF(vuln_remediation_date, vuln_report_date)) as avg_time_to_remediate FROM vulnerabilities WHERE vuln_severity = 'high' GROUP BY org_id;
# --------------
# SELECT * FROM user_accounts WHERE region = 'Europe' AND account_created >= DATE_SUB(CURRENT_DATE, INTERVAL 1 WEEK);
# --------------
# SELECT COUNT(*) FROM Autonomous_Vehicles WHERE year IN (2021, 2022) AND average_speed > 40;
# --------------
# SELECT AVG(occupancy_rate) FROM public_transportation_occupancy WHERE city = 'Seoul';
# --------------
# SELECT DATE(start_time) AS day, COUNT(*) AS usage FROM london_bikes WHERE city = 'London' GROUP BY day;
# --------------
# DELETE FROM Policy WHERE PolicyID NOT IN (SELECT PolicyID FROM Claims WHERE PolicyID = Policy.PolicyID AND ClaimDate > DATEADD(month, -24, GETDATE()) AND PolicyType = 'Renters');
# --------------
# SELECT COUNT(*) FROM technology_unions WHERE salary > 80000.00;
# --------------
# SELECT current_capacity FROM landfill_capacity WHERE region = 'North America';
# --------------
# SELECT country, MIN(landfill_capacity) FROM LandfillCapacity WHERE region = 'European Union' GROUP BY country;
# --------------
# SELECT city, (SUM(waste) / population) * 100000 FROM WasteGeneration GROUP BY city;
# --------------
# SELECT COUNT(*) FROM drought_impact WHERE (year = 2019 OR year = 2020) AND impact_level != 'none';
# --------------
# SELECT DISTINCT region, initiative_name FROM conservation_initiatives;
# --------------
# SELECT MIN(Duration), Gender FROM Workout INNER JOIN Member ON Workout.MemberID = Member.MemberID WHERE YEAR(MembershipStart) = 2019 GROUP BY Gender;
# --------------
# SELECT MONTH(JoinDate) AS Month, Gender, COUNT(*) AS NumberOfMembers FROM Members GROUP BY Month, Gender;
# --------------
# SELECT workout_type, SUM(fee) FROM workout_fees GROUP BY workout_type;
# --------------
# SELECT airline, COUNT(*) FROM FlightOperations WHERE operated_date >= DATEADD(month, -1, GETDATE()) GROUP BY airline;
# --------------
# SELECT country, COUNT(*) FROM aerospace.satellites GROUP BY country;
# --------------
# SELECT sanctuary_name, SUM(animal_count) AS total_animals FROM animal_sanctuary GROUP BY sanctuary_name ORDER BY total_animals DESC;
# --------------
# SELECT SUM(quantity) FROM seafood_exports_v2 WHERE export_country = 'US' AND import_country = 'China' AND EXTRACT(YEAR FROM export_date) = 2020 AND unit_type = 'ton';
# --------------
# INSERT INTO audience (visitor_id, name, country, visit_date) VALUES ((SELECT MAX(visitor_id) FROM audience) + 1, 'Alex', 'USA', CURRENT_DATE);
# --------------
# SELECT AVG(project_timeline_weeks) FROM Projects WHERE area_type = 'urban';
# --------------
# INSERT INTO cannabis_production (strain, yield) VALUES ('Gelato', 500);
# --------------
# SELECT plants.plant_name FROM plants INNER JOIN emissions ON plants.plant_id = emissions.plant_id WHERE emissions.emission_level > (SELECT MAX(emission_limit) FROM allowed_emissions) AND emissions.emission_date >= DATEADD(year, -1, GETDATE());
# --------------
# SELECT Percentage FROM Health_Insurance WHERE Country = 'United States';
# --------------
# SELECT COUNT(*) FROM startups WHERE industry = 'Transportation' AND founder_community = 'Underrepresented';
# --------------
# SELECT name FROM smart_contracts WHERE developer_country IN ('Germany', 'France', 'USA');
# --------------
# SELECT asset_name, trading_volume FROM digital_assets WHERE region = 'Europe' ORDER BY trading_volume DESC LIMIT 5;
# --------------
# SELECT digital_asset, SUM(transaction_count) as total_transactions, SUM(trading_volume) as total_volume FROM decentralized_exchanges GROUP BY digital_asset;
# --------------
# INSERT INTO timber_production (region, year, volume) VALUES ('Southeast', 2018, 1200), ('Southeast', 2019, 1500), ('Southeast', 2020, 1800);
# --------------
# SELECT * FROM forest_management WHERE age > 50;
# --------------
# SELECT * FROM cosmetics INNER JOIN ingredient_sourcing ON cosmetics.product_id = ingredient_sourcing.ingredient_id WHERE cosmetics.product_type = 'Foundation' AND ingredient_sourcing.sourcing_country != 'USA';
# --------------
# SELECT i.name FROM ingredients i JOIN country_biodiversity cb ON i.sourcing_country = cb.country WHERE cb.biodiversity_index > 80;
# --------------
# SELECT AVG(threat_score) FROM threat_intelligence WHERE threat_region = 'Pacific' AND threat_date >= DATEADD(month, -1, GETDATE());
# --------------
# SELECT contractor, COUNT(*) as contract_count FROM contract_timeline WHERE contract_date >= DATEADD(month, -12, CURRENT_DATE) GROUP BY contractor ORDER BY contract_count DESC;
# --------------
# SELECT SUM(amount) FROM defense_spending WHERE continent = 'Oceania' AND year = 2018;
# --------------
# SELECT customer_id, AVG(amount) as avg_daily_amount FROM transactions WHERE transaction_date >= DATEADD(quarter, -1, GETDATE()) GROUP BY customer_id;
# --------------
# SELECT COUNT(DISTINCT destination) FROM cargo_handling WHERE cargo_id IN (SELECT cargo_id FROM regulatory_compliance);
# --------------
# SELECT COUNT(*) FROM factories WHERE industry = 'pharmaceutical' AND region = 'South America' AND ethical_manufacturing = TRUE;
# --------------
# SELECT factories.factory_id, AVG(factories.total_salary) FROM factories INNER JOIN workforce_development ON factories.factory_id = workforce_development.factory_id GROUP BY factories.factory_id;
# --------------
# SELECT SUM(waste_generated) FROM waste WHERE industry = 'electronics' AND region = 'Africa';
# --------------
# DELETE FROM ExcavationSite WHERE NumArtifacts < 10;
# --------------
# UPDATE hospitals SET address = '456 Elm St' WHERE id = 123;
# --------------
# SELECT SUM(healthcare_expenditure) FROM rural_counties WHERE state IN (SELECT state FROM rural_counties WHERE healthcare_expenditure IS NOT NULL GROUP BY state HAVING COUNT(*) > 5);
# --------------
# SELECT * FROM investments WHERE sector = 'renewable_energy' ORDER BY risk_score;
# --------------
# SELECT * FROM military_tech WHERE YEAR(tech_date) = 2020;
# --------------
# SELECT album, SUM(streams) AS total_streams FROM AlbumStreaming WHERE genre = 'jazz' GROUP BY album ORDER BY total_streams DESC LIMIT 5;
# --------------
# SELECT DonorID, SUM(DonationAmount) as TotalDonation FROM Donations WHERE DonationDate >= DATEADD(day, -30, GETDATE()) GROUP BY DonorID ORDER BY TotalDonation DESC FETCH FIRST 5 ROWS ONLY;
# --------------
# SELECT program_id, MAX(amount) FROM donations GROUP BY program_id;
# --------------
# SELECT SUM(D.Amount) as TotalDonation FROM Donations D WHERE D.ProgramID = (SELECT P.ProgramID FROM Programs P WHERE P.Name = 'Education');
# --------------
# CREATE VIEW TopTeachers AS SELECT Name, Subject FROM Teachers WHERE Subject = 'Science';
# --------------
# DELETE FROM Employees WHERE Salary > 80000.00;
# --------------
# SELECT DISTINCT country FROM oil_rigs WHERE status = 'active';
# --------------
# SELECT stadium_name, capacity FROM stadiums WHERE capacity > 70000;
# --------------
# SELECT player_name, MAX(assists) FROM players WHERE team_name = 'Heat' AND season_start_year = 2017 AND season_end_year = 2018;
# --------------
# SELECT e.name, e.country FROM social_enterprises e JOIN grants g ON e.id = g.social_enterprises_id WHERE g.grant_date >= DATE_SUB(CURRENT_DATE, INTERVAL 3 YEAR);
# --------------
# SELECT DISTINCT city FROM conferences c JOIN ethical_ai_topics t ON c.id = t.conference_id WHERE t.title LIKE '%ethical AI%';
# --------------
# SELECT EXTRACT(MONTH FROM first_order_date) AS month, COUNT(*) FILTER (WHERE EXTRACT(MONTH FROM first_order_date) = EXTRACT(MONTH FROM last_order_date)) AS new_customers, COUNT(*) FILTER (WHERE EXTRACT(MONTH FROM first_order_date) <> EXTRACT(MONTH FROM last_order_date)) AS returning_customers FROM customer WHERE first_order_date >= '2021-01-01' AND last_order_date <= '2021-12-31' GROUP BY month;
# --------------
# SELECT continent, COUNT(*) * 100.0 / (SELECT COUNT(*) FROM factories) as percentage FROM factories WHERE uses_renewable_energy = TRUE GROUP BY continent;
# --------------
# SELECT c.name, COUNT(up.post_id) as posts_about_topic FROM user_posts up JOIN categories c ON up.category_id = c.id WHERE c.name LIKE '%environmental conservation%' GROUP BY up.category_id ORDER BY posts_about_topic DESC LIMIT 3;
# --------------
# SELECT AVG(amount) FROM shariah_compliant_loans WHERE region IN ('Middle East', 'Africa');
# --------------
# SELECT COUNT(*) FROM financial_institutions WHERE country IN ('UAE', 'Egypt') AND is_shariah_compliant = true;
# --------------
# SELECT name, manager FROM programs WHERE budget > 50000.00;
# --------------
# SELECT City, SUM(DonationAmount) FROM Donations WHERE DonationDate >= DATEADD(month, -6, GETDATE()) GROUP BY City;
# --------------
# SELECT MAX(quantity) FROM DELIVERY_RECORDS WHERE is_organic = true;
# --------------
# SELECT department, SUM(amount) FROM funding WHERE year = 2021 GROUP BY department;
# --------------
# UPDATE mental_health_diagnosis M SET training_completion_date = (SELECT training_date FROM cultural_competency_training C WHERE C.patient_id = M.patient_id LIMIT 1);
# --------------
# SELECT AVG(revenue) FROM revenues WHERE is_sustainable = true;
# --------------
# SELECT year, SUM(emissions) FROM CO2Emissions WHERE country = 'Canada' GROUP BY year;
# --------------
# SELECT name, language FROM heritage_sites;
# --------------
# INSERT INTO patients (id, name, age, gender) VALUES (1, 'Dr. Rajesh Patel', 55, 'Male');
# --------------
# SELECT COUNT(DISTINCT patient_id) FROM treatments WHERE country = 'Spain' AND YEAR(treatment_date) = 2020;
# --------------
# SELECT name FROM dam WHERE province = 'Quebec' AND max_exceeded = 1;
# --------------
# SELECT COUNT(*) FROM attractions WHERE country = 'Japan' AND wheelchair_accessibility > 4;
# --------------
# SELECT District, COUNT(*) FROM ADRPrograms WHERE YearEstablished BETWEEN 2010 AND 2020 GROUP BY District;
# --------------
# SELECT MAX(speed_limit) FROM maritime_laws WHERE region = 'Bering Sea';
# --------------
# SELECT MAX(max_depth) FROM ocean_floor_mapping;
# --------------
# SELECT COUNT(*) FROM maritime_law_compliance WHERE region = 'Caribbean' AND compliant = FALSE;
# --------------
# SELECT COUNT(*) FROM Pollution_Incidents WHERE location = 'Atlantic Ocean' AND year >= 2010;
# --------------
# SELECT SUM(CASE WHEN character_gender = 'female' THEN lines ELSE 0 END) + SUM(CASE WHEN character_gender = 'male' THEN lines ELSE 0 END) FROM lines;
# --------------
# SELECT project_name FROM DefenseProjects WHERE end_date < '2021-01-01';
# --------------
# SELECT location, COUNT(*) FROM mining_sites WHERE extraction_rate > (SELECT AVG(extraction_rate) FROM mining_sites) GROUP BY location;
# --------------
# UPDATE MiningEmployees SET EmployeeCount = 350 WHERE State = 'California' AND EmployeeEthnicity = 'Native Hawaiian or Pacific Islander';
# --------------
# SELECT province, MAX(num_employees) AS max_employees, MIN(num_employees) AS min_employees FROM mining_operations GROUP BY province;
# --------------
# SELECT i.tech_type, COUNT(s.id) as total_subscribers FROM subscribers s INNER JOIN infrastructure i ON s.technology = i.tech_type GROUP BY i.tech_type;
# --------------
# SELECT region, AVG(data_usage) FROM mobile_subscribers GROUP BY region;
# --------------
# SELECT o.operator_name, DATE_FORMAT(u.usage_date, '%Y-%m') as month, AVG(u.usage_amount) FROM mobile_plans p JOIN mobile_operators o ON p.operator_id = o.operator_id JOIN usage u ON p.plan_id = u.plan_id GROUP BY o.operator_name, month;
# --------------
# SELECT monthly_spending FROM broadband_customers WHERE customer_id = 1;
# --------------
# SELECT SUM(US.StreamCount) FROM UserStreams US JOIN Songs S ON US.SongID = S.SongID JOIN UserLocation UL ON US.UserID = UL.UserID WHERE S.Genre = 'Afrobeats' AND UL.Country = 'Nigeria' AND QUARTER(US.StreamDate) = 1 AND YEAR(US.StreamDate) = 2022;
# --------------
# INSERT INTO volunteers (id, organization_id, name) VALUES (1, (SELECT id FROM organizations WHERE name = 'Doctors Without Borders'), 'Fatima Ahmed'), (2, (SELECT id FROM organizations WHERE name = 'Doctors Without Borders'), 'Sophia Lee'), (3, (SELECT id FROM organizations WHERE name = 'Doctors Without Borders'), 'Hassan Patel');
# --------------
# SELECT name FROM oceans WHERE underwater_volcanoes = (SELECT MAX(underwater_volcanoes) FROM oceans);
# --------------
# SELECT SUM(Playtime) FROM PlayerJoinDates WHERE GameName = 'Cryptic Explorers' AND JoinDate <= '2022-12-31';
# --------------
# SELECT f.name, AVG(sm.level) FROM field f INNER JOIN soil_moisture sm ON f.id = sm.field_id WHERE sm.measurement >= DATEADD(week, -1, GETDATE()) GROUP BY f.name;
# --------------
# SELECT MIN(temperature) FROM Greenhouse7 WHERE EXTRACT(MONTH FROM date) = 9;
# --------------
# SELECT COUNT(*) FROM lutetium_transactions WHERE element = 'Lutetium' AND price > 70 AND country IN (SELECT DISTINCT country FROM lutetium_transactions WHERE country LIKE 'E%');
# --------------
# SELECT r.name, AVG(m.carbon_footprint) FROM regions r JOIN manufacturers m ON r.id = m.region_id GROUP BY r.id;
# --------------
# SELECT MIN(Price) FROM Products JOIN Stores ON Products.StoreID = Stores.StoreID WHERE Category = 'Grocery' AND Country = 'USA' AND State = 'New York';
# --------------
# SELECT SUM(quantity) FROM sales WHERE business_size = 'small';
# --------------
# SELECT COUNT(DISTINCT country) FROM space_agencies;
# --------------
# SELECT mission_name, launch_date FROM missions WHERE country = 'Russia';
# --------------
# SELECT country, COUNT(*) FROM SpaceMissions GROUP BY country;
# --------------
# SELECT COUNT(*) FROM Missions WHERE agency = 'NASA';
# --------------
# INSERT INTO fans (fan_id, age, gender, country) SELECT fan_id, age, gender, country FROM new_fans;
# --------------
# SELECT team_id, total_sales FROM (SELECT team_id, SUM(total_sales) AS total_sales FROM team_performance WHERE home_game = true AND total_sales > 0 GROUP BY team_id) AS high_sales JOIN (SELECT team_id, SUM(total_sales) AS total_sales FROM team_performance WHERE home_game = true AND total_sales < 0 GROUP BY team_id) AS low_sales ON high_sales.team_id = low_sales.team_id ORDER BY total_sales DESC, high_sales.team_id;
# --------------
# SELECT COUNT(*) FROM security_incidents WHERE incident_date >= '2022-01-01' AND incident_date < '2023-01-01';
# --------------
# SELECT PolicyType, COUNT(*) as PoliciesSold FROM Policies WHERE SaleDate BETWEEN '2022-01-01' AND '2022-03-31' GROUP BY PolicyType;
# --------------
# SELECT sector, SUM(violations) as total_violations FROM union_construction WHERE sector = 'Construction' GROUP BY sector ORDER BY total_violations DESC;
# --------------
# SELECT city, (electric_vehicle_adoption_rate * 100) AS adoption_rate FROM City_Data WHERE state = 'California';
# --------------
# SELECT AVG(generation_rate) FROM WasteGeneration WHERE region = 'EMEA';
# --------------
# SELECT capacity FROM landfill_capacity WHERE region = 'East' AND year = 2020;
# --------------
# SELECT ((consumption_2018 - consumption_2017) / consumption_2017) * 100.0 FROM (SELECT consumption FROM WaterConsumptionYearly_Lima WHERE year = 2017 AND id = 1) AS t1, (SELECT consumption FROM WaterConsumptionYearly_Lima WHERE year = 2018 AND id = 1) AS t2;
# --------------
# DELETE FROM wearable_device WHERE name = 'Grace Wilson';
# --------------
# SELECT COUNT(*) FROM memberships WHERE join_date BETWEEN '2023-01-01' AND '2023-03-31';
# --------------
# SELECT * FROM members WHERE QUARTER(join_date) = 1 AND YEAR(join_date) = 2021;
# --------------
# SELECT DISTINCT m.MemberID FROM Members m WHERE m.MembershipType = 'Platinum' AND m.MemberID NOT IN (SELECT MemberID FROM Classes WHERE MONTH(ClassDate) = 1 AND YEAR(ClassDate) = 2021);
# --------------
# SELECT SUM(distance) FROM wearables WHERE device_brand = 'XYZ';
# --------------
# SELECT organization_name, COUNT(*) as incident_count FROM ai_safety GROUP BY organization_name ORDER BY incident_count DESC;
# --------------
# SELECT AVG(habitat_size) FROM animal_habitat;
# --------------
# SELECT species, SUM(deaths) FROM fish_health GROUP BY species HAVING SUM(deaths) > (SELECT AVG(deaths) FROM fish_health);
# --------------
# SELECT location, SUM(num_fish) FROM fish_stock GROUP BY location UNION ALL SELECT location, SUM(num_fish) FROM sustainable_seafood GROUP BY location;
# --------------
# SELECT e.exhibition_name, f.source_name, ef.amount FROM art_exhibitions e INNER JOIN exhibition_funding ef ON e.exhibition_id = ef.exhibition_id INNER JOIN funding_sources f ON ef.source_id = f.source_id;
# --------------
# SELECT CASE WHEN age < 30 THEN 'Under 30' ELSE '30 and over' END as age_group, COUNT(*) as user_count FROM SPOTIFY_USERS WHERE premium = true GROUP BY age_group;
# --------------
# SELECT country, SUM(count) FROM country_movies WHERE genre IN ('action', 'comedy') GROUP BY country ORDER BY SUM(count) DESC;
# --------------
# SELECT DATE_FORMAT(violation_date, '%Y-%m') as quarter, COUNT(*) as num_violations FROM compliance_violations WHERE YEAR(violation_date) = 2021 GROUP BY quarter;
# --------------
# SELECT campaign_name, budget FROM climate_communication_campaigns WHERE region = 'Asia' AND budget > 1000000.00 AND focus = 'Mitigation';
# --------------
# SELECT MAX(Amount) FROM ClimateAid WHERE Community IN (SELECT DISTINCT Community FROM ClimateAid WHERE Country = 'Amazon');
# --------------
# SELECT a.name, COUNT(m.id) FROM australia_territories a INNER JOIN mental_health_clinics m ON a.id = m.territory_id GROUP BY a.name;
# --------------
# SELECT founding_year, AVG(employee_count) FROM Company_Info WHERE industry = 'Technology' GROUP BY founding_year';
# --------------
# SELECT SUM(funding.amount) FROM funding JOIN founders ON funding.company_id = founders.company_id WHERE founders.gender = 'female';
# --------------
# SELECT region, size, COUNT(*) FROM farm_sizes JOIN kenyan_regions ON farm_sizes.region = kenyan_regions.region_code WHERE farm_sizes.year = 2017 GROUP BY region;
# --------------
# SELECT ImplementationYear, COUNT(*) FROM SupportPrograms WHERE Region = 'Northeast' GROUP BY ImplementationYear;
# --------------
# SELECT name FROM oceans WHERE avg_temperature = (SELECT MAX(avg_temperature) FROM oceans) AND avg_salinity = (SELECT MAX(avg_salinity) FROM oceans);
# --------------
# SELECT SUM(Weight) FROM Products WHERE Organic = TRUE AND Category_ID = 1;
# --------------
# SELECT metric_name, rating FROM community_policing;
# --------------
# SELECT city, MAX(attendance) FROM CulturalEvents WHERE date >= DATEADD(year, -1, GETDATE()) GROUP BY city;
# --------------
# INSERT INTO weapons (name, origin, status) VALUES ('Javelin', 'USA', 'in-development');
# --------------
# SELECT type FROM military_equipment WHERE country = 'Canada';
# --------------
# SELECT mi.name, mi.year FROM military_innovation mi INNER JOIN (SELECT DISTINCT country FROM military_innovation) mic ON mi.country = mic.country;
# --------------
# SELECT AVG(total_amount) FROM transactions t JOIN clients c ON t.client_id = c.client_id WHERE c.net_worth > 1000000 AND t.transaction_date BETWEEN '2023-10-01' AND '2023-12-31';
# --------------
# SELECT MIN(account_balance) FROM clients WHERE region = 'Northwest';
# --------------
# ports(port_id, port_name, country, region, location)
# WITH deleted_port AS (DELETE FROM ports WHERE port_id = 8000 RETURNING *) SELECT * FROM deleted_port;
# --------------
# SELECT COUNT(DISTINCT vessels.id) FROM vessels LEFT JOIN cargo ON vessels.id = cargo.vessel_id LEFT JOIN ports ON cargo.port_id = ports.id WHERE ports.name = 'Port of Mumbai' AND cargo.loaded_date >= '2022-06-01' AND cargo.loaded_date <= '2022-06-30' AND cargo.perishable IS NULL;
# --------------
# SELECT port_id, AVG(time_in_hours) FROM cargo_handling GROUP BY port_id;
# --------------
# SELECT material FROM WasteData WHERE waste_quantity > (SELECT avg_waste FROM IndustryAverages WHERE material = WasteData.material);
# --------------
# SELECT state, COUNT(*) AS num_hospitals_and_clinics, (SELECT COUNT(*) FROM hospitals WHERE has_ct_scan = true) * 100.0 / (SELECT COUNT(*) FROM hospitals) AS pct_hospitals_with_ct_scan FROM hospitals GROUP BY state UNION SELECT state, COUNT(*) AS num_hospitals_and_clinics, (SELECT COUNT(*) FROM clinics) * 100.0 / (SELECT COUNT(*) FROM clinics) AS pct_hospitals_with_ct_scan FROM clinics GROUP BY state;
# --------------
# SELECT country, COUNT(*) FROM green_energy_funding WHERE funding_date >= DATEADD(month, -3, GETDATE()) GROUP BY country;
# --------------
# DROP TABLE EmployeeDemographics;
# --------------
# DELETE FROM fields WHERE field_name LIKE '%Field%' AND region = 'Gulf of Mexico';
# --------------
# SELECT DATE_FORMAT(post_date, '%Y-%m') as month, platform, COUNT(*) as num_posts FROM social_media_posts WHERE post_text LIKE '%ethical AI%' GROUP BY month, platform;
# --------------
# DELETE FROM fares WHERE rider_id = (SELECT rider_id FROM riders WHERE name = 'John Smith');
# --------------
# SELECT COUNT(*) FROM bus_trips WHERE borough = 'NYC' AND trip_date BETWEEN '2022-01-01' AND '2022-03-31';
# --------------
# SELECT size, COUNT(*) FROM products INNER JOIN size_ranges ON products.size = size_ranges.size GROUP BY size;
# --------------
# SELECT * FROM (SELECT *, ROW_NUMBER() OVER (PARTITION BY category ORDER BY likes DESC) rn FROM posts) t WHERE t.rn = 3 AND t.category = 'sports';
# --------------
# SELECT AVG(comments_count) FROM social_media_posts;
# --------------
# SELECT AVG(price) FROM textile_sourcing WHERE material = 'cotton' AND country = 'United States';
# --------------
# SELECT customer_id, COUNT(*) as purchase_count FROM CustomerOrders WHERE product = 'Sustainable Clothing' AND order_date >= DATE_SUB(CURRENT_DATE, INTERVAL 6 MONTH) GROUP BY customer_id ORDER BY purchase_count DESC LIMIT 1;
# --------------
# SELECT DATE_FORMAT(VolunteerDate, '%Y-%m') AS Month, ProgramID, SUM(Hours) FROM Volunteers WHERE YEAR(VolunteerDate) = YEAR(CURRENT_DATE) GROUP BY Month, ProgramID;
# --------------
# SELECT SUM(calories) FROM Dishes WHERE dish_name LIKE 'HealthyHarvest%' AND price > (SELECT AVG(price) FROM Dishes WHERE dish_name LIKE 'HealthyHarvest%');
# --------------
# ...
# --------------
# SELECT b.name, COUNT(p.id), SUM(p.area_size) FROM boroughs b JOIN parks p ON b.id = p.borough_id GROUP BY b.id;
# --------------
# SELECT COUNT(*) FROM (SELECT program FROM students WHERE publications > 1 AND program = 'Arts' GROUP BY program) AS subquery;
# --------------
# SELECT COUNT(*) FROM Cultural_Heritage_Sites WHERE country_id IN (SELECT country_id FROM Countries WHERE name IN ('Japan', 'Spain'));
# --------------
# SELECT SUM(revenue) FROM tourism_activities WHERE country = 'Indonesia';
# --------------
# SELECT hotels.name, SUM(hotel_revenue.revenue) FROM hotels INNER JOIN hotel_revenue ON hotels.id = hotel_revenue.hotel_id GROUP BY hotels.id;
# --------------
# SELECT region, AVG(id) FROM HeritageSites GROUP BY region;
# --------------
# SELECT MAX(cost) FROM infrastructure_development;
# --------------
# SELECT ((visitors_2021 - visitors_2020) / visitors_2020) * 100.0 FROM (SELECT SUM(visitors) AS visitors_2020 FROM visitor_stats WHERE year = 2020) AS t1, (SELECT SUM(visitors) AS visitors_2021 FROM visitor_stats WHERE year = 2021) AS t2;
# --------------
# SELECT COUNT(*) FROM justice_data.court_hearings WHERE defendant_race IN ('Hispanic', 'Latino');
# --------------
# SELECT COUNT(*) FROM whale_sightings WHERE species = 'Whale' AND EXTRACT(MONTH FROM sighting_date) BETWEEN 7 AND 9 AND EXTRACT(YEAR FROM sighting_date) = 2021 AND location = 'North Atlantic';
# --------------
# SELECT menu_category, SUM(quantity) as total_quantity FROM orders GROUP BY menu_category ORDER BY total_quantity DESC LIMIT 3;
# --------------
# SELECT AVG(rating) FROM ratings WHERE is_gluten_free = true;
# --------------
# SELECT COUNT(*) FROM risk_assessments WHERE region = 'Asia-Pacific' AND risk_level = 'High';
# --------------
# SELECT SUM(sale_value) FROM military_sales WHERE country = 'India' AND YEAR(sale_date) = 2021;
# --------------
# SELECT MAX(production_volume) FROM mines WHERE location = 'Indonesia' AND product = 'Tin';
# --------------
# SELECT mine_name, production_tons FROM gold_mines WHERE country = 'Australia' AND production_tons = (SELECT MAX(production_tons) FROM gold_mines WHERE country = 'Australia');
# --------------
# SELECT name FROM (SELECT name, ROW_NUMBER() OVER (ORDER BY num_employees DESC) as rn FROM mining_operations) tmp WHERE rn <= 5;
# --------------
# SELECT regional_office, COUNT(*) FROM broadband_subscribers GROUP BY regional_office;
# --------------
# SELECT AVG(total_streams) FROM music_streaming ms JOIN concert_ticket_sales cts ON ms.artist_id = cts.artist_id WHERE cts.country IN ('USA', 'Canada');
# --------------
# INSERT INTO articles (article_id, title, content, publication_date) VALUES (1, 'Media Ethics', 'This article discusses the importance of media ethics.', '2022-03-01');
# --------------
# SELECT AVG(age) FROM users INNER JOIN user_interactions ON users.user_id = user_interactions.user_id INNER JOIN articles ON user_interactions.article_id = articles.article_id WHERE articles.topic = 'climate_change';
# --------------
# SELECT AVG(satisfaction) FROM Games WHERE category = 'Gaming' AND name LIKE '%Virtual Reality%';
# --------------
# DELETE FROM games WHERE genre = 'Battle Royale';
# --------------
# SELECT COUNT(*) FROM game_designers WHERE country = 'Africa' AND genre = 'Adventure' AND players > 2000;
# --------------
# SELECT city, AVG(properties) FROM sustainable_cities GROUP BY city;
# --------------
# SELECT * FROM carbon_offset.solar_projects;
# --------------
# SELECT * FROM carbon_offset.carbon_offset_programs WHERE budget > 5000000 AND budget < 15000000;
# --------------
# INSERT INTO food_safety_inspections (restaurant_name, inspection_date, score) VALUES ('Burrito Bar', '2022-02-01', 90);
# --------------
# SELECT SUM(Revenue) FROM Pizzeria WHERE Date >= '2022-01-01' AND Date < '2022-04-01' AND Pizzeria.Name = 'Bistro A';
# --------------
# SELECT r.name, SUM(s.revenue) as total_revenue FROM restaurant_sales s JOIN restaurants r ON s.restaurant_id = r.restaurant_id WHERE s.sale_date BETWEEN '2022-04-01' AND '2022-04-30' GROUP BY r.name;
# --------------
# SELECT DISTINCT company FROM SpacecraftManufacturing SM INNER JOIN SpacecraftPilots SP ON SM.spacecraft = SP.spacecraft GROUP BY company HAVING COUNT(DISTINCT country) > 1;
# --------------
# SELECT EXTRACT(MONTH FROM sale_date) AS month, SUM(sales) AS total_sales FROM ticket_sales WHERE team_id = 1 GROUP BY month;
# --------------
# SELECT TeamID, TeamName, 100.0 * COUNT(*) / (SELECT COUNT(*) FROM TicketSales WHERE SaleDate >= '2023-01-01' AND SaleDate < '2023-04-01') as Percentage FROM TicketSales JOIN Teams ON TicketSales.TeamID = Teams.TeamID GROUP BY TeamID, TeamName ORDER BY Percentage DESC;
# --------------
# SELECT SUM(revenue) FROM merchandise_sales WHERE team_name = 'Milwaukee Bucks' AND sale_year = 2021 AND division = (SELECT division FROM TEAMS WHERE team_name = 'Milwaukee Bucks');
# --------------
# SELECT incident_type, COUNT(*) as count FROM incidents WHERE sector = 'Financial' AND incident_date >= DATEADD(year, -1, GETDATE()) GROUP BY incident_type ORDER BY count DESC FETCH FIRST 5 ROWS ONLY;
# --------------
# SELECT AVG(amount) FROM Claims INNER JOIN Auto ON Claims.policyholder_id = Auto.policyholder_id WHERE car_model = 'Corolla';
# --------------
# SELECT policy_term_length FROM policies WHERE risk_assessment_score = (SELECT MAX(risk_assessment_score) FROM policies);
# --------------
# SELECT COUNT(*) FROM safety_violations WHERE sector = 'manufacturing' AND EXTRACT(YEAR FROM violation_date) = 2021;
# --------------
# DELETE FROM cargo WHERE cargo_type = 'Chemicals' AND weight < 2000;
# --------------
# SELECT COUNT(*) FROM workouts INNER JOIN members ON workouts.user_id = members.id WHERE workout_type = 'Running' AND membership_status = 'Active';
# --------------
# SELECT * FROM (SELECT *, ROW_NUMBER() OVER (ORDER BY cost DESC) rn FROM creative_ai_projects) t WHERE rn <= 3;
# --------------
# SELECT ProjectLocation, DATE_TRUNC('year', FundingDate) AS ProjectFundingYear, AVG(FundingAmount) OVER (PARTITION BY ProjectLocation, ProjectFundingYear) AS AvgFundingAmount FROM AgriculturalInnovations WHERE LeaderGender = 'Female' AND ProjectLocation = 'Nigeria';
# --------------
# SELECT COUNT(*) FROM rural_infrastructure WHERE country IN ('Indonesia', 'Thailand', 'Philippines', 'Vietnam', 'Malaysia') AND year = 2018;
# --------------
# SELECT MissionType, LaunchYear, SUM(Cost) FROM SpaceMissions GROUP BY MissionType, LaunchYear;
# --------------
# SELECT AVG(DATEDIFF(year, establishment_date, (SELECT MIN(establishment_date) FROM feed_manufacturers WHERE manufacturer_id = fm.manufacturer_id))) AS avg_date FROM feed_manufacturers fm JOIN feed_manufacturers_continent fmc ON fm.manufacturer_id = fmc.manufacturer_id WHERE fmc.continent = 'Asia';
# --------------
# SELECT SUM(movie.revenue) FROM movie JOIN studio ON movie.studio_id = studio.studio_id WHERE studio.name = 'Blue Studios';
# --------------
# SELECT SUM(hours) FROM labor_hours WHERE year = 2018;
# --------------
# SELECT COUNT(*) FROM cases JOIN attorneys ON cases.attorney_id = attorneys.attorney_id JOIN offices ON attorneys.office_id = offices.office_id WHERE offices.city = 'Los Angeles';
# --------------
# SELECT COUNT(*) FROM (SELECT attorney_id, SUM(billing_amount) AS total_billing FROM cases GROUP BY attorney_id ORDER BY total_billing DESC LIMIT 1) AS top_attorney;
# --------------
# INSERT INTO cases (case_id, attorney_id, open_date, billing_amount) VALUES (4, (SELECT attorney_id FROM attorneys WHERE last_name = 'Johnson' AND first_name = 'Laura'), '2022-06-01', 6000);
# --------------
# DELETE FROM safety_protocols WHERE chemical_name = 'LMN';
# --------------
# SELECT p.Category, c.Name AS ChemicalName, SUM(cu.QuantityUsed) FROM ChemicalUsage cu JOIN Product p ON cu.ProductId = p.Id JOIN Chemical c ON cu.ChemicalId = c.Id GROUP BY p.Category, c.Name;
# --------------
# SELECT SUM(amount) FROM climate_finance_projects WHERE region = 'Asia' AND sector = 'afforestation' AND year < 2015;
# --------------
# SELECT SUM(funding_amount) FROM investment_rounds INNER JOIN company ON investment_rounds.company_id = company.id WHERE company.country = 'Japan' AND company.founder_veteran = TRUE;
# --------------
# SELECT industry, AVG(total_funding) FROM Companies WHERE total_funding >= 1000000 GROUP BY industry ORDER BY AVG(total_funding) DESC LIMIT 3;
# --------------
# SELECT AVG(temperature) FROM weather WHERE country = 'Brazil' AND region = 'Northeast' AND month = 1;
# --------------
# SELECT COUNT(*) FROM indigenous_food_systems WHERE country = 'Australia';
# --------------
# SELECT SUM(id) OVER () as total_assets_issued, name, issuer_country, issue_date FROM digital_assets WHERE issuer_country = 'USA' ORDER BY issue_date;
# --------------
# UPDATE products SET price = price * 1.05 WHERE country = 'United States' AND category = 'makeup';
# --------------
# SELECT SUM(price) FROM hair_care_sales WHERE is_natural = true AND country = 'USA';
# --------------
# SELECT r.region_name, c.crime_type, COUNT(c.crime_id) AS num_crimes FROM regions r JOIN districts d ON r.region_id = d.region_id JOIN crimes c ON d.district_id = c.district_id GROUP BY r.region_name, c.crime_type ORDER BY num_crimes DESC;
# --------------
# SELECT e.country, COUNT(*) as employment_count FROM veteran_employment e JOIN countries c ON e.country = c.country GROUP BY e.country ORDER BY employment_count DESC LIMIT 3;
# --------------
# UPDATE peacekeeping_operations SET troops = 850 WHERE country = 'Afghanistan' AND year = 2005;
# --------------
# SELECT port_name, SUM(cargo_weight) as total_weight FROM cargo JOIN port ON cargo.port_id = port.port_id WHERE handling_date >= '2021-01-01' AND handling_date < '2022-01-01' GROUP BY port_name ORDER BY total_weight DESC LIMIT 5;
# --------------
# SELECT Site_Name FROM Excavation_Sites WHERE Number_of_Artifacts > 2000;
# --------------
# SELECT DATE_TRUNC('quarter', completion_date) AS quarter, COUNT(*) FROM training_records WHERE training_type = 'Compliance' GROUP BY quarter;
# --------------
# SELECT name FROM tennis_players WHERE grand_slam_titles = (SELECT MAX(grand_slam_titles) FROM tennis_players);
# --------------
# SELECT i.investor_name, 100.0 * COUNT(CASE WHEN i.is_shariah_compliant THEN 1 END) / COUNT(*) as pct_shariah_compliant FROM investments i JOIN (SELECT investor_id, country, PERCENTAGE FROM (SELECT investor_id, country, PERCENTAGE() OVER (PARTITION BY investor_id ORDER BY investment_value DESC) as pct FROM investments i JOIN investors j ON i.investor_id = j.investor_id) t WHERE pct >= 70 ORDER BY pct DESC;
# --------------
# SELECT COUNT(DISTINCT donor_name) FROM Donors WHERE YEAR(first_donation_date) = 2020 AND donor_name NOT IN (SELECT donor_name FROM Donors WHERE YEAR(last_donation_date) > 2020);
# --------------
# SELECT Programs.ProgramName, MIN(Donations.DonationAmount) FROM Programs INNER JOIN Donations ON Programs.ProgramID = Donations.ProgramID GROUP BY Programs.ProgramName;
# --------------
# SELECT capacity FROM warehouse WHERE city = 'Houston';
# --------------
# SELECT AVG(amount) FROM biotech.investments WHERE investment_year = 2019;
# --------------
# SELECT initiative_name, initiative_cost FROM Initiatives WHERE initiative_type = 'Education';
# --------------
# SELECT department, gender, COUNT(*) as count, ROUND(100.0 * COUNT(*) / SUM(COUNT(*)) OVER (PARTITION BY department), 2) as percentage FROM StudentDemographics WHERE department LIKE 'Engineering%' GROUP BY department, gender;
# --------------
# SELECT d.name, (COUNT(f.id) * 100.0 / (SELECT COUNT(*) FROM faculty f WHERE f.department = d.name)) as percentage FROM faculty f RIGHT JOIN departments d ON f.department = d.name WHERE f.gender = 'Female' GROUP BY d.name;
# --------------
# SELECT SUM(capacity) FROM RenewableEnergyProjects WHERE country = 'United States';
# --------------
# SELECT Job_Title, COUNT(*) FROM CommunityHealthWorkers WHERE Language = 'Spanish' GROUP BY Job_Title;
# --------------
# SELECT e.country, AVG(e.energy_consumption / t.tourists) AS avg_energy_consumption, AVG(c.emissions / t.tourists) AS avg_carbon_emissions FROM energy_consumption e JOIN carbon_emissions c ON e.country = c.country JOIN (SELECT country, SUM(tourists) AS tourists FROM energy_consumption GROUP BY country) t ON e.country = t.country GROUP BY e.country;
# --------------
# SELECT AVG(rating) FROM eco_hotels WHERE country = 'France';
# --------------
# SELECT Artists.Name, Artists.Birthplace FROM Artists INNER JOIN Artworks ON Artists.ArtistID = Artworks.ArtistID WHERE Artworks.Genre = 'Post-Impressionism' GROUP BY Artists.Name, Artists.Birthplace ORDER BY COUNT(*) DESC LIMIT 1;
# --------------
# DELETE FROM research_projects WHERE funding_amount > 500000.00;
# --------------
# SELECT EXTRACT(MONTH FROM date) month, COUNT(*) records FROM arctic_weather GROUP BY month;
# --------------
# SELECT AVG(temperature) avg_temp, YEAR(CURDATE()) - YEAR(MIN(ar.year)) year FROM ArcticResearchLab ar GROUP BY year;
# --------------
# SELECT AVG(temperature) FROM Arctic_Research_Station_15 WHERE date = '2022-03-01';
# --------------
# SELECT state, SUM(length) FROM Highways GROUP BY state;
# --------------
# SELECT MIN(depth) FROM ocean_floor_mapping WHERE location = 'Mariana Trench';
# --------------
# SELECT e.position, COUNT(*) as num_employees FROM employee_positions ep JOIN employees e ON e.id = ep.emp_id JOIN employee_dept ed ON e.id = ed.emp_id JOIN departments d ON d.id = ed.dept_id WHERE d.name = 'drilling' GROUP BY e.position;
# --------------
# SELECT s.subscriber_id, s.name, s.mobile_contract_start_date, s.mobile_contract_end_date, s.broadband_contract_start_date, s.broadband_contract_end_date FROM subscribers s WHERE s.mobile_contract_start_date IS NOT NULL AND s.broadband_contract_start_date IS NOT NULL;
# --------------
# SELECT word, COUNT(*) as word_count FROM news WHERE category = 'Politics' GROUP BY word ORDER BY word_count DESC LIMIT 1;
# --------------
# SELECT AVG(DEPTH) FROM (SELECT DEPTH FROM TRENCHES WHERE REGION = 'Pacific Ocean' ORDER BY DEPTH DESC LIMIT 5) AS T;
# --------------
# SELECT MAX(temp) FROM temps INNER JOIN sensors ON temps.sensor_id = sensors.sensor_id WHERE sensors.location = 'Field D';
# --------------
# SELECT MIN(price) FROM price_data WHERE element = 'Promethium' AND year BETWEEN 2016 AND 2018;
# --------------
# SELECT * FROM (SELECT *, ROW_NUMBER() OVER (PARTITION BY Neighborhood ORDER BY Price, Size) rn FROM Properties WHERE Neighborhood = 'RenewableHeights' ORDER BY Price, Size) t WHERE rn <= 3;
# --------------
# SELECT AVG(size) FROM property WHERE city = 'Seattle' AND co_owned = TRUE;
# --------------
# SELECT COUNT(*) FROM threat_indicators WHERE sector = 'Energy' AND confidence > 75;
# --------------
# UPDATE cars SET fuel_type = 'conventional' WHERE year < 2010;
# --------------
# SELECT AVG(fuel_efficiency) FROM JPHybridVehicles WHERE company = 'Toyota' OR company = 'Honda';
# --------------
# SELECT SUM(quantity) FROM Fabrics WHERE year = 2020;
# --------------
# SELECT AVG(lead_time) FROM suppliers WHERE material LIKE '%eco-friendly%';
# --------------
# SELECT * FROM Claims WHERE ProcessingDate >= DATEADD(day, -60, GETDATE());
# --------------
# SELECT gender, SUM(claim_amount) FROM claims JOIN policyholders ON claims.policyholder_id = policyholders.id GROUP BY gender;
# --------------
# SELECT state FROM union_members GROUP BY state HAVING COUNT(*) = (SELECT COUNT(*) FROM union_members WHERE state = union_members.state GROUP BY state ORDER BY COUNT(*) DESC LIMIT 1);
# --------------
# SELECT COUNT(*) FROM visitor WHERE visitor_city = 'Seattle';
# --------------
# SELECT SUM(annual_waste_generation_kg) FROM organizations WHERE sector = 'urban' AND YEAR(date) = 2021;
# --------------
# SELECT Plant, MAX(Volume) FROM WasteWaterTreatment WHERE Date = '2022-02-10' GROUP BY Plant;
# --------------
# SELECT user_id, SUM(workout_duration) as total_workout_duration, COUNT(*) as number_of_workouts FROM Workouts WHERE workout_date BETWEEN '2022-01-01' AND '2022-01-31' GROUP BY user_id;
# --------------
# SELECT COUNT(*) FROM (SELECT CASE WHEN day_type = 'Weekday' THEN heart_rate END AS weekday_heart_rate, CASE WHEN day_type = 'Weekend' THEN heart_rate END AS weekend_heart_rate FROM heart_rates) AS subquery WHERE weekend_heart_rate > weekday_heart_rate;
# --------------

# %%
references
# Out:
# ["SELECT MAX(billing_amount) FROM cases JOIN attorneys ON cases.attorney_id = attorneys.attorney_id WHERE attorneys.state = 'NY' AND attorneys.win_rate > 0.8 AND cases.case_outcome = 'Won';",
#  "SELECT country, emissions FROM emissions WHERE country NOT IN ('US') ORDER BY emissions DESC LIMIT 3;",
#  'SELECT State, COUNT(*) FROM Hospitals WHERE MentalHealth = TRUE GROUP BY State;',
#  'SELECT AVG(raised_amount) as avg_investment_per_round FROM investments JOIN diversity ON investments.company_id = diversity.company_id WHERE diversity.latinx_founder = true;',
#  "SELECT COUNT(*) FROM accommodations WHERE accommodation_category = 'Online Learning';",
#  "DELETE FROM CoralReefs WHERE Health_Status = 'Degraded';",
#  "SELECT MIN(Daily_Transactions) AS Min_Transactions FROM Smart_Contracts JOIN Digital_Assets ON Smart_Contracts.Asset_ID = Digital_Assets.Asset_ID WHERE Issuer_Country IN ('Egypt', 'Nigeria', 'South Africa', 'Kenya');",
#  "SELECT status FROM regulation WHERE country = 'germany';",
#  'SELECT SUM(market_cap) AS total_market_cap FROM digital_assets WHERE asset_id IN (SELECT asset_id FROM transactions GROUP BY asset_id HAVING COUNT(*) >= 1000);',
#  "SELECT AVG(training_count/1.0) FROM DisasterPreparedness WHERE state = 'California' GROUP BY year;",
#  'SELECT artist_name, museum_name, SUM(quantity) FROM MuseumArtists GROUP BY artist_name, museum_name;',
#  "SELECT avg_attendance FROM concerts WHERE genre = 'Jazz';",
#  "INSERT INTO veteran_employment (veteran_id, name) VALUES (888, 'James Smith');",
#  "UPDATE threat_intelligence SET threat_level = 'medium' WHERE threat_source = 'United Nations' AND threat_date < '2022-01-01';",
#  "SELECT employee_id FROM employee_skills WHERE skill_name = 'sustainable_manufacturing' AND experience_years > 2;",
#  'SELECT site_name, SUM(total_artifacts) FROM excavation_sites WHERE year = 2020 GROUP BY site_name;',
#  "SELECT name FROM hospitals WHERE region = 'Northeast' ORDER BY patient_capacity ASC LIMIT 1;",
#  "INSERT INTO open_pedagogy_resources (resource_name, topic) VALUES ('Critical Thinking in Math Education', 'Mathematics Education');",
#  'SELECT Department FROM Employees GROUP BY Department HAVING COUNT(DISTINCT EmployeeID) > 1;',
#  'SELECT HireYear, Department, COUNT(*) OVER (PARTITION BY HireYear ORDER BY HireYear) AS Running_Total FROM Hiring;',
#  'SELECT sector, (SUM(efficiency) / (SELECT SUM(efficiency) FROM energy_efficiency WHERE year = 2015 AND sector = e.sector) * 100.0) - 100.0 AS improvement FROM energy_efficiency e WHERE year = 2020 GROUP BY sector;',
#  "SELECT SUM(capacity) FROM windfarm WHERE country IN ('Germany', 'France');",
#  "INSERT INTO basketball_players (player_id, player_name, position, team, country) VALUES (1, 'Marta Santiago', 'Point Guard', 'Barcelona Basquet', 'Spain');",
#  "SELECT AVG(item_count) FROM items_delivered WHERE EXTRACT(QUARTER FROM delivery_date) = 3 AND country = 'South America';",
#  "DELETE FROM accessibility_features WHERE feature_type = 'Voice Command' AND status = 'Discontinued';",
#  'SELECT year, company, COUNT(*) as num_patents FROM ai_patents GROUP BY year, company ORDER BY year;',
#  "UPDATE EthicalAIPractices SET StartDate = '2023-01-01' WHERE Project = 'AI for Children';",
#  'SELECT AVG(COUNT(*)) FROM digital_divide_projects GROUP BY completion_year;',
#  "SELECT SUM(budget) FROM accessible_tech WHERE sector = 'education';",
#  "SELECT SUM(bt.fare) FROM bus_trips bt JOIN bus_routes br ON bt.route_id = br.route_id WHERE br.starting_letter = 'B';",
#  'SELECT Brand_ID, DATEDIFF(DAY, Last_Usage_Date, GETDATE()) as Days_Since_Last_Usage FROM Brand_Sustainable_Material_Last_Usage WHERE Last_Usage_Date IS NOT NULL;',
#  'SELECT region, violations FROM labor_practices_violations GROUP BY region;',
#  'SELECT name, country, SUM(spend) as total_spend FROM african_consumers GROUP BY country ORDER BY total_spend DESC LIMIT 1;',
#  'SELECT country, COUNT(*) as num_sustainable_manufacturers FROM ManufacturerLabor WHERE has_sustainable_labor = true GROUP BY country ORDER BY num_sustainable_manufacturers DESC;',
#  "SELECT COUNT(*) FROM sales WHERE size = '2XL' AND date >= '2022-07-01' AND date <= '2022-07-31';",
#  "SELECT SUM(amount) FROM donations WHERE donor = 'Aisha' AND donation_date BETWEEN '2021-01-01' AND '2021-12-31';",
#  'SELECT COUNT(*) as TotalTransactions FROM FinancialTransactions INNER JOIN Volunteers ON FinancialTransactions.VolunteerID = Volunteers.VolunteerID;',
#  "UPDATE OrganicProducts SET name = 'Eco-friendly Product2' WHERE id = 2;",
#  "SELECT COUNT(*) FROM Inventory WHERE is_organic = TRUE AND category = 'Fruit';",
#  'SELECT carrier_name, COUNT(*) as count FROM shipment GROUP BY carrier_name;',
#  'SELECT transportation_mode, COUNT(DISTINCT item_type) as unique_item_types FROM shipments GROUP BY transportation_mode;',
#  "SELECT w.WarehouseName, COUNT(s.ShipmentID) as LateDeliveries FROM Warehouses w INNER JOIN Shipments s ON w.WarehouseID = s.WarehouseID WHERE w.Region = 'Americas' AND s.LateDelivery = 1 AND s.ShippedDate >= DATEADD(month, -1, GETDATE()) GROUP BY w.WarehouseName HAVING COUNT(s.ShipmentID) >= 25;",
#  "SELECT name, state, area_sqm FROM parks WHERE state = 'New York';",
#  "SELECT (COUNT(*) FILTER (WHERE faculty_race = 'AAPI')) * 100.0 / COUNT(*) FROM faculty_members WHERE faculty_department LIKE '%Business%';",
#  'SELECT AVG(budget) FROM green_buildings;',
#  "SELECT SUM(capacity) FROM wind_projects WHERE country = 'Germany';",
#  'SELECT city, project_type, SUM(investment_cost) FROM energy_efficient_lighting GROUP BY city, project_type HAVING SUM(investment_cost) > 1000000;',
#  "SELECT MAX(number) as max_violations FROM mental_health_parity_violations WHERE state IN ('Alabama', 'Georgia', 'Florida', 'North Carolina', 'South Carolina', 'Mississippi', 'Louisiana', 'Arkansas', 'Tennessee', 'Virginia', 'Kentucky');",
#  "SELECT city, COUNT(*) FROM asian_sites WHERE city IN ('Tokyo', 'Seoul') AND type = 'historical' GROUP BY city;",
#  "SELECT country, SUM(num_sessions) as total_sessions FROM virtual_tourism WHERE session_date BETWEEN '2023-01-01' AND '2023-03-31' GROUP BY country ORDER BY total_sessions DESC LIMIT 5;",
#  "SELECT SUM(num_engagements) FROM TourEngagements WHERE city = 'Barcelona' AND rating >= 4.5;",
#  "SELECT Artist.country_of_origin, Artwork.medium, COUNT(Artwork.artwork_id) FROM Artist INNER JOIN Artwork ON Artist.artist_id = Artwork.artist_id WHERE Artwork.genre = 'Expressionism' GROUP BY Artist.country_of_origin, Artwork.medium;",
#  "SELECT COUNT(*) FROM UNESCO_SITES WHERE region = 'Oceania';",
#  "SELECT AVG(age) FROM patients WHERE improvement = 'improved';",
#  "SELECT AVG(age) FROM patients JOIN treatments ON patients.patient_id = treatments.patient_id WHERE patients.country = 'Canada' AND treatments.treatment_type = 'Therapy';",
#  "INSERT INTO design_standards (id, name, version, description) VALUES (4, 'Bridge Design Standards for Earthquake Zones', 2022, 'New standards for bridge design in earthquake zones');",
#  'SELECT MAX(visitors) FROM gcnp_visitors;',
#  "SELECT SUM(revenue) FROM sustainable_tourism WHERE country IN ('New Zealand', 'Canada') AND year = 2022;",
#  'SELECT COUNT(DISTINCT service_type) FROM defendant_services;',
#  "SELECT species, AVG(depth) FROM underwater_species WHERE ocean IN ('Indian', 'Pacific') GROUP BY species;",
#  "UPDATE marine_sites SET max_depth = 3500 WHERE site_name = 'Research Site A';",
#  "SELECT country, pollution_level FROM CountryPollution WHERE location = 'Atlantic Ocean' AND pollution_level = (SELECT MAX(pollution_level) FROM CountryPollution WHERE location = 'Atlantic Ocean');",
#  'CREATE TABLE food_waste (waste_type VARCHAR(255), quantity INT);',
#  'SELECT C.name, COUNT(O.id) as order_frequency, RANK() OVER (ORDER BY COUNT(O.id) DESC) as rank FROM Customers C JOIN Orders O ON C.id = O.customer_id WHERE O.order_date >= DATEADD(day, -30, GETDATE()) GROUP BY C.id, C.name ORDER BY rank;',
#  "SELECT MAX(value) FROM contract_values WHERE contractor = 'Northrop Grumman' AND service = 'Geopolitical Risk Assessment';",
#  "SELECT AVG(l.productivity) AS avg_productivity FROM labor l WHERE l.department = 'coal';",
#  'SELECT continent, avg_upload_speed, avg_upload_speed/AVG(avg_upload_speed) OVER (PARTITION BY continent) as avg_upload_speed_percentage FROM avg_upload_speed_view;',
#  "SELECT MAX(data_usage) FROM subscribers WHERE region = 'urban';",
#  'SELECT countries.name AS country, COUNT(*) FROM subscribers JOIN mobile_plans ON subscribers.plan_id = mobile_plans.id JOIN broadband_plans ON subscribers.plan_id = broadband_plans.id JOIN countries ON subscribers.country = countries.id GROUP BY countries.name;',
#  'SELECT city, MAX(sales) as max_sales FROM Concerts;',
#  'SELECT DonorID, AVG(DonationAmount) OVER (PARTITION BY DonorID, EXTRACT(MONTH FROM DonationDate)) AS AvgDonationPerMonth FROM DonationAmounts WHERE EXTRACT(YEAR FROM DonationDate) = 2021 ORDER BY DonorID, DonationDate;',
#  "SELECT donor_id, AVG(COUNT(donation_id)) as avg_donations_per_month FROM donations GROUP BY donor_id, DATE_FORMAT(donation_date, '%Y-%m') WITH ROLLUP;",
#  'SELECT DISTINCT ProgramName FROM ProgramDonations;',
#  'SELECT c.cause_name, AVG(dam.donation_frequency) FROM philanthropy.causes c JOIN (SELECT cause_id, COUNT(*) AS donation_frequency FROM philanthropy.donation_amount_by_cause GROUP BY cause_id) dam ON c.cause_id = dam.cause_id GROUP BY c.cause_name;',
#  "SELECT MAX(PlaytimeMinutes) FROM CosmicRacersPlayers WHERE Rank IN ('Platinum', 'Diamond');",
#  "SELECT COUNT(DISTINCT PlayerId) FROM GamePlayer GP JOIN Player P ON GP.PlayerId = P.id WHERE GP.GameId = (SELECT G.id FROM Game G WHERE G.name = 'Fantasy') AND P.country = 'Asia';",
#  'SELECT VR_Games.GameName, Designers.DesignerName, Designers.YearsOfExperience FROM VR_Games INNER JOIN VR_GameDesign ON VR_Games.GameID = VR_GameDesign.GameID INNER JOIN Designers ON VR_GameDesign.DesignerID = Designers.DesignerID;',
#  'SELECT country, COUNT(*) as analysis_count FROM satellite_image_analysis WHERE analysis_date >= DATE_SUB(CURRENT_DATE, INTERVAL 1 MONTH) GROUP BY country ORDER BY analysis_count DESC LIMIT 3;',
#  'SELECT AVG(temperature) FROM (SELECT temperature FROM Field1_Temperature WHERE EXTRACT(MONTH FROM measurement_time) = 7 AND EXTRACT(YEAR FROM measurement_time) IN (2021, 2022) GROUP BY sensor_id, EXTRACT(DAY FROM measurement_time)) t',
#  'SELECT ct.crop_type, MAX(ct.temperature) as max_temp, MAX(ch.humidity) as max_humidity FROM crop_temperature ct JOIN crop_humidity ch ON ct.timestamp = ch.timestamp WHERE ct.timestamp BETWEEN DATEADD(month, -1, CURRENT_TIMESTAMP) AND CURRENT_TIMESTAMP GROUP BY ct.crop_type;',
#  "SELECT SUM(count) FROM Deliveries WHERE quarter = 2 AND region = 'North';",
#  "SELECT MIN(amount) FROM Budget WHERE department = 'Education' AND year = 2022;",
#  'SELECT element, MIN(quantity) FROM production WHERE year = 2019 GROUP BY element;',
#  "SELECT co_owners.name, properties.address FROM co_owners INNER JOIN properties ON co_owners.property_id = properties.id WHERE co_owners.city IN ('Portland', 'Seattle');",
#  "SELECT program_location, COUNT(*) as num_programs FROM carbon_offset_programs WHERE program_start_date BETWEEN '2020-01-01' AND '2020-12-31' AND program_location LIKE 'Asia%' GROUP BY program_location;",
#  "SELECT AVG(rating) FROM projects WHERE location = 'Germany';",
#  "SELECT project_name FROM renewable_projects WHERE location IN ('US', 'Canada');",
#  'SELECT menu_item_id, SUM(quantity_sold) as total_quantity_sold FROM menusales WHERE sale_date BETWEEN DATE_SUB(CURRENT_DATE, INTERVAL 1 MONTH) AND CURRENT_DATE GROUP BY menu_item_id ORDER BY total_quantity_sold ASC;',
#  'SELECT source, COUNT(id) as count, AVG(DATEDIFF(CURDATE(), launch_date)) as avg_years_in_orbit FROM space_debris GROUP BY source;',
#  "SELECT COUNT(*) FROM SpaceMissions WHERE status = 'Success' AND start_date < '2010-01-01';",
#  "SELECT SUM(Mass) FROM Spacecraft WHERE Manufacturer = 'SpaceX';",
#  'SELECT gender, COUNT(*) FROM fan_demographics GROUP BY gender;',
#  'SELECT COUNT(*) FROM security_incidents si JOIN users u ON si.user_id = u.user_id WHERE incident_date >= DATE_SUB(CURRENT_DATE, INTERVAL 1 YEAR) AND u.department_size > 50;',
#  "SELECT DATE(date) as trip_date, AVG(speed) as avg_speed FROM taxi_speeds WHERE taxi_type = 'Autonomous' AND city = 'New York' AND date BETWEEN DATE_SUB(CURDATE(), INTERVAL 7 DAY) AND CURDATE() GROUP BY trip_date ORDER BY trip_date;",
#  "SELECT SUM(claim_amount) FROM claims WHERE policyholder_state IN ('Utah', 'Idaho');",
#  "SELECT Underwriters.UnderwriterID, Underwriters.Region, SUM(Claims.Amount) AS TotalClaimAmount FROM Claims INNER JOIN Underwriters ON Claims.UnderwriterID = Underwriters.UnderwriterID WHERE Underwriters.Region = 'Midwest' GROUP BY Underwriters.UnderwriterID, Underwriters.Region ORDER BY TotalClaimAmount DESC LIMIT 3;",
#  'SELECT w.region, 100.0 * AVG(CASE WHEN i.injury_count = 0 THEN 1 ELSE 0 END) as pct_no_injuries FROM workplaces w LEFT JOIN injuries i ON w.id = i.workplace_id GROUP BY w.region;',
#  'DELETE FROM VehicleSafetyTesting WHERE release_year < 2010;',
#  "SELECT AVG(speed) FROM vessels WHERE port_id IN (SELECT id FROM ports WHERE country = 'USA' AND name IN ('New York', 'Savannah', 'Norfolk')) AND EXTRACT(MONTH FROM arrival_date) = 7;",
#  'SELECT vessel_id, SUM(amount) FROM regulatory_compliance GROUP BY vessel_id;',
#  'SELECT country, AVG(recycling_rate) FROM RecyclingRatesOceania WHERE year = 2021 GROUP BY country;',
#  'SELECT researcher_name FROM safety_research ORDER BY contributions DESC LIMIT 3;',
#  "SELECT SUM(cost) FROM infrastructure_projects WHERE country = 'India' AND completion_year BETWEEN 2021 AND 2022;",
#  "SELECT country, SUM(investment) FROM rural_infrastructure_projects WHERE community_type = 'Latinx' GROUP BY country;",
#  "SELECT project_id, budget FROM innovation_projects WHERE country = 'Indonesia' GROUP BY project_id ORDER BY budget DESC LIMIT 5;",
#  'SELECT farm_id, SUM(weight) over (partition by farm_id order by date) biomass FROM FishBiomass WHERE farm_id = 2;',
#  'SELECT MAX(donation_amount) FROM dance_sponsors;',
#  "SELECT AVG(DonationAmount) FROM (SELECT DonationAmount FROM Donors WHERE DonationDate BETWEEN '2021-04-01' AND '2021-06-30' AND DonorID NOT IN (SELECT DonorID FROM Donors WHERE DonationDate < '2021-04-01')) AS NewDonors;",
#  "SELECT SUM(cost) FROM Projects WHERE state = 'Texas' AND is_sustainable = true AND QUARTER(start_date) = 2 AND YEAR(start_date) = 2022 GROUP BY state;",
#  "SELECT COUNT(*) FROM cases WHERE attorney = 'Rodriguez' AND state = 'Texas' AND outcome = 'won' AND date BETWEEN '2020-01-01' AND '2020-12-31';",
#  "DELETE FROM waste_production WHERE region = 'Antarctica' AND date = '2022-01-01';",
#  "SELECT AVG(f.emissions) FROM factories f WHERE f.location = 'California';",
#  '(SELECT Protocol FROM Plant_A_Safety_Protocols EXCEPT SELECT Protocol FROM Plant_B_Safety_Protocols) UNION (SELECT Protocol FROM Plant_B_Safety_Protocols EXCEPT SELECT Protocol FROM Plant_C_Safety_Protocols) UNION (SELECT Protocol FROM Plant_C_Safety_Protocols EXCEPT SELECT Protocol FROM Plant_A_Safety_Protocols);',
#  "SELECT finance_type, SUM(amount) FROM climate_finance WHERE project_location = 'Africa' AND finance_year BETWEEN 2015 AND 2020 GROUP BY finance_type;",
#  'SELECT Finance.city FROM Finance, Mitigation WHERE Finance.city = Mitigation.city AND Finance.avg_temp > Mitigation.avg_temp',
#  "SELECT AVG(LifeExpectancy) FROM Countries WHERE Continent = 'Africa';",
#  "INSERT INTO student_disability (id, student_name, disability_type, accommodation_provided) VALUES (3, 'Jim Brown', 'Mobility Impairment', 'Wheelchair Access'), (4, 'Jake White', 'Learning Disability', 'Extra Time for Exams');",
#  "UPDATE climate_change SET avg_temp_celsius = avg_temp_celsius - 0.2, avg_temp_fahrenheit = avg_temp_fahrenheit - 0.36 WHERE region = 'Arctic Ocean';",
#  "SELECT hash, value, timestamp FROM transactions WHERE user_address = '0x456...';",
#  "SELECT name FROM regulatory_frameworks WHERE country_id = (SELECT id FROM countries WHERE name = 'Country1');",
#  'SELECT organic, COUNT(*) FROM products_organic GROUP BY organic;',
#  "SELECT AVG(price) FROM cosmetics WHERE is_vegan = TRUE AND country = 'USA';",
#  'SELECT (COUNT(*) FILTER (WHERE is_vegan = TRUE AND is_gluten_free = TRUE)) * 100.0 / COUNT(*) FROM lipsticks;',
#  "SELECT ROUND((SUM(CASE WHEN is_sustainable = true THEN sale_quantity ELSE 0 END) / SUM(sale_quantity)) * 100, 2) FROM haircare_sales WHERE sale_date BETWEEN '2021-07-01' AND '2021-09-30' AND country = 'France';",
#  'SELECT b.brand_name, AVG(p.rating) as avg_rating FROM brands b INNER JOIN products p ON b.brand_id = p.brand_id WHERE p.is_cruelty_free = TRUE GROUP BY b.brand_name ORDER BY avg_rating DESC;',
#  'SELECT name, AVG(crime_count/population) OVER (PARTITION BY name) FROM neighborhoods;',
#  'SELECT cd.community_name, ct.crime_type, AVG(cd.response_time) as avg_response_time FROM community_districts cd JOIN crime_data cd ON cd.cd_number = cd.cd_number JOIN (SELECT crime_type, cd_number, COUNT(*) as count FROM crime_data WHERE crime_date >= CURDATE() - INTERVAL 1 MONTH GROUP BY crime_type, cd_number ORDER BY count DESC LIMIT 5) ct ON cd.cd_number = ct.cd_number WHERE cd.crime_date >= CURDATE() - INTERVAL 1 MONTH GROUP BY cd.community_name, ct.crime_type;',
#  "SELECT (SUM(CASE WHEN equipment_type = 'Type A' THEN maintenance_cost ELSE 0 END) - SUM(CASE WHEN equipment_type = 'Type B' THEN maintenance_cost ELSE 0 END))/10000 FROM equipment_maintenance WHERE EXTRACT(YEAR FROM maintenance_date) = 2022;",
#  "SELECT * FROM defense_diplomacy WHERE (country1 = 'China' AND country2 = 'India') OR (country1 = 'India' AND country2 = 'China') AND year BETWEEN 2005 AND 2010;",
#  "SELECT SUM(capacity) FROM vessels WHERE registry = 'Hong Kong';",
#  "SELECT name FROM suppliers WHERE country = 'Germany';",
#  "SELECT tech_name, capabilities FROM military_tech WHERE region = 'North America';",
#  "DELETE FROM music_genres WHERE genre = 'Hip-Hop' AND YEAR(event_date) = 2019;",
#  "SELECT AVG(song_length) FROM songs INNER JOIN artists ON songs.artist_id = artists.artist_id WHERE artists.country = 'United States';",
#  'SELECT COUNT(*) FROM Donations WHERE Amount > 100;',
#  "SELECT AVG(DonationAmount) FROM Donations WHERE DonorName LIKE 'S%';",
#  "SELECT AVG(donation_amount) FROM Donations d JOIN Donors don ON d.donor_id = don.donor_id WHERE program_id IN (SELECT program_id FROM Programs WHERE category = 'health') AND donor_id IN (SELECT donor_id FROM Donors WHERE YEAR(first_donation_date) = 2022 AND first_donation_date BETWEEN '2022-04-01' AND '2022-06-30' GROUP BY donor_id HAVING COUNT(*) = 1);",
#  'SELECT student_id, course_id, COUNT(course_id) OVER (PARTITION BY student_id ORDER BY completion_date) as completed_courses FROM lifelong_learning WHERE student_id = 2;',
#  'SELECT Name FROM TopTeachers;',
#  'SELECT district_id, AVG(mental_health_score) as avg_score FROM student_mental_health GROUP BY district_id ORDER BY avg_score DESC;',
#  'SELECT SUM(Salary) FROM Employees;',
#  "INSERT INTO energy_storage (id, region, year, capacity) VALUES (3, 'Sao Paulo', 2027, 9000);",
#  "SELECT country, SUM(generation) as total_generation FROM energy_generation WHERE country IN ('Kenya', 'Nigeria', 'South Africa') AND generation_date >= '2021-01-01' AND generation_date < '2021-04-01' AND source_type IN ('Solar', 'Wind') GROUP BY country;",
#  "SELECT SUM(CASE WHEN region IN ('Permian Basin', 'Marcellus Shale') AND well_type = 'Gas' AND status = 'Producing' THEN 1 ELSE 0 END) as producing_gas_wells FROM wells;",
#  'SELECT team_id, AVG(won) * 100.0 / (SELECT COUNT(*) FROM games WHERE team_id = teams.team_id) AS win_percentage FROM games JOIN teams ON games.team_id = teams.team_id WHERE season_id = (SELECT MAX(season_id) FROM teams) GROUP BY team_id ORDER BY win_percentage DESC LIMIT 1;',
#  'SELECT name, MAX(home_runs) FROM baseball_stats;',
#  "SELECT SUM(Funding.amount) FROM Funding INNER JOIN Organization ON Funding.organization_id = Organization.id WHERE Organization.country = 'India';",
#  'SELECT MAX(fare) FROM urban.trams WHERE fare > 2;',
#  "SELECT revenue FROM routes WHERE route_name = 'Red Line';",
#  "SELECT AVG(delivery_time) FROM orders WHERE eco_friendly = TRUE AND country = 'Italy';",
#  "SELECT country, SUM(income) as total_income, SUM(expenses) as total_expenses FROM FinancialWellbeingPrograms WHERE country = 'Australia' GROUP BY country;",
#  'SELECT donor_age, SUM(donation_amount) as total_donation FROM donors WHERE YEAR(donation_date) = 2021 GROUP BY donor_age;',
#  "SELECT AVG(weight) FROM packages WHERE shipped_date >= DATE_SUB(CURRENT_DATE, INTERVAL 1 YEAR) AND destination = 'Africa';",
#  "SELECT SUM(weight) FROM parcels JOIN shipments ON parcels.shipment_id = shipments.id WHERE source_airport = 'FRA' AND destination_airport = 'ICN' AND shipped_date BETWEEN '2022-03-01' AND '2022-03-31';",
#  "DELETE FROM genetic_research_experiments WHERE experiment_date < '2010-01-01';",
#  "SELECT name FROM projects WHERE location = 'Spain' AND biosensor_used = true;",
#  "UPDATE programs SET budget = 3000000.0 WHERE id = 1 AND state = 'Florida';",
#  'SELECT committee_name FROM committees WHERE members < 5 ORDER BY members ASC;',
#  "SELECT MAX(salary) FROM faculty WHERE department='Physics' AND rank='Professor';",
#  "SELECT Region, AVG(CommunityHealthWorkerCount / MentalHealthProfessionalCount) AS Ratio FROM (SELECT Region, SUM(CASE WHEN WorkerType = 'MentalHealthProfessional' THEN Count ELSE 0 END) AS MentalHealthProfessionalCount, SUM(CASE WHEN WorkerType = 'CommunityHealthWorker' THEN Count ELSE 0 END) AS CommunityHealthWorkerCount FROM HealthWorkers GROUP BY Region) AS HealthWorkerCounts GROUP BY Region;",
#  "SELECT COUNT(*) as CountOfCases FROM MentalHealthParity WHERE Region = 'Southwest' AND YEAR(ReportDate) = 2020;",
#  "SELECT SUM(bookings) FROM accommodations WHERE city = 'Barcelona' AND is_eco_friendly = true;",
#  "SELECT region, AVG(bookings/NULLIF(hotel_id,0)) FROM ai_bookings WHERE quarter = 'Q2 2022' AND region = 'North America' GROUP BY region;",
#  "SELECT s.name FROM researcher_species rs JOIN researchers r ON r.id = rs.researcher_id JOIN species s ON s.id = rs.species_id WHERE r.name = 'Agnes Sorensen';",
#  "SELECT COUNT(*) FROM Green_Infrastructure WHERE location = 'Park';",
#  'SELECT city, AVG(price) as avg_price FROM Hotels_Europe GROUP BY city;',
#  'SELECT project_name FROM marine_research_projects;',
#  "SELECT MIN(min_depth) FROM coral_species WHERE region = 'Caribbean';",
#  "SELECT (COUNT(*) FILTER (WHERE topic = 'disinformation detection' AND creator_type = 'independent')) * 100.0 / COUNT(*) FROM videos;",
#  "SELECT (COUNT(*) * 100.0 / (SELECT COUNT(*) FROM Employees)) AS PercentageFemaleManagers FROM Employees WHERE Gender = 'Female' AND Position = 'Manager';",
#  "SELECT tower_id, city, latitude FROM network_towers WHERE city = 'Los Angeles' AND latitude BETWEEN -118.4 AND -118.3;",
#  "SELECT AVG(word_count) FROM (SELECT a.id, COUNT(w.word) AS word_count FROM articles a INNER JOIN words w ON a.id = w.article_id WHERE a.newspaper = 'The Wall Street Journal' AND a.category = 'Business' GROUP BY a.id) t;",
#  "SELECT MIN(conservation_score) FROM marine_protected_areas WHERE region = 'Mediterranean';",
#  "SELECT COUNT(*) FROM deep_sea_exploration WHERE ocean = 'Southern Ocean';",
#  'SELECT region, COUNT(*) FROM marine_species GROUP BY region;',
#  "DELETE FROM esports_teams WHERE region = 'Asia';",
#  "SELECT MIN(PlayerLevel) FROM Players WHERE Game = 'CS:GO';",
#  "SELECT SUM(fine_amount) FROM fines WHERE fine_city = 'Houston' AND YEAR(fine_date) = 2019;",
#  "SELECT DISTINCT producer FROM production WHERE element = 'Gadolinium' ORDER BY producer ASC;",
#  'SELECT City FROM AffordableHousing WHERE OccupancyRate < 0.80;',
#  'SELECT person.name FROM person INNER JOIN property ON person.id = property.owner_id WHERE price > (SELECT AVG(price) FROM property);',
#  'SELECT country, (SUM(consumption) FILTER (WHERE year BETWEEN 2018 AND 2022) OVER (PARTITION BY country)::DECIMAL / SUM(consumption) OVER (PARTITION BY country)) * 100 AS pct_renewable FROM SEA_Renewable_Energy;',
#  "SELECT country, SUM(product_quantity) AS total_sales FROM sales JOIN ethical_brands ON sales.brand_id = ethical_brands.brand_id WHERE ethical_brands.product_category = 'Clothing' GROUP BY country ORDER BY total_sales DESC, country;",
#  'SELECT MAX(distance) FROM astrophysics_research;',
#  "SELECT MIN(age) FROM athletes WHERE community = 'LGBTQ+';",
#  'SELECT cve_id, COUNT(*) as vulnerability_count, RANK() OVER (ORDER BY vulnerability_count DESC) as vulnerability_rank FROM Vulnerabilities WHERE timestamp BETWEEN DATE_SUB(CURRENT_TIMESTAMP, INTERVAL 1 MONTH) AND CURRENT_TIMESTAMP GROUP BY cve_id ORDER BY vulnerability_count DESC, severity DESC LIMIT 5;',
#  "SELECT org_id, AVG(DATEDIFF(day, vuln_report_date, vuln_remediation_date)) as avg_remediation_time FROM vulnerabilities WHERE vuln_severity = 'high' GROUP BY org_id;",
#  "SELECT username FROM user_accounts WHERE region = 'Europe' AND account_created >= DATE_SUB(NOW(), INTERVAL 1 WEEK);",
#  'SELECT COUNT(*) FROM Autonomous_Vehicles WHERE year IN (2021, 2022) AND average_speed > 40.0;',
#  "SELECT AVG(occupancy_rate) FROM public_transportation_occupancy WHERE city = 'Seoul';",
#  'SELECT DATE(start_time) AS ride_date, COUNT(DISTINCT bike_id)  FROM london_bikes GROUP BY ride_date;',
#  "DELETE FROM Policy WHERE PolicyID NOT IN (SELECT PolicyID FROM Claims WHERE PolicyID = Policy.PolicyID AND ClaimDate > DATE_SUB(CURDATE(), INTERVAL 24 MONTH) AND PolicyType = 'Renters');",
#  'SELECT COUNT(*) FROM technology_unions WHERE salary > 80000;',
#  "SELECT current_capacity FROM landfill_capacity WHERE region = 'North America';",
#  "SELECT country, MIN(landfill_capacity) FROM LandfillCapacity WHERE region = 'European Union' GROUP BY country;",
#  'SELECT wg.city, (SUM(wg.amount) / cp.population) FROM WasteGeneration wg INNER JOIN CityPopulation cp ON wg.city = cp.city AND wg.year = cp.year WHERE wg.year = 2020 GROUP BY wg.city;',
#  "SELECT COUNT(DISTINCT customer_id) as num_impacted_customers FROM drought_impact WHERE year IN (2019, 2020) AND impact_level <> 'none';",
#  'SELECT DISTINCT region, initiative_name FROM conservation_initiatives;',
#  "SELECT Member.Gender, MIN(Workout.Duration) FROM Workout INNER JOIN Member ON Workout.MemberID = Member.MemberID WHERE Member.MembershipStart BETWEEN '2019-01-01' AND '2019-12-31' GROUP BY Member.Gender;",
#  'SELECT MONTH(JoinDate), Gender, COUNT(*) FROM Members GROUP BY MONTH(JoinDate), Gender;',
#  'SELECT workouts.workout_type, SUM(workout_fees.fee) AS total_revenue FROM workouts INNER JOIN workout_fees ON workouts.workout_type = workout_fees.workout_type GROUP BY workouts.workout_type;',
#  'SELECT airline, COUNT(*) FROM FlightOperations WHERE operated_date >= DATEADD(month, -1, GETDATE()) GROUP BY airline;',
#  'SELECT country, COUNT(*) as total_satellites FROM aerospace.satellites GROUP BY country;',
#  'SELECT sanctuary_name, animal_type, SUM(animal_count) AS total_animals FROM animal_sanctuary GROUP BY sanctuary_name, animal_type WITH ROLLUP ORDER BY total_animals DESC;',
#  "SELECT SUM(quantity) FROM seafood_exports_v2 WHERE export_country = 'US' AND import_country = 'China' AND EXTRACT(YEAR FROM export_date) = 2020;",
#  "INSERT INTO audience (visitor_id, name, country, visit_date) VALUES ((SELECT MAX(visitor_id) FROM audience) + 1, 'Alex', 'USA', CURDATE());",
#  "SELECT AVG(project_timeline_weeks) FROM Projects WHERE area_type = 'urban';",
#  "INSERT INTO cannabis_production (strain, yield) VALUES ('Gelato', 500);",
#  'SELECT plants.plant_name FROM plants INNER JOIN emissions ON plants.plant_id = emissions.plant_id WHERE emissions.emission_level > (SELECT MAX(emission_limit) FROM allowed_emissions) AND emissions.emission_date >= DATE_SUB(CURDATE(), INTERVAL 1 YEAR);',
#  "SELECT Percentage FROM Health_Insurance WHERE Country = 'United States';",
#  "SELECT COUNT(*) FROM startups WHERE industry = 'Transportation' AND founder_community = 'Underrepresented';",
#  "SELECT name FROM smart_contracts WHERE developer_country IN ('Germany', 'France', 'Italy', 'Spain', 'Poland');",
#  "SELECT d.asset_name, SUM(d.trading_volume) as total_volume  FROM digital_assets d WHERE d.region = 'Europe' GROUP BY d.asset_name ORDER BY total_volume DESC LIMIT 5;",
#  'SELECT d.digital_asset, SUM(d.transaction_count) as total_transactions, SUM(d.trading_volume) as total_volume FROM decentralized_exchanges d GROUP BY d.digital_asset;',
#  "INSERT INTO timber_production (region, year, volume) VALUES ('Southeast', 2018, 1200), ('Southeast', 2019, 1500), ('Southeast', 2020, 1800);",
#  'SELECT * FROM forest_management WHERE age > 50;',
#  "SELECT * FROM cosmetics WHERE product_type = 'Foundation' AND product_id NOT IN (SELECT cosmetics.product_id FROM cosmetics INNER JOIN ingredient_sourcing ON cosmetics.product_id = ingredient_sourcing.ingredient_id WHERE ingredient_sourcing.sourcing_country = 'USA');",
#  'SELECT i.name, i.sourcing_country FROM ingredients i JOIN country_biodiversity cb ON i.sourcing_country = cb.country WHERE cb.biodiversity_index > 70;',
#  "SELECT AVG(threat_score) as avg_threat_score FROM threat_intelligence WHERE threat_region = 'Pacific' AND threat_date >= DATEADD(month, -1, GETDATE());",
#  'SELECT contractor, COUNT(*) FROM contract_timeline WHERE contract_date >= DATEADD(year, -1, CURRENT_DATE) GROUP BY contractor;',
#  "SELECT SUM(amount) FROM defense_spending WHERE continent = 'Oceania' AND year = 2018;",
#  "SELECT customer_id, AVG(amount) AS avg_daily_amount FROM transactions WHERE transaction_date >= CURRENT_DATE - INTERVAL '3 months' GROUP BY customer_id, EXTRACT(DAY FROM transaction_date), EXTRACT(MONTH FROM transaction_date), EXTRACT(YEAR FROM transaction_date) ORDER BY customer_id;",
#  'SELECT destination, COUNT(DISTINCT destination) AS dest_count FROM cargo_handling CH JOIN regulatory_compliance RC ON CH.cargo_id = RC.cargo_id GROUP BY destination HAVING COUNT(DISTINCT destination) > 1;',
#  "SELECT COUNT(*) FROM factories WHERE industry = 'pharmaceutical' AND region = 'South America' AND ethical_manufacturing = TRUE;",
#  'SELECT factories.factory_id, COUNT(factories.employees) AS total_employees, AVG(factories.total_salary) AS avg_salary FROM factories INNER JOIN workforce_development ON factories.factory_id = workforce_development.factory_id GROUP BY factories.factory_id;',
#  "SELECT SUM(waste_generated) FROM waste WHERE industry = 'electronics' AND region = 'Africa';",
#  'DELETE FROM ExcavationSite WHERE NumArtifacts < 10;',
#  "UPDATE hospitals SET address = '456 Elm St' WHERE id = '123';",
#  "SELECT county_name, SUM(healthcare_expenditure) as total_expenditure FROM rural_counties WHERE state IN ('TX', 'CA') AND YEAR(visit_date) = 2022 GROUP BY county_name;",
#  "SELECT * FROM investments WHERE sector = 'renewable_energy' ORDER BY risk_score;",
#  'SELECT * FROM military_tech WHERE YEAR(tech_date) = 2020;',
#  "SELECT album, SUM(streams) AS total_streams FROM AlbumStreaming WHERE genre = 'jazz' GROUP BY album ORDER BY total_streams DESC LIMIT 5;",
#  "SELECT DonorID, SUM(DonationAmount) AS TotalDonated FROM Donations WHERE DonationDate >= CURRENT_DATE - INTERVAL '30 days' GROUP BY DonorID ORDER BY TotalDonated DESC LIMIT 5;",
#  'SELECT program_id, MAX(amount) OVER (PARTITION BY program_id) AS max_donation_amount FROM donations;',
#  "SELECT SUM(D.Amount) as TotalDonation FROM Donations D WHERE D.ProgramID = (SELECT P.ProgramID FROM Programs P WHERE P.Name = 'Education');",
#  "CREATE VIEW TopTeachers AS SELECT Name, Subject FROM Teachers WHERE Subject = 'Science';",
#  'DELETE FROM Employees WHERE Salary > 80000;',
#  "SELECT DISTINCT country FROM oil_rigs WHERE status = 'active';",
#  'SELECT stadium_name, capacity FROM stadiums WHERE capacity > 70000;',
#  "SELECT player_name, MAX(assists) FROM players WHERE team_name = 'Heat' AND season_start_year = 2017 AND season_end_year = 2018 GROUP BY player_name;",
#  "SELECT social_enterprises.name, social_enterprises.country FROM social_enterprises INNER JOIN grants ON social_enterprises.id = grants.social_enterprises_id WHERE grants.grant_date >= DATE_SUB(CURRENT_DATE(), INTERVAL 3 YEAR) AND social_enterprises.focus = 'Digital Divide';",
#  'SELECT DISTINCT city FROM conferences JOIN ethical_ai_topics ON conferences.id = ethical_ai_topics.conference_id;',
#  "INSERT INTO customer (id, first_order_date, last_order_date) SELECT customer_id, MIN(order_date) AS first_order_date, MAX(order_date) AS last_order_date FROM orders GROUP BY customer_id; SELECT YEAR(order_date) AS year, MONTH(order_date) AS month, CASE WHEN DATEDIFF(last_order_date, first_order_date) > 30 THEN 'returning' ELSE 'new' END AS customer_type, COUNT(DISTINCT id) AS num_orders FROM orders JOIN customer ON orders.customer_id = customer.id WHERE YEAR(order_date) = 2021 GROUP BY year, month, customer_type;",
#  'SELECT continent, 100.0 * AVG(CASE WHEN uses_renewable_energy THEN 1.0 ELSE 0.0 END) AS percentage FROM factories GROUP BY continent;',
#  "SELECT c.name AS topic, COUNT(up.post_id) AS posts_about_topic FROM user_posts up JOIN categories c ON up.category_id = c.id WHERE c.name LIKE '%environmental conservation%' GROUP BY up.category_id ORDER BY posts_about_topic DESC LIMIT 3;",
#  "SELECT AVG(amount) FROM shariah_compliant_loans WHERE region IN ('Middle East', 'Africa');",
#  "SELECT COUNT(*) FROM financial_institutions WHERE is_shariah_compliant = true AND (country = 'Middle East' OR country = 'North Africa');",
#  'SELECT * FROM programs WHERE budget > 50000;',
#  "SELECT City, SUM(DonationAmount) FROM Donations WHERE DonationDate >= NOW() - INTERVAL '6 months' GROUP BY City;",
#  'SELECT MAX(quantity) FROM DELIVERY_RECORDS WHERE is_organic = true;',
#  'SELECT department, SUM(amount) as total_funding FROM funding WHERE year = 2021 GROUP BY department;',
#  'UPDATE mental_health_diagnosis M SET training_completion_date = (SELECT training_date FROM cultural_competency_training C WHERE C.patient_id = M.patient_id LIMIT 1);',
#  'SELECT AVG(revenue) FROM revenues WHERE is_sustainable = true;',
#  "SELECT year, SUM(emissions) FROM CO2Emissions WHERE country = 'Canada' GROUP BY year;",
#  'SELECT name, language FROM heritage_sites;',
#  "INSERT INTO patients (id, name, age, gender) VALUES (1, 'Jane Doe', 35, 'Female'); INSERT INTO patient_demographics (id, patient_id, race, ethnicity, zip_code) VALUES (1, 1, 'White', 'Not Hispanic or Latino', '12345');",
#  "SELECT COUNT(DISTINCT patient_id) FROM treatments JOIN patients ON treatments.patient_id = patients.patient_id WHERE patients.country = 'Spain' AND treatment_date LIKE '2020%';",
#  "SELECT name FROM dam WHERE province = 'Quebec' AND max_exceeded = 1;",
#  "SELECT COUNT(*) FROM attractions WHERE country = 'Japan' AND wheelchair_accessibility > 4;",
#  'SELECT District, COUNT(*) FROM ADRPrograms WHERE YearEstablished >= 2010 AND YearEstablished <= 2020 GROUP BY District;',
#  "SELECT speed_limit FROM maritime_laws WHERE region = 'Bering Sea';",
#  'SELECT MAX(max_depth) FROM ocean_floor_mapping;',
#  "SELECT COUNT(*) FROM maritime_law_compliance WHERE region = 'Caribbean' AND compliant = FALSE;",
#  "SELECT COUNT(*) FROM Pollution_Incidents WHERE location = 'Atlantic Ocean' AND year >= 2010;",
#  'SELECT character_gender, SUM(lines) as total_lines FROM lines WHERE movie_id = 1 GROUP BY character_gender;',
#  "SELECT project_name FROM DefenseProjects WHERE end_date > '2021-12-31';",
#  'SELECT location, COUNT(*) as mine_count FROM mining_sites WHERE extraction_rate > (SELECT AVG(extraction_rate) FROM mining_sites) GROUP BY location;',
#  "UPDATE MiningEmployees SET EmployeeCount = 350 WHERE State = 'California' AND EmployeeEthnicity = 'Native Hawaiian or Pacific Islander';",
#  'SELECT province, MAX(num_employees) AS max_employees, MIN(num_employees) AS min_employees FROM mining_operations GROUP BY province;',
#  'SELECT i.tech_type, COUNT(s.id) AS num_subscribers FROM subscribers s RIGHT JOIN infrastructure i ON s.technology = i.tech_type GROUP BY i.tech_type;',
#  'SELECT region, AVG(data_usage) AS avg_data_usage FROM mobile_subscribers GROUP BY region;',
#  'SELECT o.operator_name, AVG(u.usage_amount) AS avg_monthly_data_usage FROM mobile_operators o INNER JOIN mobile_plans p ON o.operator_id = p.operator_id INNER JOIN usage u ON p.plan_id = u.plan_id WHERE u.usage_date >= DATEADD(month, -1, GETDATE()) GROUP BY o.operator_name;',
#  'SELECT monthly_spending FROM broadband_customers WHERE customer_id = 2;',
#  "SELECT SUM(US.StreamCount) FROM UserStreams US INNER JOIN Songs S ON US.SongID = S.SongID INNER JOIN UserLocation UL ON US.UserID = UL.UserID WHERE S.Genre = 'Afrobeats' AND UL.Country = 'Nigeria' AND QUARTER(US.StreamDate) = 1 AND YEAR(US.StreamDate) = 2022;",
#  "INSERT INTO volunteers (id, organization_id, name) VALUES (5, 1, 'Mohammed Ali'), (6, 1, 'Sara Ahmed'), (7, 1, 'Pablo Rodriguez');",
#  'SELECT name FROM oceans WHERE underwater_volcanoes = (SELECT MAX(underwater_volcanoes) FROM oceans);',
#  "SELECT SUM(Playtime) FROM PlayerJoinDates WHERE GameName = 'Cryptic Explorers' AND YEAR(JoinDate) = 2022;",
#  'SELECT field_id, AVG(level) FROM soil_moisture WHERE measurement >= DATEADD(day, -7, GETDATE()) GROUP BY field_id;',
#  'SELECT MIN(temperature) FROM Greenhouse7 WHERE EXTRACT(MONTH FROM date) = 9;',
#  "SELECT COUNT(*) FROM lutetium_transactions WHERE country IN ('France', 'Germany') AND element = 'Lutetium' AND price > 70;",
#  'SELECT regions.name, AVG(manufacturers.carbon_footprint) FROM regions INNER JOIN manufacturers ON regions.id = manufacturers.region_id GROUP BY regions.name;',
#  "SELECT MIN(Products.Price) FROM Products INNER JOIN Stores ON Products.StoreID = Stores.StoreID WHERE Products.Category = 'Grocery' AND Stores.State = 'New York';",
#  "SELECT SUM(quantity) FROM sales WHERE business_size = 'small';",
#  'SELECT COUNT(*) FROM space_agencies;',
#  "SELECT mission_name, launch_date FROM missions WHERE country = 'Russia';",
#  'SELECT country, COUNT(*) AS num_missions FROM SpaceMissions GROUP BY country;',
#  "SELECT COUNT(*) FROM Missions WHERE agency = 'NASA';",
#  'INSERT INTO fans (fan_id, age, gender, country) SELECT fan_id, age, gender, country FROM new_fans;',
#  'SELECT team_id, SUM(total_sales) FROM team_performance WHERE home_game = true AND total_sales > 0 GROUP BY team_id ORDER BY SUM(total_sales) DESC, team_id;',
#  "SELECT COUNT(*) FROM security_incidents WHERE incident_date BETWEEN '2022-01-01' AND '2022-12-31';",
#  "SELECT PolicyType, COUNT(*) OVER (PARTITION BY PolicyType) as PolicyCount FROM Policies WHERE SaleDate >= '2022-01-01' AND SaleDate < '2022-04-01';",
#  "SELECT sector, SUM(violations) as total_violations FROM union_construction WHERE sector = 'Construction' GROUP BY sector ORDER BY total_violations DESC;",
#  'SELECT city, electric_vehicle_adoption_rate FROM City_Data ORDER BY electric_vehicle_adoption_rate DESC;',
#  "SELECT AVG(generation_rate) FROM WasteGeneration WHERE region = 'EMEA';",
#  "SELECT capacity FROM landfill_capacity WHERE region = 'East' AND year = 2020;",
#  'SELECT ((consumption_2018 - consumption_2017) / consumption_2017) * 100.0 FROM (SELECT consumption AS consumption_2017 FROM WaterConsumptionYearly_Lima WHERE year = 2017) AS subquery_2017 CROSS JOIN (SELECT consumption AS consumption_2018 FROM WaterConsumptionYearly_Lima WHERE year = 2018) AS subquery_2018;',
#  "WITH deleted_device AS (DELETE FROM wearable_device WHERE name = 'Grace Wilson' RETURNING *) SELECT * FROM deleted_device;",
#  "SELECT COUNT(*) FROM memberships WHERE join_date BETWEEN '2023-01-01' AND '2023-03-31';",
#  "SELECT member_id FROM members WHERE join_date BETWEEN '2021-01-01' AND '2021-03-31';",
#  "SELECT DISTINCT m.MemberID FROM Members m WHERE m.MembershipType = 'Platinum' AND m.MemberID NOT IN (SELECT MemberID FROM Classes WHERE MONTH(ClassDate) = 1 AND YEAR(ClassDate) = 2021);",
#  "SELECT SUM(distance) FROM wearables WHERE device_brand = 'XYZ';",
#  'SELECT organization_name, COUNT(*) as incidents_count FROM ai_safety GROUP BY organization_name ORDER BY incidents_count DESC;',
#  'SELECT AVG(habitat_size) FROM animal_habitat;',
#  'SELECT species, SUM(deaths) FROM fish_health GROUP BY species HAVING SUM(deaths) > (SELECT AVG(deaths) FROM fish_health);',
#  'SELECT f.location, SUM(f.num_fish + s.num_fish) FROM fish_stock f FULL OUTER JOIN sustainable_seafood s ON f.location = s.location GROUP BY f.location;',
#  'SELECT e.exhibition_name, f.source_name, ef.amount FROM art_exhibitions e INNER JOIN exhibition_funding ef ON e.exhibition_id = ef.exhibition_id INNER JOIN funding_sources f ON ef.source_id = f.source_id;',
#  'SELECT FLOOR(age/10)*10 as age_group, COUNT(*) as num_users FROM SPOTIFY_USERS WHERE premium = true GROUP BY age_group;',
#  "SELECT country, genre, SUM(count) FROM country_movies WHERE genre IN ('Action', 'Comedy') GROUP BY country, genre ORDER BY SUM(count) DESC;",
#  "SELECT EXTRACT(QUARTER FROM violation_date) AS quarter, COUNT(*) FROM compliance_violations WHERE violation_date BETWEEN '2021-01-01' AND '2021-12-31' GROUP BY quarter;",
#  "SELECT campaign_name FROM climate_communication_campaigns WHERE region = 'Asia' AND budget > 1000000.00 AND focus = 'Mitigation';",
#  "SELECT MAX(Amount) FROM ClimateAid WHERE Community IN ('Ashaninka', 'Yawanawá', 'Huni Kui', 'Matsés', 'Kaxinawá');",
#  'SELECT t.name, COUNT(mhc.id) FROM mental_health_clinics mhc JOIN australia_territories t ON mhc.territory_id = t.id GROUP BY t.name;',
#  "SELECT founding_year, AVG(employee_count) FROM (SELECT company_name, CASE WHEN industry = 'Technology' THEN founding_year END as founding_year, employee_count FROM Company_Info) t GROUP BY founding_year;",
#  "SELECT SUM(funding.amount) FROM funding JOIN founders ON funding.company_id = founders.company_id WHERE founders.gender = 'female';",
#  'SELECT region, AVG(size), MIN(size), MAX(size), STDDEV(size) FROM farm_sizes JOIN kenyan_regions ON farm_sizes.region = kenyan_regions.region_code WHERE year = 2017 GROUP BY region;',
#  "SELECT ImplementationYear, COUNT(ProgramID) FROM SupportPrograms WHERE Region = 'Northeast' GROUP BY ImplementationYear;",
#  'SELECT name, MAX(avg_temperature) as max_temperature, MAX(avg_salinity) as max_salinity FROM oceans;',
#  'SELECT c.Category_Name, SUM(p.Weight) FROM Products p JOIN Categories c ON p.Category_ID = c.Category_ID WHERE p.Organic = TRUE GROUP BY c.Category_ID;',
#  'SELECT metric_name, rating FROM community_policing;',
#  'SELECT * FROM CulturalEvents WHERE date >= DATEADD(year, -1, GETDATE()) ORDER BY attendance DESC LIMIT 1;',
#  "INSERT INTO weapons (name, origin, status) VALUES ('Javelin', 'USA', 'in-development');",
#  "SELECT type FROM military_equipment WHERE country = 'Canada';",
#  'SELECT mi.name, mi.year FROM military_innovation mi INNER JOIN (SELECT DISTINCT country FROM military_innovation) mic ON mi.country = mic.country;',
#  "SELECT AVG(total_amount) FROM transactions t INNER JOIN clients c ON t.client_id = c.client_id WHERE c.net_worth > 1000000 AND t.transaction_date BETWEEN '2023-10-01' AND '2023-12-31'",
#  "SELECT MIN(account_balance) FROM clients WHERE region = 'Northwest';",
#  'DELETE FROM ports WHERE port_id = 5002;',
#  "SELECT COUNT(DISTINCT vessels.id) FROM vessels LEFT JOIN cargo ON vessels.id = cargo.vessel_id LEFT JOIN ports ON cargo.port_id = ports.id WHERE ports.name = 'Port of Mumbai' AND cargo.loaded_date >= DATE('2022-06-01') AND cargo.loaded_date <= DATE('2022-06-30') AND cargo.perishable = false GROUP BY vessels.id HAVING COUNT(cargo.id) = 0;",
#  'SELECT port_id, AVG(time_in_hours) FROM cargo_handling GROUP BY port_id;',
#  'SELECT w.material, w.waste_quantity, i.avg_waste FROM WasteData w INNER JOIN IndustryAverages i ON w.material = i.material WHERE w.waste_quantity > i.avg_waste;',
#  'SELECT s.state, COUNT(h.id) AS num_hospitals, COUNT(c.id) AS num_clinics, COUNT(h2.id) * 100.0 / (COUNT(h.id) + COUNT(c.id)) AS pct_hospitals_with_ct_scan FROM hospitals h INNER JOIN clinics c ON h.state = c.state INNER JOIN hospitals h2 ON h.state = h2.state AND h2.has_ct_scan = true GROUP BY s.state;',
#  'SELECT country, COUNT(*) FROM green_energy_funding WHERE funding_date >= DATE_SUB(CURRENT_DATE, INTERVAL 3 MONTH) GROUP BY country;',
#  'DROP TABLE EmployeeDemographics;',
#  "DELETE FROM fields WHERE field_name LIKE '%Field%' AND region = 'Gulf of Mexico';",
#  "SELECT EXTRACT(MONTH FROM post_date) as month, platform, COUNT(*) as num_posts FROM social_media_posts WHERE post_text LIKE '%ethical AI%' GROUP BY month, platform ORDER BY month;",
#  "DELETE FROM fares WHERE rider_id = (SELECT rider_id FROM riders WHERE name = 'John Smith');",
#  "SELECT COUNT(*) FROM bus_trips WHERE trip_date BETWEEN '2022-01-01' AND '2022-03-31' GROUP BY borough;",
#  'SELECT sr.range, COUNT(p.product_id) FROM products p JOIN size_ranges sr ON p.size = sr.size GROUP BY sr.range;',
#  "SELECT * FROM (SELECT *, ROW_NUMBER() OVER (PARTITION BY category ORDER BY likes DESC) as rn FROM posts) t WHERE t.rn = 3 AND t.category = 'sports';",
#  'SELECT AVG(comments_count) FROM social_media_posts;',
#  "SELECT AVG(price) FROM textile_sourcing WHERE material = 'cotton' AND country = 'United States';",
#  "SELECT customer_id, COUNT(*) as num_purchases FROM CustomerOrders WHERE product LIKE 'Sustainable%' AND order_date >= DATEADD(month, -6, CURRENT_DATE) GROUP BY customer_id ORDER BY num_purchases DESC;",
#  "SELECT P.Name, DATE_FORMAT(V.VolunteerDate, '%Y-%m') AS Month, SUM(V.Hours) AS TotalHours FROM Programs P JOIN Volunteers V ON P.ProgramID = V.ProgramID WHERE YEAR(V.VolunteerDate) = YEAR(CURDATE()) GROUP BY P.ProgramID, Month;",
#  "SELECT SUM(Dishes.calories) FROM Dishes WHERE Dishes.dish_name LIKE 'HealthyHarvest%' AND Dishes.price > (SELECT AVG(price) FROM Dishes)",
#  "SELECT WarehouseID, WarehouseName, SUM(Quantity) AS TotalQuantity FROM Warehouses W JOIN Shipments S ON W.WarehouseID = S.WarehouseID WHERE W.Country = 'USA' GROUP BY WarehouseID, WarehouseName ORDER BY TotalQuantity DESC LIMIT 3;",
#  "UPDATE warehouse_management SET item_name = 'Super Widget' WHERE id = 1;",
#  'SELECT return_point, SUM(return_id) as total_returns FROM returns WHERE return_half = 1 AND return_year = 2022 GROUP BY return_point ORDER BY total_returns DESC LIMIT 3;',
#  "SELECT AVG(funding) FROM biotech.startups WHERE industry = 'Biotechnology' AND location = 'USA';",
#  "SELECT DISTINCT service_type FROM public_services WHERE service_type NOT IN ('type_c', 'type_d');",
#  "SELECT professors.name, grants.amount FROM professors INNER JOIN grants ON professors.id = grants.professor_id INNER JOIN departments ON professors.department_id = departments.id WHERE departments.name = 'Computer Science';",
#  'SELECT region, SUM(worker_count) FROM region_health_workers GROUP BY region;',
#  "SELECT COUNT(*) FROM virtual_tours WHERE location = 'Japan' AND date >= DATEADD(year, -1, GETDATE());",
#  "SELECT COUNT(DISTINCT vt.hotel_id) AS total_tours_engaged FROM virtual_tours vt INNER JOIN hotels h ON vt.hotel_id = h.hotel_id INNER JOIN ai_solutions ai ON h.hotel_id = ai.hotel_id WHERE h.region = 'Africa' AND ai.solution_type = 'housekeeping';",
#  "SELECT artwork_name, price FROM Artworks WHERE period = 'Surrealism';",
#  'SELECT MONTH(date) AS month, species, AVG(temperature) AS avg_temp FROM arctic_weather WHERE YEAR(date) = 2020 GROUP BY month, species;',
#  "SELECT AVG(age) FROM patients WHERE condition = 'Anxiety Disorder';",
#  "SELECT MAX(Cost) - MIN(Cost) as Cost_Difference FROM Road_Australia WHERE Country = 'Australia';",
#  "SELECT SUM(market_spend) FROM sustainable_tourism_initiatives WHERE country = 'Japan' AND start_year BETWEEN 2017 AND 2019;",
#  "SELECT AVG(Visitors_Brazil.expenditure) FROM Visitors_Brazil WHERE Visitors_Brazil.country = 'Brazil' AND Visitors_Brazil.year = 2022;",
#  'SELECT destination_name, country, awards, RANK() OVER (PARTITION BY country ORDER BY awards ASC) AS rank FROM Destinations;',
#  'SELECT county, COUNT(*) FROM legal_aid_organizations GROUP BY county;',
#  "SELECT s.biomass FROM MarineSpecies s JOIN MarineEcosystems e ON s.species_id IN (1, 2, 3) AND e.ecosystem_name = 'Coral Reef';",
#  'SELECT COUNT(*) FROM Arctic_Marine_Species WHERE is_affected_by_pollution = true;',
#  "SELECT AVG(views) FROM movies WHERE country = 'South Korea' UNION SELECT AVG(views) FROM movies WHERE country = 'Japan';",
# ...
#  "SELECT branch, personnel_count FROM MilitaryPersonnel WHERE branch IN ('Army', 'Navy', 'Air Force') GROUP BY branch;",
#  "DELETE FROM songs WHERE genre = 'jazz' AND release_year < 1960;",
#  "SELECT AVG(amount) FROM donations WHERE campaign = 'Education for All' AND YEAR(donation_date) = 2021;",
#  "SELECT COUNT(*) FROM Donations INNER JOIN Volunteers ON Donations.volunteer_id = Volunteers.id WHERE Volunteers.country = 'India';",
#  'SELECT year, score, LAG(score, 1) OVER (PARTITION BY student_id ORDER BY year) AS previous_score, score - LAG(score, 1) OVER (PARTITION BY student_id ORDER BY year) AS score_change FROM mental_health_changes;',
#  "INSERT INTO tanker (name, operator, source, destination, capacity) VALUES ('Norwegian Titan', 'Theta Shipping', 'Norway', 'Canada', 100000);",
#  "INSERT INTO oil_market (market_id, market_name, crude_oil_price_usd) VALUES (105, 'Asian Market', 85.99);",
#  "INSERT INTO wells (id, location, depth) VALUES (1, 'Brazil', 4000);",
#  'SELECT gender, MAX(age) as max_age, MIN(name) as oldest_donor FROM donors GROUP BY gender;',
#  'SELECT device_type, user_count FROM (SELECT device_type, user_count, NTILE(4) OVER (ORDER BY user_count) as percentile FROM technology_accessibility) tmp WHERE percentile IN (2, 3, 4) ORDER BY user_count ASC;',
#  'SELECT vehicle_type, SUM(fare) FROM Fares GROUP BY vehicle_type ORDER BY SUM(fare) DESC;',
#  "SELECT AVG(delay_time) FROM subway_delays WHERE station = 'uptown' GROUP BY EXTRACT(MONTH FROM delay_date);",
#  "SELECT AVG(g.production_cost) FROM garments g GROUP BY g.factory_id HAVING COUNT(*) FILTER (WHERE g.garment_name LIKE '%Recycled Polyester%') > 0;",
#  "SELECT u.name, ps.data_sharing, JSON_EXTRACT(ps.sharing_preferences, '$.location') as location_sharing FROM users u INNER JOIN privacy_settings ps ON u.id = ps.user_id WHERE JSON_EXTRACT(ps.sharing_preferences, '$.location') = 'true';",
#  "SELECT MAX(users.followers) FROM users JOIN posts ON users.id = posts.user_id WHERE posts.content ILIKE '%sustainable living%' AND posts.post_date >= NOW() - INTERVAL '1 month';",
#  "SELECT SUM(revenue) FROM sponsored_posts WHERE category = 'beauty';",
#  "DELETE FROM nutrition_facts WHERE product_id = 'P001';",
#  'SELECT supplier_id, COUNT(*) as shipment_count FROM shipments WHERE organic = true GROUP BY supplier_id ORDER BY shipment_count DESC LIMIT 3;',
#  "SELECT SUM(quantity) FROM shipments JOIN warehouses ON shipments.warehouse_id = warehouses.warehouse_id WHERE warehouses.city = 'NYC';",
#  'SELECT SUM(budget) FROM biosensor_tech WHERE quarter IN (3, 4) AND year = 2021;',
#  'SELECT i.name, b.investment_amount FROM investors i JOIN biosensors b ON i.id = b.investor_id WHERE b.investment_amount > 50000;',
#  "UPDATE startups SET name = 'NewStartupA' WHERE name = 'StartupA';",
#  "SELECT SUM(funding) FROM genome_inc WHERE project = 'Genetic Research';",
#  "SELECT SUM(size) as total_size FROM green_buildings WHERE country = 'India' AND certification = 'GRIHA';",
#  "SELECT contractor_name, COUNT(*) AS total_certified_projects FROM green_buildings INNER JOIN contractors ON green_buildings.contractor_id = contractors.contractor_id WHERE contractors.state = 'CA' GROUP BY contractor_name ORDER BY total_certified_projects DESC LIMIT 5;",
#  'SELECT C.name, COUNT(*) FROM Countries C INNER JOIN CountryHeritages CH ON C.id = CH.country_id GROUP BY C.name ORDER BY COUNT(*) DESC LIMIT 3;',
#  'SELECT c.continent_id, AVG(COUNT(*)) FROM countries c JOIN languages l ON c.id = l.country_id WHERE c.continent_id = 1 GROUP BY c.continent_id;',
#  "SELECT COUNT(*) FROM diagnoses JOIN patients ON diagnoses.patient_id = patients.id WHERE diagnoses.condition = 'Anxiety' AND patients.country = 'Germany';",
#  "SELECT AVG(maintenance_cost) FROM Airport WHERE country = 'Germany' AND type = 'Airport';",
#  'SELECT country_name, COUNT(*) FROM MarinePollution GROUP BY country_name;',
#  "SELECT COUNT(*) FROM tv_shows WHERE country = 'Spain' AND year = 2017;",
#  "SELECT MIN(pub_date) FROM articles_tech WHERE category = 'Tech';",
#  'SELECT COUNT(*) as num_allergen_free, (COUNT(*) * 100.0 / (SELECT COUNT(*) FROM menus)) as allergen_free_percentage FROM menus WHERE has_allergen_free = TRUE;',
#  "SELECT Region, SUM(Quantity) as Total_Quantity FROM Regional_Sales WHERE Menu_Item = 'Veggie Burger' GROUP BY Region;",
#  "SELECT SUM(i.unit_price * o.quantity) as revenue FROM inventory i JOIN orders o ON i.item_id = o.item_id JOIN menu_items m ON i.item_id = m.item_id WHERE m.is_organic = true AND o.order_date BETWEEN '2022-02-01' AND '2022-02-28';",
#  "SELECT MAX(quantity_sold) FROM naval_sales WHERE company = 'ArmaTech' AND region = 'Europe';",
#  "SELECT COUNT(DISTINCT genre) FROM Festivals WHERE region = 'Africa' AND festival_performance = 1;",
#  "DELETE FROM audience_demographics WHERE age < 18 AND country = 'Russia';",
#  'DELETE FROM Players WHERE HasPlayedVR = FALSE AND Age < 25;',
#  "SELECT AVG(PrizePool) FROM PrizePools WHERE Game = 'WoW' AND Region = 'North America';",
#  'SELECT COUNT(*) FROM sensor;',
#  'DELETE FROM irrigation_data WHERE irrigation_id = 31;',
#  'SELECT country, quantity * 100.0 / SUM(quantity) OVER (PARTITION BY NULL) AS percentage FROM europium_production;',
#  "SELECT MAX(quantity * price) FROM Yttrium_Sales WHERE country = 'India' GROUP BY year ORDER BY year DESC LIMIT 3;",
#  "UPDATE menu SET price = 12.99 WHERE item_name = 'Tofu Stir Fry' AND restaurant_id = 5 AND price < 12.99;",
#  "SELECT MIN(revenue) FROM Restaurants WHERE type = 'Ethiopian';",
#  "SELECT SUM(Revenue) FROM Revenue WHERE Practice = 'Ethical Labor' AND Country = 'South America';",
#  "SELECT name FROM space_craft WHERE orbit = 'GTO' ORDER BY mass DESC LIMIT 1;",
#  'SELECT SUM(Mass) FROM Space_Debris;',
#  'SELECT team_id, SUM(total_sales) FROM team_performance WHERE home_game = true AND total_sales > 0 GROUP BY team_id;',
#  'SELECT salesperson_id, COUNT(*) as num_sales, SUM(revenue) as total_revenue FROM sales GROUP BY salesperson_id ORDER BY num_sales DESC;',
#  'SELECT country, AVG(sustainability_rating) as avg_sustainability_rating, RANK() OVER (ORDER BY AVG(sustainability_rating) DESC) as ranking FROM suppliers GROUP BY country HAVING COUNT(*) FILTER (WHERE sustainability_rating > 0) >= 3 ORDER BY avg_sustainability_rating DESC, country;',
#  "SELECT PolicyholderID, Name FROM (SELECT PolicyholderID, Name, PolicyType, ClaimAmount, ROW_NUMBER() OVER (PARTITION BY PolicyholderID ORDER BY ClaimAmount DESC) AS RankClaimAmount FROM Policyholder JOIN Policy ON Policyholder.PolicyholderID = Policy.PolicyholderID JOIN Claim ON Policy.PolicyID = Claim.PolicyID WHERE Region = 'Midwest') AS Subquery WHERE RankClaimAmount = 1 AND ClaimAmount > 1000;",
#  "SELECT AVG(num_employees) FROM workplaces WHERE country = 'USA' AND is_unionized = true;",
#  'SELECT AVG(total_workers) FROM industry;',
#  "SELECT AVG(speed) FROM vessel_speed WHERE vessel_name = 'VesselL';",
#  'SELECT Visitor.name FROM Visitor JOIN Visitor_Exhibition ON Visitor.id = Visitor_Exhibition.visitor_id GROUP BY Visitor.name HAVING COUNT(DISTINCT Visitor_Exhibition.exhibition_id) > 1;',
#  'DELETE FROM recycling_rates WHERE year = 2018;',
#  "SELECT SUM(savings) FROM WaterConservationInitiatives WHERE city = 'San Diego' AND year = 2019;",
#  'DELETE FROM Workouts WHERE id = 2;',
#  "SELECT COUNT(*) FROM fairness_incidents WHERE region = 'Asia' AND incident_date >= '2022-04-01' AND incident_date < '2022-07-01';",
#  "SELECT AVG(num_models) as avg_models_per_month FROM (SELECT COUNT(*) as num_models, EXTRACT(MONTH FROM launch_date) as month FROM explainable_ai WHERE country = 'Singapore' AND launch_date BETWEEN '2021-01-01' AND '2021-12-31' GROUP BY month) as subquery;",
#  'SELECT spacecraft, COUNT(*) FROM Accidents GROUP BY spacecraft;',
#  "SELECT COUNT(*) FROM Satellite_Deployments WHERE manufacturer = 'SpaceX' AND success = true AND YEAR(deployment_date) >= 2017;",
#  'SELECT country, COUNT(program) FROM community_education GROUP BY country;',
#  'CREATE VIEW fish_biomass AS SELECT species, AVG(biomass) as avg_biomass FROM fish_stock GROUP BY species;',
#  "SELECT AVG(ad.attendee_age) FROM attendee_demographics ad JOIN event_attendance ea ON ad.attendee_id = ea.attendee_id WHERE ea.event_name LIKE '%Dance%';",
#  "DELETE FROM genres WHERE country = 'Russia';",
#  "SELECT SUM(amount) FROM Funding WHERE program = 'Dance' AND location = 'California' AND date >= '2017-01-01';",
#  "SELECT release_year, AVG(production_budget) FROM movies WHERE genre = 'Action' AND release_year BETWEEN 2010 AND 2020 GROUP BY release_year;",
#  "SELECT project_id, region, labor_hours, RANK() OVER (ORDER BY labor_hours DESC) as labor_rank FROM project WHERE region = 'Northeast';",
#  "SELECT AVG(quantity) FROM Waste_Disposal WHERE chemical_name = 'Sulfuric Acid' AND disposal_date BETWEEN '2022-07-01' AND '2022-07-31';",
#  "SELECT MAX(CP.SafetyScore) AS MaxScore FROM ChemicalProducts CP INNER JOIN Manufacturers M ON CP.ManufacturerID = M.ManufacturerID WHERE M.Region = 'Asia';",
#  "SELECT COUNT(*) FROM climate_finance WHERE location = 'Asia';",
#  'SELECT drug_name, SUM(revenue) FROM drug_sales_3 WHERE year BETWEEN 2017 AND 2019 GROUP BY drug_name;',
#  "SELECT COUNT(*) FROM community_health_centers WHERE location = 'urban';",
#  "SELECT AVG(Employee.date_hired) FROM Employee INNER JOIN Company ON Company.id = Employee.company_id WHERE Company.industry = 'GreenTech';",
#  'SELECT country, initiatives FROM urban_agriculture ORDER BY initiatives DESC;',
#  'SELECT type, MIN(budget) FROM AccommodationTypes GROUP BY type;',
#  "SELECT COUNT(program) FROM conservation_efforts WHERE country = 'Pacific Ocean';",
#  'SELECT ingredient_name, AVG(sustainability_rating) as avg_rating, COUNT(product_id) as total_products FROM ingredients GROUP BY ingredient_name ORDER BY avg_rating DESC, total_products DESC LIMIT 2;',
#  'SELECT product_id, carbon_footprint, AVG(carbon_footprint) OVER (ORDER BY product_id ROWS BETWEEN UNBOUNDED PRECEDING AND CURRENT ROW) as running_avg_cf FROM sustainability_metrics;',
#  'SELECT call_type, COUNT(*) FROM search_and_rescue GROUP BY call_type;',
#  'SELECT call_type, AVG(response_time) FROM emergency_calls GROUP BY call_type;',
#  "SELECT COUNT(*) FROM community_policing WHERE country = 'USA';",
#  "SELECT COUNT(*) FROM emergency_incidents WHERE city = 'Oakland';",
#  "SELECT MAX(Value) FROM Investments WHERE Market = 'US'",
#  "SELECT MIN(age), MAX(age) FROM customers WHERE country = 'Japan';",
#  "SELECT * FROM Employee WHERE Department = 'Quality Control';",
#  "SELECT AVG(age) FROM (SELECT patient_id, age FROM patients JOIN hospital_visits ON patients.patient_id = hospital_visits.patient_id WHERE hospital_visits.location = 'Rural Louisiana' AND EXTRACT(YEAR FROM hospital_visits.visit_date) = 2021) AS subquery;",
#  'SELECT region_id, incident_quarter, AVG(incident_count) OVER (PARTITION BY region_id ORDER BY incident_quarter ROWS BETWEEN 2 PRECEDING AND CURRENT ROW) as moving_avg FROM incident_data;',
#  "SELECT name FROM advisors WHERE clearance = 'Top Secret';",
#  "SELECT Name FROM MilitaryAircrafts WHERE ManufacturingDate >= '2000-01-01' AND Country = 'USA';",
#  'SELECT ProgramCategory, SUM(Spent) as TotalSpent FROM Programs WHERE YEAR(ProgramStartDate) = 2022 AND QUARTER(ProgramStartDate) <= 2 GROUP BY ProgramCategory;',
#  'SELECT subject, COUNT(*) as number_of_teachers FROM teachers WHERE professional_development_course_completion_date >= DATE_SUB(CURRENT_DATE, INTERVAL 1 YEAR) GROUP BY subject;',
#  "SELECT COUNT(*) FROM Employees WHERE Department = 'HR' AND HireDate >= DATE_SUB(CURRENT_DATE, INTERVAL 6 MONTH);",
#  "SELECT AVG(efficiency_rating) FROM energy_efficiency WHERE building_type = 'Residential' AND country = 'India';",
#  "SELECT AVG(age) FROM basketball_players WHERE gender = 'female';",
#  'DELETE FROM shelters WHERE shelter_id = 2;',
#  'SELECT disaster_type, SUM(donation_amount) as total_donations FROM donations WHERE donation_date >= DATE_SUB(NOW(), INTERVAL 3 MONTH) GROUP BY disaster_type;',
#  'SELECT tr.route_name, AVG(tf.fare_amount) as avg_fare FROM train_routes tr INNER JOIN train_fares tf ON tr.route_id = tf.route_id GROUP BY tr.route_name;',
#  "SELECT COUNT(*) FROM posts WHERE platform = 'Twitter' AND MONTH(post_date) = 6 AND YEAR(post_date) = 2021 AND user_id IN (SELECT user_id FROM users WHERE category = 'brand');",
#  'SELECT AVG(posts.likes) as avg_likes FROM posts WHERE posts.user_id IN (SELECT user_id FROM posts GROUP BY user_id HAVING COUNT(*) > 1) AND posts.timestamp >= DATE_SUB(NOW(), INTERVAL 1 MONTH);',
#  "SELECT SUBSTRING_INDEX(SUBSTRING_INDEX(hashtags, ' ', n.n), ' ', -1) hashtag, COUNT(*) count FROM posts JOIN users ON posts.user_id = users.id CROSS JOIN (SELECT 1 n UNION SELECT 2 UNION SELECT 3 UNION SELECT 4 UNION SELECT 5) n WHERE users.country = 'Brazil' GROUP BY hashtag ORDER BY count DESC LIMIT 1;",
#  "SELECT COUNT(*) FROM financial_capability_training WHERE quarter = 1 AND year = 2022 AND country = 'Germany';",
#  "UPDATE dishes SET calorie_count = 350 WHERE name = 'Pão de Queijo' AND country = 'Brazil';",
#  "SELECT AVG(expression) FROM (SELECT expression FROM genetic.gene_expression WHERE tissue = 'Cardiovascular' ORDER BY expression DESC LIMIT 5);",
#  "SELECT energy_type, AVG(energy_output) as avg_energy_output FROM renewable_energy WHERE energy_type = 'Wind' GROUP BY energy_type;",
#  "SELECT worker_id, (SUM(CASE WHEN metric1 THEN 1 ELSE 0 END) + SUM(CASE WHEN metric2 THEN 1 ELSE 0 END) + SUM(CASE WHEN metric3 THEN 1 ELSE 0 END)) * 100.0 / 3 as percentage_met FROM health_equity_metrics_worker WHERE region = 'West' AND year IN (2020, 2021) GROUP BY worker_id;",
#  "SELECT AVG(rating) FROM virtual_tours WHERE country IN ('Indonesia', 'Malaysia', 'Thailand') AND quarter = 'Q2';",
#  "SELECT MAX(revenue) FROM sustainable_tours WHERE country = 'Japan';",
#  "SELECT COUNT(*) FROM Exhibitions WHERE (location = 'France' OR location = 'Spain') AND movement = 'Modern Art';",
#  'DELETE FROM LanguagePreservation WHERE id = 1;',
#  "SELECT Continent, AVG(Number_Speakers) AS Avg_Speakers, MIN(Language_Name) AS Most_Spoken FROM Endangered_Languages_Continent WHERE Continent IN ('South America') GROUP BY Continent;",
#  "SELECT COUNT(*) FROM court_cases WHERE defender_type = 'Public Defender' AND YEAR(court_date) = 2020 AND city(court_date) = 'New York';",
#  'SELECT province_territory, AVG(clients_served) AS average_clients_served FROM canada_legal_aid GROUP BY province_territory;',
#  'DELETE FROM MilitaryEquipmentSales WHERE sale_amount > 50000;',
#  "SELECT SUM(production) FROM mine WHERE mineral = 'Iron' AND location = 'Russia';",
#  'SELECT mine_name, AVG(co2_amount) AS avg_monthly_emission FROM co2_emissions JOIN mine_info ON co2_emissions.mine_id = mine_info.mine_id GROUP BY mine_id HAVING AVG(co2_amount) > (SELECT AVG(co2_amount) FROM co2_emissions);',
#  "SELECT NewsSource.name, COUNT(DISTINCT NewsSource.author) AS unique_authors FROM news.NewsSource INNER JOIN news.Region ON NewsSource.name = Region.name WHERE Region.location = 'western' GROUP BY NewsSource.name",
#  "SELECT COUNT(*) FROM deep_sea_expeditions WHERE location = 'Pacific Ocean';",
#  "SELECT species_name FROM marine_species WHERE ocean_location = 'Arctic Ocean';",
#  'SELECT type, COUNT(*) FROM marine_species GROUP BY type;',
#  "SELECT location, AVG(humidity) as avg_humidity FROM Weather WHERE timestamp > NOW() - INTERVAL '1 week' GROUP BY location ORDER BY avg_humidity DESC LIMIT 3;",
#  "SELECT SUM(precipitation) FROM precipitation WHERE sensor_id = 005 AND timestamp BETWEEN '2022-01-01 00:00:00' AND '2022-01-31 23:59:59';",
#  "SELECT MAX(size) - MIN(size) FROM properties WHERE city = 'Sydney';",
#  "SELECT country, COUNT(*) as num_policies FROM clean_energy_policies WHERE policy_status = 'Implemented' GROUP BY country;",
#  "SELECT product_category, SUM(sale_amount * sales_price) AS total_revenue FROM products p JOIN sales s ON p.product_id = s.product_id WHERE sale_region IN ('UK', 'France', 'Germany') GROUP BY product_category ORDER BY total_revenue DESC LIMIT 3;",
#  ...]

# %%
import evaluate

# %%
# Tính BLEU
bleu = evaluate.load("bleu")
results = bleu.compute(predictions=extracted_sqls_with_context, references=references)

print(results)
# Out:
# Downloading builder script:   0%|          | 0.00/5.94k [00:00<?, ?B/s]
# Downloading extra modules:   0%|          | 0.00/1.55k [00:00<?, ?B/s]
# Downloading extra modules:   0%|          | 0.00/3.34k [00:00<?, ?B/s]
# {'bleu': 0.7024396808185429, 'precisions': [0.8420181664398926, 0.7422860949842962, 0.6769394680767106, 0.6196219769418221], 'brevity_penalty': 0.9816726196522841, 'length_ratio': 0.9818385326400925, 'translation_length': 54386, 'reference_length': 55392}
